# %%
import os
os.chdir('..')

from typing import Any, Dict, Optional

import pandas as pd
import numpy as np

import xtx.utils.dev_utils as dev_utils
# from xtx.features.feature_extractor import FeatureExtractor
from xtx.modeling.runners import CrossValClassificationRunner, CrossValRunner
# from xtx.modeling.stacking import RunnersStacking
from xtx.modeling.time_folds import TimeFolds

pd.set_option("display.max_columns", 100)
experiment = dev_utils.load_yaml('configs/experiment.yaml')

from xtx.modeling.evaluation import get_mse_and_corr_scores
def score_cols(fold_processor, usecols, prefix=None):
    model = runner.init_model()
    model.fit(fold_processor.train_data[:, usecols], fold_processor.train_target)
    val_predicted = model.predict(fold_processor.valid_data[:, usecols])
    return get_mse_and_corr_scores(fold_processor.valid_target, val_predicted, verbose=True, prefix=prefix)

experiment
# Out:
# {'train_data_path': 'data/xtx_data.csv',
#  'test_data_path': None,
#  'train_topk_features': 'topk_artefacts',
#  'test_topk_features': 'test_topk_artefacts',
#  'cached_features': 'data/__extended_features.pkl',
#  'cached_test_features': 'data/__extended_test_features.pkl',
#  'from_pool': False,
#  'usecols': ['usecols/usecols_fold_0.txt', 'usecols/usecols_fold_1.txt'],
#  'predictions_dir': 'predictions/debug',
#  'runners_dir': 'runners/5_folds_extended',
#  'model_zoo': 'configs/models_zoo.yaml',
#  'use_regression_models': ['default_ridge', 'default_dart'],
#  'use_classification_models': [],
#  'stacking_model': 'stacking_ridge',
#  'TimeFolds': {'n_folds': 5,
#   'minifold_size': 60000,
#   'neutral_ratio': 0.025,
#   'test_ratio': 0.2,
#   'train_test_gap': 2000},
#  'random_seed': 42,
#  'pseudo_target': [40]}

# %%
model_zoo = dev_utils.load_yaml(experiment['model_zoo'])
# model_config = model_zoo['train_zoo']['default_ridge']
model_config = model_zoo['selection_ridge']
model_config
# Out:
# {'model_module': 'sklearn.linear_model',
#  'model_cls': 'Ridge',
#  'model_params': {'alpha': 10}}

# %%
train_features = pd.read_pickle(experiment['cached_features'])
target = pd.read_csv('data/xtx_data.csv', usecols=['y']).y
train_target = target.iloc[:-699533]
test_target = target.iloc[-699533:]
train_features.head()
# Out:
#    ask_rate_0  bid_rate_0  mid_price  mid_price_log  spread  bid_ask_spread  \
# 0      1619.5      1615.0    1617.25       7.389101     4.5        0.002786
# 1      1619.5      1615.0    1617.25       7.389101     4.5        0.002786
# 2      1619.5      1615.0    1617.25       7.389101     4.5        0.002786
# 3      1619.5      1615.0    1617.25       7.389101     4.5        0.002786
# 4      1619.5      1615.0    1617.25       7.389101     4.5        0.002786
#
#    ask_size_0  bid_size_0  ask_len  bid_len  len_ratio  \
# 0         1.0         7.0     35.0    192.0   0.182292
# 1         1.0         7.0     40.0    192.0   0.208333
# 2         1.0         7.0     42.0    192.0   0.218750
# 3         1.0         7.0     62.0    192.0   0.322917
# 4         1.0         7.0     72.0    192.0   0.375000
#
#    cum_volume_imbalance_0  volume_imbalance_0       wap0  \
# 0                    0.75                0.75  1618.9375
# 1                    0.75                0.75  1618.9375
# 2                    0.75                0.75  1618.9375
# 3                    0.75                0.75  1618.9375
# 4                    0.75                0.75  1618.9375
#
#    cum_volume_imbalance_1  volume_imbalance_1    wap1  cum_volume_imbalance_2  \
# 0                0.214286                 0.0  1617.0               -0.320755
# 1                0.214286                 0.0  1617.0               -0.320755
# 2                0.214286                 0.0  1617.0               -0.320755
# 3                0.214286                 0.0  1617.0               -0.320755
# 4                0.214286                 0.0  1617.0               -0.320755
#
#    volume_imbalance_2         wap2  cum_volume_imbalance_3  \
# 0               -0.92  1613.319946               -0.111111
# 1               -0.92  1613.319946               -0.176471
# 2               -0.92  1613.319946               -0.176471
# 3               -0.92  1613.319946               -0.176471
# 4               -0.92  1613.319946               -0.176471
#
#    volume_imbalance_3         wap3  cum_volume_imbalance_4  \
# 0            1.000000     0.000000                0.156627
# 1            0.333333  1618.333374                0.090909
# 2            0.333333  1618.333374                0.066667
# 3            0.333333  1618.333374               -0.127273
# 4            0.333333  1618.333374               -0.200000
#
#    volume_imbalance_4         wap4  cum_volume_imbalance_5  \
# 0            1.000000     0.000000                0.186047
# 1            1.000000     0.000000                0.120879
# 2            0.818182  1621.000000                0.096774
# 3           -0.047619  1616.238037               -0.097345
# 4           -0.230769  1615.230713               -0.170732
#
#    volume_imbalance_5  wap5  cum_volume_imbalance_6  volume_imbalance_6  wap6  \
# 0                 1.0   0.0                0.339623                 1.0   0.0
# 1                 1.0   0.0                0.279279                 1.0   0.0
# 2                 1.0   0.0                0.256637                 1.0   0.0
# 3                 1.0   0.0                0.067669                 1.0   0.0
# 4                 1.0   0.0               -0.006993                 1.0   0.0
#
#    cum_volume_imbalance_7  volume_imbalance_7  wap7  cum_volume_imbalance_8  \
# 0                0.473684                 1.0   0.0                0.513889
# 1                0.420290                 1.0   0.0                0.463087
# 2                0.400000                 1.0   0.0                0.443709
# 3                0.225000                 1.0   0.0                0.274854
# 4                0.152941                 1.0   0.0                0.204420
#
#    volume_imbalance_8  wap8  cum_volume_imbalance_9  volume_imbalance_9  wap9  \
# 0                 1.0   0.0                0.556962                 1.0   0.0
# 1                 1.0   0.0                0.509202                 1.0   0.0
# 2                 1.0   0.0                0.490909                 1.0   0.0
# 3                 1.0   0.0                0.329730                 1.0   0.0
# 4                 1.0   0.0                0.261538                 1.0   0.0
#
#    ask_rate_moda_spread  bid_rate_moda_spread  increased_ask_counts  \
# 0                   1.5                  12.0                     0
# 1                   1.5                  12.0                     1
# 2                   1.5                  12.0                     1
# 3                   1.5                  12.0                     1
# 4                   2.5                  12.0                     1
#
#    increased_ask_rank  decreased_ask_counts  decreased_ask_rank  \
# 0                  15                     0                  15
# 1                   3                     0                  15
# 2                   4                     0                  15
# 3                   4                     0                  15
# 4                   4                     0                  15
#
#    increased_bid_counts  increased_bid_rank  decreased_bid_counts  ...  \
# 0                     0                  15                     0  ...
# 1                     0                  15                     0  ...
# 2                     0                  15                     0  ...
# 3                     0                  15                     0  ...
# 4                     0                  15                     0  ...
#
#    wap1_10_mean  wap1_10_std  wap1_10_max  volume_imbalance_10_mean  \
# 0           NaN          NaN          NaN                       NaN
# 1           NaN          NaN          NaN                       NaN
# 2           NaN          NaN          NaN                       NaN
# 3           NaN          NaN          NaN                       NaN
# 4           NaN          NaN          NaN                       NaN
#
#    volume_imbalance_10_max  volume_imbalance_10_std  volume_imbalance_10_skew  \
# 0                      NaN                      NaN                       NaN
# 1                      NaN                      NaN                       NaN
# 2                      NaN                      NaN                       NaN
# 3                      NaN                      NaN                       NaN
# 4                      NaN                      NaN                       NaN
#
#    len_ratio_10_mean  len_ratio_10_std  wap0_20_mean  wap0_20_std  \
# 0                NaN               NaN           NaN          NaN
# 1                NaN               NaN           NaN          NaN
# 2                NaN               NaN           NaN          NaN
# 3                NaN               NaN           NaN          NaN
# 4                NaN               NaN           NaN          NaN
#
#    wap0_20_max  wap1_20_mean  wap1_20_std  wap1_20_max  \
# 0          NaN           NaN          NaN          NaN
# 1          NaN           NaN          NaN          NaN
# 2          NaN           NaN          NaN          NaN
# 3          NaN           NaN          NaN          NaN
# 4          NaN           NaN          NaN          NaN
#
#    volume_imbalance_20_mean  volume_imbalance_20_max  volume_imbalance_20_std  \
# 0                       NaN                      NaN                      NaN
# 1                       NaN                      NaN                      NaN
# 2                       NaN                      NaN                      NaN
# 3                       NaN                      NaN                      NaN
# 4                       NaN                      NaN                      NaN
#
#    volume_imbalance_20_skew  len_ratio_20_mean  len_ratio_20_std  \
# 0                       NaN                NaN               NaN
# 1                       NaN                NaN               NaN
# 2                       NaN                NaN               NaN
# 3                       NaN                NaN               NaN
# 4                       NaN                NaN               NaN
#
#    wap0_40_mean  wap0_40_std  wap0_40_max  wap1_40_mean  wap1_40_std  \
# 0           NaN          NaN          NaN           NaN          NaN
# 1           NaN          NaN          NaN           NaN          NaN
# 2           NaN          NaN          NaN           NaN          NaN
# 3           NaN          NaN          NaN           NaN          NaN
# 4           NaN          NaN          NaN           NaN          NaN
#
#    wap1_40_max  volume_imbalance_40_mean  volume_imbalance_40_max  \
# 0          NaN                       NaN                      NaN
# 1          NaN                       NaN                      NaN
# 2          NaN                       NaN                      NaN
# 3          NaN                       NaN                      NaN
# 4          NaN                       NaN                      NaN
#
#    volume_imbalance_40_std  volume_imbalance_40_skew  len_ratio_40_mean  \
# 0                      NaN                       NaN                NaN
# 1                      NaN                       NaN                NaN
# 2                      NaN                       NaN                NaN
# 3                      NaN                       NaN                NaN
# 4                      NaN                       NaN                NaN
#
#    len_ratio_40_std  wap0_80_mean  wap0_80_std  wap0_80_max  wap1_80_mean  \
# 0               NaN           NaN          NaN          NaN           NaN
# 1               NaN           NaN          NaN          NaN           NaN
# 2               NaN           NaN          NaN          NaN           NaN
# 3               NaN           NaN          NaN          NaN           NaN
# 4               NaN           NaN          NaN          NaN           NaN
#
#    wap1_80_std  wap1_80_max  volume_imbalance_80_mean  \
# 0          NaN          NaN                       NaN
# 1          NaN          NaN                       NaN
# 2          NaN          NaN                       NaN
# 3          NaN          NaN                       NaN
# 4          NaN          NaN                       NaN
#
#    volume_imbalance_80_max  volume_imbalance_80_std  volume_imbalance_80_skew  \
# 0                      NaN                      NaN                       NaN
# 1                      NaN                      NaN                       NaN
# 2                      NaN                      NaN                       NaN
# 3                      NaN                      NaN                       NaN
# 4                      NaN                      NaN                       NaN
#
#    len_ratio_80_mean  len_ratio_80_std  wap0_ewm_80  wap1_ewm_80  \
# 0                NaN               NaN    1618.9375       1617.0
# 1                NaN               NaN    1618.9375       1617.0
# 2                NaN               NaN    1618.9375       1617.0
# 3                NaN               NaN    1618.9375       1617.0
# 4                NaN               NaN    1618.9375       1617.0
#
#    mid_price_ewm_80  volume_imbalance_ewm_80  volume_imbalance_1_ewm_80
# 0           1617.25                     0.75                        0.0
# 1           1617.25                     0.75                        0.0
# 2           1617.25                     0.75                        0.0
# 3           1617.25                     0.75                        0.0
# 4           1617.25                     0.75                        0.0
#
# [5 rows x 231 columns]

# %%
time_folds = TimeFolds(**experiment['TimeFolds'])
print(experiment['TimeFolds'])
time_folds.fit(train_features, target)
# Out:
# {'n_folds': 5, 'minifold_size': 60000, 'neutral_ratio': 0.025, 'test_ratio': 0.2, 'train_test_gap': 2000}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/sneddy/projects/xtx/notebooks/select_features_from_pool.ipynb Cell 3' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/Users/sneddy/projects/xtx/notebooks/select_features_from_pool.ipynb#ch0000037?line=0'>1</a> time_folds = TimeFolds(**experiment['TimeFolds'])
#       <a href='vscode-notebook-cell:/Users/sneddy/projects/xtx/notebooks/select_features_from_pool.ipynb#ch0000037?line=1'>2</a> print(experiment['TimeFolds'])
# ----> <a href='vscode-notebook-cell:/Users/sneddy/projects/xtx/notebooks/select_features_from_pool.ipynb#ch0000037?line=2'>3</a> time_folds.fit(train_features, target)
#
# NameError: name 'target' is not defined

# %%
runner = CrossValRunner(time_folds, **model_config)
fold_processor = runner.preprocessor.prepare_fold(fold_id)
# Out:
# {'model_module': 'sklearn.linear_model', 'model_cls': 'Ridge', 'model_params': {'alpha': 10, 'positive': True}}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/sneddy/projects/xtx/notebooks/select_features_from_pool.ipynb Cell 3' in <cell line: 5>()
#       <a href='vscode-notebook-cell:/Users/sneddy/projects/xtx/notebooks/select_features_from_pool.ipynb#ch0000005?line=2'>3</a> model_config = model_zoo['selection_ridge']
#       <a href='vscode-notebook-cell:/Users/sneddy/projects/xtx/notebooks/select_features_from_pool.ipynb#ch0000005?line=3'>4</a> print(model_config)
# ----> <a href='vscode-notebook-cell:/Users/sneddy/projects/xtx/notebooks/select_features_from_pool.ipynb#ch0000005?line=4'>5</a> runner = CrossValRunner(time_folds, **model_config)
#
# NameError: name 'time_folds' is not defined

# %%
n_features = train_features.shape[1]
colname2idx = {name: idx for idx, name in enumerate(train_features.columns)}

dev_utils.init_seed(42)
best_usecols = np.random.choice(n_features, n_features // 2, replace=False)
best_mse, best_corr = score_cols(fold_processor, usecols=best_usecols)
# Out:
#  MSE score: 0.4863;  Corr score: 0.1643

# %%
for current_iter in range(100000):
    if current_iter % 2 == 0:
        removing_col = np.random.choice(best_usecols)
        use_cols = [col for col in best_usecols if col != removing_col]
        prefix = f'---{removing_col}'
    else:
        adding_col = np.random.choice([idx for idx in range(n_features) if idx not in best_usecols])
        use_cols = best_usecols + [adding_col]
        prefix = f'+++{adding_col}'
    current_mse, current_corr = score_cols(fold_processor, usecols=use_cols, prefix=prefix)
    if current_mse < best_mse:
        best_usecols = use_cols
        best_mse, best_corr = current_mse, current_corr
        if current_iter % 2 == 0:
            print(f'SUCCESSFULL REMOVE OF {train_features.columns[removing_col]}. Len: {len(use_cols)}')
        else:
            print(f'SUCCESSFULL ADDING OF {train_features.columns[adding_col]}. Len: {len(use_cols)}')
            print(f'Last added cols: {[train_features.columns[col] for col in best_usecols[-5:]]}')
# Out:
# ---170 MSE score: 0.4863; ---170 Corr score: 0.1643
# +++122 MSE score: 0.4863; +++122 Corr score: 0.1642
# ---153 MSE score: 0.4863; ---153 Corr score: 0.1643
# +++33 MSE score: 0.4864; +++33 Corr score: 0.1642
# ---182 MSE score: 0.4864; ---182 Corr score: 0.1641
# +++174 MSE score: 0.4863; +++174 Corr score: 0.1645
# SUCCESSFULL ADDING OF mid_price_min_diff_80. Len: 123
# Last added cols: ['volume_imbalance_80_max', 'len_ratio_80_mean', 'wap0_ewm_80', 'volume_imbalance_ewm_80', 'mid_price_min_diff_80']
# ---98 MSE score: 0.4863; ---98 Corr score: 0.1645
# +++44 MSE score: 0.4862; +++44 Corr score: 0.1652
# SUCCESSFULL ADDING OF increased_ask_rank. Len: 124
# Last added cols: ['len_ratio_80_mean', 'wap0_ewm_80', 'volume_imbalance_ewm_80', 'mid_price_min_diff_80', 'increased_ask_rank']
# ---170 MSE score: 0.4862; ---170 Corr score: 0.1651
# +++194 MSE score: 0.4863; +++194 Corr score: 0.1649
# ---140 MSE score: 0.4862; ---140 Corr score: 0.1652
# +++184 MSE score: 0.4862; +++184 Corr score: 0.1650
# ---126 MSE score: 0.4863; ---126 Corr score: 0.1648
# +++199 MSE score: 0.4862; +++199 Corr score: 0.1652
# ---215 MSE score: 0.4863; ---215 Corr score: 0.1648
# +++219 MSE score: 0.4862; +++219 Corr score: 0.1652
# ---175 MSE score: 0.4862; ---175 Corr score: 0.1650
# +++62 MSE score: 0.4862; +++62 Corr score: 0.1652
# ---2 MSE score: 0.4862; ---2 Corr score: 0.1652
# +++55 MSE score: 0.4862; +++55 Corr score: 0.1652
# ---88 MSE score: 0.4862; ---88 Corr score: 0.1652
# +++4 MSE score: 0.4862; +++4 Corr score: 0.1653
# SUCCESSFULL ADDING OF spread. Len: 125
# Last added cols: ['wap0_ewm_80', 'volume_imbalance_ewm_80', 'mid_price_min_diff_80', 'increased_ask_rank', 'spread']
# ---142 MSE score: 0.4862; ---142 Corr score: 0.1652
# +++79 MSE score: 0.4862; +++79 Corr score: 0.1653
# ---61 MSE score: 0.4862; ---61 Corr score: 0.1653
# SUCCESSFULL REMOVE OF bid_flatten_len_5. Len: 124
# +++6 MSE score: 0.4862; +++6 Corr score: 0.1650
# ---109 MSE score: 0.4862; ---109 Corr score: 0.1649
# +++152 MSE score: 0.4862; +++152 Corr score: 0.1653
# SUCCESSFULL ADDING OF mid_price_log_80. Len: 125
# Last added cols: ['volume_imbalance_ewm_80', 'mid_price_min_diff_80', 'increased_ask_rank', 'spread', 'mid_price_log_80']
# ---35 MSE score: 0.4862; ---35 Corr score: 0.1652
# +++83 MSE score: 0.4861; +++83 Corr score: 0.1658
# SUCCESSFULL ADDING OF bid_flatten_skew_25. Len: 126
# Last added cols: ['mid_price_min_diff_80', 'increased_ask_rank', 'spread', 'mid_price_log_80', 'bid_flatten_skew_25']
# ---128 MSE score: 0.4861; ---128 Corr score: 0.1658
# SUCCESSFULL REMOVE OF decreased_ask_counts_3_volume. Len: 125
# +++150 MSE score: 0.4862; +++150 Corr score: 0.1656
# ---36 MSE score: 0.4861; ---36 Corr score: 0.1660
# SUCCESSFULL REMOVE OF volume_imbalance_8. Len: 124
# +++201 MSE score: 0.4861; +++201 Corr score: 0.1655
# ---84 MSE score: 0.4861; ---84 Corr score: 0.1660
# +++204 MSE score: 0.4861; +++204 Corr score: 0.1660
# SUCCESSFULL ADDING OF wap0_40_max. Len: 125
# Last added cols: ['increased_ask_rank', 'spread', 'mid_price_log_80', 'bid_flatten_skew_25', 'wap0_40_max']
# ---98 MSE score: 0.4861; ---98 Corr score: 0.1660
# SUCCESSFULL REMOVE OF bid_flatten_mean_50. Len: 124
# +++103 MSE score: 0.4861; +++103 Corr score: 0.1660
# SUCCESSFULL ADDING OF flatten_spread_50_mean. Len: 125
# Last added cols: ['spread', 'mid_price_log_80', 'bid_flatten_skew_25', 'wap0_40_max', 'flatten_spread_50_mean']
# ---157 MSE score: 0.4861; ---157 Corr score: 0.1660
# SUCCESSFULL REMOVE OF spread_rolling_std_5. Len: 124
# +++151 MSE score: 0.4861; +++151 Corr score: 0.1659
# ---137 MSE score: 0.4861; ---137 Corr score: 0.1660
# +++36 MSE score: 0.4861; +++36 Corr score: 0.1659
# ---109 MSE score: 0.4861; ---109 Corr score: 0.1657
# +++157 MSE score: 0.4861; +++157 Corr score: 0.1660
# ---81 MSE score: 0.4863; ---81 Corr score: 0.1647
# +++157 MSE score: 0.4861; +++157 Corr score: 0.1660
# ---88 MSE score: 0.4861; ---88 Corr score: 0.1660
# +++141 MSE score: 0.4861; +++141 Corr score: 0.1661
# SUCCESSFULL ADDING OF increased_ask_counts_20_volume. Len: 125
# Last added cols: ['mid_price_log_80', 'bid_flatten_skew_25', 'wap0_40_max', 'flatten_spread_50_mean', 'increased_ask_counts_20_volume']
# ---226 MSE score: 0.4861; ---226 Corr score: 0.1659
# +++163 MSE score: 0.4860; +++163 Corr score: 0.1661
# SUCCESSFULL ADDING OF mid_price_max_diff_20. Len: 126
# Last added cols: ['bid_flatten_skew_25', 'wap0_40_max', 'flatten_spread_50_mean', 'increased_ask_counts_20_volume', 'mid_price_max_diff_20']
# ---152 MSE score: 0.4861; ---152 Corr score: 0.1660
# +++8 MSE score: 0.4862; +++8 Corr score: 0.1661
# ---181 MSE score: 0.4861; ---181 Corr score: 0.1660
# +++122 MSE score: 0.4861; +++122 Corr score: 0.1659
# ---10 MSE score: 0.4861; ---10 Corr score: 0.1660
# +++53 MSE score: 0.4860; +++53 Corr score: 0.1660
# ---127 MSE score: 0.4860; ---127 Corr score: 0.1661
# SUCCESSFULL REMOVE OF increased_ask_counts_3_volume. Len: 125
# +++99 MSE score: 0.4860; +++99 Corr score: 0.1662
# SUCCESSFULL ADDING OF bid_flatten_std_50. Len: 126
# Last added cols: ['wap0_40_max', 'flatten_spread_50_mean', 'increased_ask_counts_20_volume', 'mid_price_max_diff_20', 'bid_flatten_std_50']
# ---30 MSE score: 0.4861; ---30 Corr score: 0.1658
# +++11 MSE score: 0.4861; +++11 Corr score: 0.1655
# ---154 MSE score: 0.4860; ---154 Corr score: 0.1662
# +++156 MSE score: 0.4860; +++156 Corr score: 0.1661
# ---21 MSE score: 0.4861; ---21 Corr score: 0.1660
# +++23 MSE score: 0.4861; +++23 Corr score: 0.1659
# ---155 MSE score: 0.4860; ---155 Corr score: 0.1661
# +++130 MSE score: 0.4861; +++130 Corr score: 0.1656
# ---1 MSE score: 0.4860; ---1 Corr score: 0.1661
# +++196 MSE score: 0.4861; +++196 Corr score: 0.1659
# ---159 MSE score: 0.4860; ---159 Corr score: 0.1662
# SUCCESSFULL REMOVE OF mid_price_min_diff_10. Len: 125
# +++156 MSE score: 0.4860; +++156 Corr score: 0.1661
# ---125 MSE score: 0.4861; ---125 Corr score: 0.1659
# +++110 MSE score: 0.4861; +++110 Corr score: 0.1660
# ---99 MSE score: 0.4860; ---99 Corr score: 0.1661
# +++22 MSE score: 0.4860; +++22 Corr score: 0.1662
# ---81 MSE score: 0.4862; ---81 Corr score: 0.1651
# +++86 MSE score: 0.4860; +++86 Corr score: 0.1663
# SUCCESSFULL ADDING OF flatten_spread_25_ewm. Len: 126
# Last added cols: ['flatten_spread_50_mean', 'increased_ask_counts_20_volume', 'mid_price_max_diff_20', 'bid_flatten_std_50', 'flatten_spread_25_ewm']
# ---136 MSE score: 0.4860; ---136 Corr score: 0.1663
# +++192 MSE score: 0.4860; +++192 Corr score: 0.1664
# SUCCESSFULL ADDING OF wap0_20_max. Len: 127
# Last added cols: ['increased_ask_counts_20_volume', 'mid_price_max_diff_20', 'bid_flatten_std_50', 'flatten_spread_25_ewm', 'wap0_20_max']
# ---60 MSE score: 0.4860; ---60 Corr score: 0.1664
# SUCCESSFULL REMOVE OF bid_flatten_ewm_5. Len: 126
# +++122 MSE score: 0.4860; +++122 Corr score: 0.1661
# ---202 MSE score: 0.4860; ---202 Corr score: 0.1662
# +++11 MSE score: 0.4861; +++11 Corr score: 0.1657
# ---1 MSE score: 0.4860; ---1 Corr score: 0.1664
# +++13 MSE score: 0.4860; +++13 Corr score: 0.1664
# ---93 MSE score: 0.4860; ---93 Corr score: 0.1664
# +++11 MSE score: 0.4861; +++11 Corr score: 0.1657
# ---93 MSE score: 0.4860; ---93 Corr score: 0.1664
# +++210 MSE score: 0.4860; +++210 Corr score: 0.1662
# ---112 MSE score: 0.4861; ---112 Corr score: 0.1661
# +++40 MSE score: 0.4860; +++40 Corr score: 0.1664
# ---158 MSE score: 0.4860; ---158 Corr score: 0.1663
# +++110 MSE score: 0.4860; +++110 Corr score: 0.1662
# ---57 MSE score: 0.4860; ---57 Corr score: 0.1662
# +++180 MSE score: 0.4860; +++180 Corr score: 0.1664
# SUCCESSFULL ADDING OF wap0_10_max. Len: 127
# Last added cols: ['mid_price_max_diff_20', 'bid_flatten_std_50', 'flatten_spread_25_ewm', 'wap0_20_max', 'wap0_10_max']
# ---111 MSE score: 0.4860; ---111 Corr score: 0.1661
# +++223 MSE score: 0.4860; +++223 Corr score: 0.1664
# SUCCESSFULL ADDING OF volume_imbalance_80_skew. Len: 128
# Last added cols: ['bid_flatten_std_50', 'flatten_spread_25_ewm', 'wap0_20_max', 'wap0_10_max', 'volume_imbalance_80_skew']
# ---21 MSE score: 0.4860; ---21 Corr score: 0.1662
# +++216 MSE score: 0.4860; +++216 Corr score: 0.1663
# ---84 MSE score: 0.4860; ---84 Corr score: 0.1664
# +++36 MSE score: 0.4860; +++36 Corr score: 0.1663
# ---129 MSE score: 0.4861; ---129 Corr score: 0.1660
# +++189 MSE score: 0.4860; +++189 Corr score: 0.1662
# ---153 MSE score: 0.4860; ---153 Corr score: 0.1664
# +++159 MSE score: 0.4860; +++159 Corr score: 0.1664
# ---68 MSE score: 0.4860; ---68 Corr score: 0.1664
# +++198 MSE score: 0.4860; +++198 Corr score: 0.1663
# ---139 MSE score: 0.4860; ---139 Corr score: 0.1663
# +++195 MSE score: 0.4860; +++195 Corr score: 0.1664
# ---221 MSE score: 0.4860; ---221 Corr score: 0.1664
# +++130 MSE score: 0.4861; +++130 Corr score: 0.1659
# ---45 MSE score: 0.4860; ---45 Corr score: 0.1664
# SUCCESSFULL REMOVE OF decreased_ask_counts. Len: 127
# +++61 MSE score: 0.4860; +++61 Corr score: 0.1664
# ---158 MSE score: 0.4860; ---158 Corr score: 0.1664
# +++151 MSE score: 0.4860; +++151 Corr score: 0.1663
# ---86 MSE score: 0.4860; ---86 Corr score: 0.1663
# +++102 MSE score: 0.4860; +++102 Corr score: 0.1662
# ---51 MSE score: 0.4860; ---51 Corr score: 0.1663
# +++36 MSE score: 0.4860; +++36 Corr score: 0.1663
# ---81 MSE score: 0.4862; ---81 Corr score: 0.1652
# +++162 MSE score: 0.4860; +++162 Corr score: 0.1664
# ---158 MSE score: 0.4860; ---158 Corr score: 0.1664
# +++173 MSE score: 0.4859; +++173 Corr score: 0.1670
# SUCCESSFULL ADDING OF mid_price_max_diff_80. Len: 128
# Last added cols: ['flatten_spread_25_ewm', 'wap0_20_max', 'wap0_10_max', 'volume_imbalance_80_skew', 'mid_price_max_diff_80']
# ---15 MSE score: 0.4862; ---15 Corr score: 0.1654
# +++203 MSE score: 0.4859; +++203 Corr score: 0.1670
# ---0 MSE score: 0.4859; ---0 Corr score: 0.1670
# +++22 MSE score: 0.4859; +++22 Corr score: 0.1670
# ---155 MSE score: 0.4859; ---155 Corr score: 0.1670
# +++159 MSE score: 0.4859; +++159 Corr score: 0.1670
# ---18 MSE score: 0.4860; ---18 Corr score: 0.1664
# +++194 MSE score: 0.4860; +++194 Corr score: 0.1667
# ---14 MSE score: 0.4859; ---14 Corr score: 0.1669
# +++80 MSE score: 0.4859; +++80 Corr score: 0.1670
# SUCCESSFULL ADDING OF bid_flatten_mean_25. Len: 129
# Last added cols: ['wap0_20_max', 'wap0_10_max', 'volume_imbalance_80_skew', 'mid_price_max_diff_80', 'bid_flatten_mean_25']
# ---57 MSE score: 0.4859; ---57 Corr score: 0.1669
# +++12 MSE score: 0.4860; +++12 Corr score: 0.1664
# ---75 MSE score: 0.4859; ---75 Corr score: 0.1670
# +++64 MSE score: 0.4860; +++64 Corr score: 0.1665
# ---131 MSE score: 0.4859; ---131 Corr score: 0.1670
# +++27 MSE score: 0.4859; +++27 Corr score: 0.1670
# ---57 MSE score: 0.4859; ---57 Corr score: 0.1669
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/sneddy/projects/xtx/notebooks/select_features_from_pool.ipynb Cell 11' in <cell line: 1>()
#       <a href='vscode-notebook-cell:/Users/sneddy/projects/xtx/notebooks/select_features_from_pool.ipynb#ch0000013?line=7'>8</a>     use_cols = best_usecols + [adding_col]
#       <a href='vscode-notebook-cell:/Users/sneddy/projects/xtx/notebooks/select_features_from_pool.ipynb#ch0000013?line=8'>9</a>     prefix = f'+++{adding_col}'
# ---> <a href='vscode-notebook-cell:/Users/sneddy/projects/xtx/notebooks/select_features_from_pool.ipynb#ch0000013?line=9'>10</a> current_mse, current_corr = score_cols(fold_processor, usecols=use_cols, prefix=prefix)
#      <a href='vscode-notebook-cell:/Users/sneddy/projects/xtx/notebooks/select_features_from_pool.ipynb#ch0000013?line=10'>11</a> if current_mse < best_mse:
#      <a href='vscode-notebook-cell:/Users/sneddy/projects/xtx/notebooks/select_features_from_pool.ipynb#ch0000013?line=11'>12</a>     best_usecols = use_cols
#
# /Users/sneddy/projects/xtx/notebooks/select_features_from_pool.ipynb Cell 8' in score_cols(fold_processor, usecols, fold_id, prefix)
#       <a href='vscode-notebook-cell:/Users/sneddy/projects/xtx/notebooks/select_features_from_pool.ipynb#ch0000017?line=1'>2</a> def score_cols(fold_processor, usecols, fold_id=0, prefix=None):
#       <a href='vscode-notebook-cell:/Users/sneddy/projects/xtx/notebooks/select_features_from_pool.ipynb#ch0000017?line=2'>3</a>     model = runner.init_model()
# ----> <a href='vscode-notebook-cell:/Users/sneddy/projects/xtx/notebooks/select_features_from_pool.ipynb#ch0000017?line=3'>4</a>     model.fit(fold_processor.train_data[:, usecols], fold_processor.train_target)
#       <a href='vscode-notebook-cell:/Users/sneddy/projects/xtx/notebooks/select_features_from_pool.ipynb#ch0000017?line=4'>5</a>     val_predicted = model.predict(fold_processor.valid_data[:, usecols])
#       <a href='vscode-notebook-cell:/Users/sneddy/projects/xtx/notebooks/select_features_from_pool.ipynb#ch0000017?line=5'>6</a>     return get_mse_and_corr_scores(fold_processor.valid_target, val_predicted, verbose=True, prefix=prefix)
#
# KeyboardInterrupt:

# %%
best_usenames = train_features.columns[best_usecols]
with open('usecols/usecols_fold_0.txt', 'w') as f:
    f.writelines('\n'.join(best_usenames))

# %%
best_usenames
# Out:
# Index(['ask_rate_0', 'bid_rate_0', 'mid_price', 'spread', 'bid_ask_spread',
#        'bid_size_0', 'bid_len', 'len_ratio', 'cum_volume_imbalance_1',
#        'volume_imbalance_1',
#        ...
#        'wap1_40_max', 'len_ratio_40_mean', 'wap0_80_mean', 'wap0_80_std',
#        'wap1_80_std', 'volume_imbalance_80_max', 'volume_imbalance_80_skew',
#        'len_ratio_80_mean', 'wap0_ewm_80', 'volume_imbalance_ewm_80'],
#       dtype='object', length=129)

# %%
time_folds_prod = TimeFolds(**experiment['TimeFolds'])
print(experiment['TimeFolds'])
time_folds_prod.fit(train_features.loc[:, best_usenames], target)
# Out:
# {'n_folds': 5, 'minifold_size': 60000, 'neutral_ratio': 0.025, 'test_ratio': 0.2, 'train_test_gap': 2000}

# %%
model_zoo = dev_utils.load_yaml(experiment['model_zoo'])
model_config = model_zoo['train_zoo']['default_ridge']
model_config10 = model_zoo['selection_ridge']
print(model_config)
runner = CrossValRunner(time_folds_prod, **model_config)
runner.fit(verbose=True)
# Out:
# {'model_module': 'sklearn.linear_model', 'model_cls': 'Ridge', 'model_params': {'alpha': 100}}
# Ridge:   0%|          | 0/5 [00:00<?, ?it/s]
# |    | dataset   | metric_name   |   fold_0 |   fold_1 |   fold_2 |   fold_3 |   fold_4 |
# |---:|:----------|:--------------|---------:|---------:|---------:|---------:|---------:|
# |  0 | val       | mse           |    0.486 |    0.467 |    0.452 |    0.567 |    0.526 |
# |  1 | val       | corr          |    0.167 |    0.164 |    0.154 |    0.149 |    0.145 |
# |  2 | test      | mse           |    0.331 |    0.332 |    0.331 |    0.331 |    0.331 |
# |  3 | test      | corr          |    0.155 |    0.152 |    0.151 |    0.156 |    0.155 |
#              	Val  corr score averaged: 0.156
#             	Val   MSE score averaged: 0.500
#
#              	Test corr score averaged: 0.154
#             	Test  MSE score averaged: 0.331
#             ------------------------------------------------------------------
#             	Test  MSE predicts averaged: 0.331
#             	Test corr predicts averaged: 0.156

# %% [markdown]
# # Fold 1

# %%
time_folds = TimeFolds(**experiment['TimeFolds'])
print(experiment['TimeFolds'])
time_folds.fit(train_features, target)

fold_id = 1
runner = CrossValRunner(time_folds, **model_config)
fold_processor = runner.preprocessor.prepare_fold(fold_id)

# %%
model_config10 = model_config
model_config10['model_params']['alpha'] = 10

# %%
runner = CrossValRunner(time_folds, **model_config10)
fold_processor = runner.preprocessor.prepare_fold(fold_id)

# %%
n_features = train_features.shape[1]
colname2idx = {name: idx for idx, name in enumerate(train_features.columns)}

dev_utils.init_seed(42 + fold_id)
# best_usecols = np.random.choice(n_features, n_features // 2, replace=False)
best_mse, best_corr = score_cols(fold_processor, usecols=best_usecols)
# Out:
#  MSE score: 0.4656;  Corr score: 0.1731

# %%
for current_iter in range(100000):
    if current_iter % 2 == 0:
        removing_col = np.random.choice(best_usecols)
        use_cols = [col for col in best_usecols if col != removing_col]
        prefix = f'---{removing_col}'
    else:
        adding_col = np.random.choice([idx for idx in range(n_features) if idx not in best_usecols])
        use_cols = best_usecols + [adding_col]
        prefix = f'+++{adding_col}'
    current_mse, current_corr = score_cols(fold_processor, usecols=use_cols, prefix=prefix)
    if current_mse < best_mse:
        best_usecols = use_cols
        best_mse, best_corr = current_mse, current_corr
        if current_iter % 2 == 0:
            print(f'SUCCESSFULL REMOVE OF {train_features.columns[removing_col]}. Len: {len(use_cols)}')
        else:
            print(f'SUCCESSFULL ADDING OF {train_features.columns[adding_col]}. Len: {len(use_cols)}')
            print(f'Last added cols: {[train_features.columns[col] for col in best_usecols[-5:]]}')
# Out:
# ---198 MSE score: 0.4656; ---198 Corr score: 0.1732
# SUCCESSFULL REMOVE OF volume_imbalance_20_std. Len: 125
# +++162 MSE score: 0.4656; +++162 Corr score: 0.1732
# ---56 MSE score: 0.4656; ---56 Corr score: 0.1731
# +++53 MSE score: 0.4656; +++53 Corr score: 0.1731
# ---182 MSE score: 0.4656; ---182 Corr score: 0.1732
# SUCCESSFULL REMOVE OF wap1_10_std. Len: 124
# +++40 MSE score: 0.4656; +++40 Corr score: 0.1732
# ---208 MSE score: 0.4654; ---208 Corr score: 0.1739
# SUCCESSFULL REMOVE OF volume_imbalance_40_mean. Len: 123
# +++47 MSE score: 0.4655; +++47 Corr score: 0.1738
# ---98 MSE score: 0.4654; ---98 Corr score: 0.1739
# SUCCESSFULL REMOVE OF bid_flatten_mean_50. Len: 122
# +++202 MSE score: 0.4654; +++202 Corr score: 0.1741
# SUCCESSFULL ADDING OF wap0_40_mean. Len: 123
# Last added cols: ['ask_flatten_len_25', 'ask_len', 'mid_price_std_10', 'len_ratio_10_mean', 'wap0_40_mean']
# ---50 MSE score: 0.4657; ---50 Corr score: 0.1726
# +++74 MSE score: 0.4654; +++74 Corr score: 0.1739
# ---106 MSE score: 0.4654; ---106 Corr score: 0.1742
# SUCCESSFULL REMOVE OF ewm_wap_flatten_50. Len: 122
# +++155 MSE score: 0.4654; +++155 Corr score: 0.1742
# ---139 MSE score: 0.4654; ---139 Corr score: 0.1742
# SUCCESSFULL REMOVE OF volume_imbalance_diff_10. Len: 121
# +++121 MSE score: 0.4655; +++121 Corr score: 0.1735
# ---128 MSE score: 0.4654; ---128 Corr score: 0.1742
# SUCCESSFULL REMOVE OF decreased_ask_counts_3_volume. Len: 120
# +++194 MSE score: 0.4654; +++194 Corr score: 0.1741
# ---50 MSE score: 0.4656; ---50 Corr score: 0.1727
# +++85 MSE score: 0.4654; +++85 Corr score: 0.1741
# ---140 MSE score: 0.4654; ---140 Corr score: 0.1742
# +++155 MSE score: 0.4654; +++155 Corr score: 0.1742
# ---84 MSE score: 0.4654; ---84 Corr score: 0.1739
# +++16 MSE score: 0.4654; +++16 Corr score: 0.1742
# SUCCESSFULL ADDING OF wap1. Len: 121
# Last added cols: ['ask_len', 'mid_price_std_10', 'len_ratio_10_mean', 'wap0_40_mean', 'wap1']
# ---62 MSE score: 0.4654; ---62 Corr score: 0.1741
# +++177 MSE score: 0.4655; +++177 Corr score: 0.1738
# ---64 MSE score: 0.4654; ---64 Corr score: 0.1742
# +++118 MSE score: 0.4653; +++118 Corr score: 0.1750
# SUCCESSFULL ADDING OF bid_flatten_iqr_100. Len: 122
# Last added cols: ['mid_price_std_10', 'len_ratio_10_mean', 'wap0_40_mean', 'wap1', 'bid_flatten_iqr_100']
# ---147 MSE score: 0.4653; ---147 Corr score: 0.1749
# +++176 MSE score: 0.4653; +++176 Corr score: 0.1748
# ---138 MSE score: 0.4653; ---138 Corr score: 0.1749
# +++175 MSE score: 0.4653; +++175 Corr score: 0.1750
# ---148 MSE score: 0.4653; ---148 Corr score: 0.1749
# +++121 MSE score: 0.4654; +++121 Corr score: 0.1742
# ---12 MSE score: 0.4653; ---12 Corr score: 0.1750
# SUCCESSFULL REMOVE OF volume_imbalance_0. Len: 121
# +++165 MSE score: 0.4653; +++165 Corr score: 0.1750
# ---118 MSE score: 0.4654; ---118 Corr score: 0.1742
# +++70 MSE score: 0.4653; +++70 Corr score: 0.1750
# ---166 MSE score: 0.4652; ---166 Corr score: 0.1751
# SUCCESSFULL REMOVE OF spread_rolling_mean_20. Len: 120
# +++23 MSE score: 0.4652; +++23 Corr score: 0.1751
# ---122 MSE score: 0.4653; ---122 Corr score: 0.1746
# +++184 MSE score: 0.4652; +++184 Corr score: 0.1751
# ---90 MSE score: 0.4654; ---90 Corr score: 0.1739
# +++220 MSE score: 0.4654; +++220 Corr score: 0.1744
# ---102 MSE score: 0.4652; ---102 Corr score: 0.1751
# +++82 MSE score: 0.4652; +++82 Corr score: 0.1752
# SUCCESSFULL ADDING OF bid_flatten_iqr_25. Len: 121
# Last added cols: ['len_ratio_10_mean', 'wap0_40_mean', 'wap1', 'bid_flatten_iqr_100', 'bid_flatten_iqr_25']
# ---200 MSE score: 0.4652; ---200 Corr score: 0.1752
# +++86 MSE score: 0.4652; +++86 Corr score: 0.1751
# ---115 MSE score: 0.4653; ---115 Corr score: 0.1749
# +++227 MSE score: 0.4654; +++227 Corr score: 0.1743
# ---0 MSE score: 0.4652; ---0 Corr score: 0.1753
# SUCCESSFULL REMOVE OF ask_rate_0. Len: 120
# +++70 MSE score: 0.4652; +++70 Corr score: 0.1753
# ---72 MSE score: 0.4652; ---72 Corr score: 0.1753
# +++66 MSE score: 0.4652; +++66 Corr score: 0.1753
# ---46 MSE score: 0.4652; ---46 Corr score: 0.1751
# +++187 MSE score: 0.4652; +++187 Corr score: 0.1753
# SUCCESSFULL ADDING OF volume_imbalance_10_skew. Len: 121
# Last added cols: ['wap0_40_mean', 'wap1', 'bid_flatten_iqr_100', 'bid_flatten_iqr_25', 'volume_imbalance_10_skew']
# ---57 MSE score: 0.4652; ---57 Corr score: 0.1754
# SUCCESSFULL REMOVE OF ask_flatten_iqr_5. Len: 120
# +++220 MSE score: 0.4653; +++220 Corr score: 0.1746
# ---167 MSE score: 0.4652; ---167 Corr score: 0.1753
# +++66 MSE score: 0.4652; +++66 Corr score: 0.1754
# SUCCESSFULL ADDING OF bid_flatten_kurtosis_5. Len: 121
# Last added cols: ['wap1', 'bid_flatten_iqr_100', 'bid_flatten_iqr_25', 'volume_imbalance_10_skew', 'bid_flatten_kurtosis_5']
# ---30 MSE score: 0.4652; ---30 Corr score: 0.1755
# SUCCESSFULL REMOVE OF volume_imbalance_6. Len: 120
# +++21 MSE score: 0.4653; +++21 Corr score: 0.1746
# ---159 MSE score: 0.4652; ---159 Corr score: 0.1755
# +++145 MSE score: 0.4652; +++145 Corr score: 0.1752
# ---36 MSE score: 0.4652; ---36 Corr score: 0.1754
# +++124 MSE score: 0.4653; +++124 Corr score: 0.1746
# ---62 MSE score: 0.4652; ---62 Corr score: 0.1754
# +++106 MSE score: 0.4652; +++106 Corr score: 0.1754
# ---123 MSE score: 0.4651; ---123 Corr score: 0.1757
# SUCCESSFULL REMOVE OF wap_flatten_100. Len: 119
# +++124 MSE score: 0.4653; +++124 Corr score: 0.1746
# ---161 MSE score: 0.4651; ---161 Corr score: 0.1758
# SUCCESSFULL REMOVE OF spread_rolling_mean_10. Len: 118
# +++53 MSE score: 0.4651; +++53 Corr score: 0.1757
# ---200 MSE score: 0.4651; ---200 Corr score: 0.1758
# +++162 MSE score: 0.4651; +++162 Corr score: 0.1757
# ---38 MSE score: 0.4651; ---38 Corr score: 0.1757
# +++123 MSE score: 0.4652; +++123 Corr score: 0.1756
# ---205 MSE score: 0.4650; ---205 Corr score: 0.1767
# SUCCESSFULL REMOVE OF wap1_40_mean. Len: 117
# +++100 MSE score: 0.4650; +++100 Corr score: 0.1764
# ---7 MSE score: 0.4650; ---7 Corr score: 0.1767
# SUCCESSFULL REMOVE OF bid_size_0. Len: 116
# +++85 MSE score: 0.4650; +++85 Corr score: 0.1766
# ---127 MSE score: 0.4650; ---127 Corr score: 0.1767
# +++30 MSE score: 0.4650; +++30 Corr score: 0.1766
# ---13 MSE score: 0.4650; ---13 Corr score: 0.1767
# +++181 MSE score: 0.4650; +++181 Corr score: 0.1766
# ---66 MSE score: 0.4650; ---66 Corr score: 0.1767
# +++89 MSE score: 0.4650; +++89 Corr score: 0.1768
# SUCCESSFULL ADDING OF ask_flatten_ewm_50. Len: 117
# Last added cols: ['bid_flatten_iqr_100', 'bid_flatten_iqr_25', 'volume_imbalance_10_skew', 'bid_flatten_kurtosis_5', 'ask_flatten_ewm_50']
# ---13 MSE score: 0.4650; ---13 Corr score: 0.1768
# +++182 MSE score: 0.4650; +++182 Corr score: 0.1765
# ---174 MSE score: 0.4650; ---174 Corr score: 0.1763
# +++98 MSE score: 0.4650; +++98 Corr score: 0.1767
# ---102 MSE score: 0.4650; ---102 Corr score: 0.1768
# +++162 MSE score: 0.4650; +++162 Corr score: 0.1767
# ---130 MSE score: 0.4649; ---130 Corr score: 0.1772
# SUCCESSFULL REMOVE OF decreased_bid_counts_{window}. Len: 116
# +++32 MSE score: 0.4649; +++32 Corr score: 0.1769
# ---188 MSE score: 0.4649; ---188 Corr score: 0.1772
# +++173 MSE score: 0.4650; +++173 Corr score: 0.1767
# ---230 MSE score: 0.4652; ---230 Corr score: 0.1755
# +++212 MSE score: 0.4649; +++212 Corr score: 0.1772
# SUCCESSFULL ADDING OF len_ratio_40_mean. Len: 117
# Last added cols: ['bid_flatten_iqr_25', 'volume_imbalance_10_skew', 'bid_flatten_kurtosis_5', 'ask_flatten_ewm_50', 'len_ratio_40_mean']
# ---199 MSE score: 0.4649; ---199 Corr score: 0.1772
# SUCCESSFULL REMOVE OF volume_imbalance_20_skew. Len: 116
# +++139 MSE score: 0.4649; +++139 Corr score: 0.1771
# ---226 MSE score: 0.4649; ---226 Corr score: 0.1772
# +++177 MSE score: 0.4650; +++177 Corr score: 0.1767
# ---212 MSE score: 0.4649; ---212 Corr score: 0.1772
# +++74 MSE score: 0.4649; +++74 Corr score: 0.1769
# ---15 MSE score: 0.4656; ---15 Corr score: 0.1727
# +++29 MSE score: 0.4649; +++29 Corr score: 0.1771
# ---10 MSE score: 0.4649; ---10 Corr score: 0.1771
# +++146 MSE score: 0.4649; +++146 Corr score: 0.1771
# ---209 MSE score: 0.4649; ---209 Corr score: 0.1770
# +++128 MSE score: 0.4649; +++128 Corr score: 0.1772
# ---111 MSE score: 0.4651; ---111 Corr score: 0.1762
# +++7 MSE score: 0.4649; +++7 Corr score: 0.1772
# ---22 MSE score: 0.4649; ---22 Corr score: 0.1772
# +++161 MSE score: 0.4649; +++161 Corr score: 0.1771
# ---202 MSE score: 0.4649; ---202 Corr score: 0.1769
# +++99 MSE score: 0.4649; +++99 Corr score: 0.1773
# SUCCESSFULL ADDING OF bid_flatten_std_50. Len: 117
# Last added cols: ['volume_imbalance_10_skew', 'bid_flatten_kurtosis_5', 'ask_flatten_ewm_50', 'len_ratio_40_mean', 'bid_flatten_std_50']
# ---112 MSE score: 0.4649; ---112 Corr score: 0.1769
# +++57 MSE score: 0.4649; +++57 Corr score: 0.1772
# ---58 MSE score: 0.4649; ---58 Corr score: 0.1771
# +++182 MSE score: 0.4649; +++182 Corr score: 0.1771
# ---211 MSE score: 0.4649; ---211 Corr score: 0.1773
# SUCCESSFULL REMOVE OF volume_imbalance_40_skew. Len: 116
# +++206 MSE score: 0.4651; +++206 Corr score: 0.1758
# ---109 MSE score: 0.4649; ---109 Corr score: 0.1770
# +++51 MSE score: 0.4649; +++51 Corr score: 0.1773
# ---96 MSE score: 0.4648; ---96 Corr score: 0.1775
# SUCCESSFULL REMOVE OF bid_flatten_ewm_50. Len: 115
# +++193 MSE score: 0.4649; +++193 Corr score: 0.1774
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/sneddy/projects/xtx/notebooks/select_features_from_pool.ipynb Cell 20' in <cell line: 1>()
#       <a href='vscode-notebook-cell:/Users/sneddy/projects/xtx/notebooks/select_features_from_pool.ipynb#ch0000027?line=7'>8</a>     use_cols = best_usecols + [adding_col]
#       <a href='vscode-notebook-cell:/Users/sneddy/projects/xtx/notebooks/select_features_from_pool.ipynb#ch0000027?line=8'>9</a>     prefix = f'+++{adding_col}'
# ---> <a href='vscode-notebook-cell:/Users/sneddy/projects/xtx/notebooks/select_features_from_pool.ipynb#ch0000027?line=9'>10</a> current_mse, current_corr = score_cols(fold_processor, usecols=use_cols, prefix=prefix)
#      <a href='vscode-notebook-cell:/Users/sneddy/projects/xtx/notebooks/select_features_from_pool.ipynb#ch0000027?line=10'>11</a> if current_mse < best_mse:
#      <a href='vscode-notebook-cell:/Users/sneddy/projects/xtx/notebooks/select_features_from_pool.ipynb#ch0000027?line=11'>12</a>     best_usecols = use_cols
#
# /Users/sneddy/projects/xtx/notebooks/select_features_from_pool.ipynb Cell 8' in score_cols(fold_processor, usecols, fold_id, prefix)
#       <a href='vscode-notebook-cell:/Users/sneddy/projects/xtx/notebooks/select_features_from_pool.ipynb#ch0000017?line=1'>2</a> def score_cols(fold_processor, usecols, fold_id=0, prefix=None):
#       <a href='vscode-notebook-cell:/Users/sneddy/projects/xtx/notebooks/select_features_from_pool.ipynb#ch0000017?line=2'>3</a>     model = runner.init_model()
# ----> <a href='vscode-notebook-cell:/Users/sneddy/projects/xtx/notebooks/select_features_from_pool.ipynb#ch0000017?line=3'>4</a>     model.fit(fold_processor.train_data[:, usecols], fold_processor.train_target)
#       <a href='vscode-notebook-cell:/Users/sneddy/projects/xtx/notebooks/select_features_from_pool.ipynb#ch0000017?line=4'>5</a>     val_predicted = model.predict(fold_processor.valid_data[:, usecols])
#       <a href='vscode-notebook-cell:/Users/sneddy/projects/xtx/notebooks/select_features_from_pool.ipynb#ch0000017?line=5'>6</a>     return get_mse_and_corr_scores(fold_processor.valid_target, val_predicted, verbose=True, prefix=prefix)
#
# File ~/Library/Python/3.8/lib/python/site-packages/sklearn/linear_model/_ridge.py:1011, in Ridge.fit(self, X, y, sample_weight)
#    <a href='file:///Users/sneddy/Library/Python/3.8/lib/python/site-packages/sklearn/linear_model/_ridge.py?line=1001'>1002</a> _accept_sparse = _get_valid_accept_sparse(sparse.issparse(X), self.solver)
#    <a href='file:///Users/sneddy/Library/Python/3.8/lib/python/site-packages/sklearn/linear_model/_ridge.py?line=1002'>1003</a> X, y = self._validate_data(
#    <a href='file:///Users/sneddy/Library/Python/3.8/lib/python/site-packages/sklearn/linear_model/_ridge.py?line=1003'>1004</a>     X,
#    <a href='file:///Users/sneddy/Library/Python/3.8/lib/python/site-packages/sklearn/linear_model/_ridge.py?line=1004'>1005</a>     y,
#    (...)
#    <a href='file:///Users/sneddy/Library/Python/3.8/lib/python/site-packages/sklearn/linear_model/_ridge.py?line=1008'>1009</a>     y_numeric=True,
#    <a href='file:///Users/sneddy/Library/Python/3.8/lib/python/site-packages/sklearn/linear_model/_ridge.py?line=1009'>1010</a> )
# -> <a href='file:///Users/sneddy/Library/Python/3.8/lib/python/site-packages/sklearn/linear_model/_ridge.py?line=1010'>1011</a> return super().fit(X, y, sample_weight=sample_weight)
#
# File ~/Library/Python/3.8/lib/python/site-packages/sklearn/linear_model/_ridge.py:782, in _BaseRidge.fit(self, X, y, sample_weight)
#     <a href='file:///Users/sneddy/Library/Python/3.8/lib/python/site-packages/sklearn/linear_model/_ridge.py?line=777'>778</a>     else:
#     <a href='file:///Users/sneddy/Library/Python/3.8/lib/python/site-packages/sklearn/linear_model/_ridge.py?line=778'>779</a>         # for dense matrices or when intercept is set to 0
#     <a href='file:///Users/sneddy/Library/Python/3.8/lib/python/site-packages/sklearn/linear_model/_ridge.py?line=779'>780</a>         params = {}
# --> <a href='file:///Users/sneddy/Library/Python/3.8/lib/python/site-packages/sklearn/linear_model/_ridge.py?line=781'>782</a>     self.coef_, self.n_iter_ = _ridge_regression(
#     <a href='file:///Users/sneddy/Library/Python/3.8/lib/python/site-packages/sklearn/linear_model/_ridge.py?line=782'>783</a>         X,
#     <a href='file:///Users/sneddy/Library/Python/3.8/lib/python/site-packages/sklearn/linear_model/_ridge.py?line=783'>784</a>         y,
#     <a href='file:///Users/sneddy/Library/Python/3.8/lib/python/site-packages/sklearn/linear_model/_ridge.py?line=784'>785</a>         alpha=self.alpha,
#     <a href='file:///Users/sneddy/Library/Python/3.8/lib/python/site-packages/sklearn/linear_model/_ridge.py?line=785'>786</a>         sample_weight=sample_weight,
#     <a href='file:///Users/sneddy/Library/Python/3.8/lib/python/site-packages/sklearn/linear_model/_ridge.py?line=786'>787</a>         max_iter=self.max_iter,
#     <a href='file:///Users/sneddy/Library/Python/3.8/lib/python/site-packages/sklearn/linear_model/_ridge.py?line=787'>788</a>         tol=self.tol,
#     <a href='file:///Users/sneddy/Library/Python/3.8/lib/python/site-packages/sklearn/linear_model/_ridge.py?line=788'>789</a>         solver=solver,
#     <a href='file:///Users/sneddy/Library/Python/3.8/lib/python/site-packages/sklearn/linear_model/_ridge.py?line=789'>790</a>         positive=self.positive,
#     <a href='file:///Users/sneddy/Library/Python/3.8/lib/python/site-packages/sklearn/linear_model/_ridge.py?line=790'>791</a>         random_state=self.random_state,
#     <a href='file:///Users/sneddy/Library/Python/3.8/lib/python/site-packages/sklearn/linear_model/_ridge.py?line=791'>792</a>         return_n_iter=True,
#     <a href='file:///Users/sneddy/Library/Python/3.8/lib/python/site-packages/sklearn/linear_model/_ridge.py?line=792'>793</a>         return_intercept=False,
#     <a href='file:///Users/sneddy/Library/Python/3.8/lib/python/site-packages/sklearn/linear_model/_ridge.py?line=793'>794</a>         check_input=False,
#     <a href='file:///Users/sneddy/Library/Python/3.8/lib/python/site-packages/sklearn/linear_model/_ridge.py?line=794'>795</a>         **params,
#     <a href='file:///Users/sneddy/Library/Python/3.8/lib/python/site-packages/sklearn/linear_model/_ridge.py?line=795'>796</a>     )
#     <a href='file:///Users/sneddy/Library/Python/3.8/lib/python/site-packages/sklearn/linear_model/_ridge.py?line=796'>797</a>     self._set_intercept(X_offset, y_offset, X_scale)
#     <a href='file:///Users/sneddy/Library/Python/3.8/lib/python/site-packages/sklearn/linear_model/_ridge.py?line=798'>799</a> return self
#
# File ~/Library/Python/3.8/lib/python/site-packages/sklearn/linear_model/_ridge.py:599, in _ridge_regression(X, y, alpha, sample_weight, solver, max_iter, tol, verbose, positive, random_state, return_n_iter, return_intercept, X_scale, X_offset, check_input)
#     <a href='file:///Users/sneddy/Library/Python/3.8/lib/python/site-packages/sklearn/linear_model/_ridge.py?line=596'>597</a> else:
#     <a href='file:///Users/sneddy/Library/Python/3.8/lib/python/site-packages/sklearn/linear_model/_ridge.py?line=597'>598</a>     try:
# --> <a href='file:///Users/sneddy/Library/Python/3.8/lib/python/site-packages/sklearn/linear_model/_ridge.py?line=598'>599</a>         coef = _solve_cholesky(X, y, alpha)
#     <a href='file:///Users/sneddy/Library/Python/3.8/lib/python/site-packages/sklearn/linear_model/_ridge.py?line=599'>600</a>     except linalg.LinAlgError:
#     <a href='file:///Users/sneddy/Library/Python/3.8/lib/python/site-packages/sklearn/linear_model/_ridge.py?line=600'>601</a>         # use SVD solver if matrix is singular
#     <a href='file:///Users/sneddy/Library/Python/3.8/lib/python/site-packages/sklearn/linear_model/_ridge.py?line=601'>602</a>         solver = "svd"
#
# File ~/Library/Python/3.8/lib/python/site-packages/sklearn/linear_model/_ridge.py:150, in _solve_cholesky(X, y, alpha)
#     <a href='file:///Users/sneddy/Library/Python/3.8/lib/python/site-packages/sklearn/linear_model/_ridge.py?line=146'>147</a> n_features = X.shape[1]
#     <a href='file:///Users/sneddy/Library/Python/3.8/lib/python/site-packages/sklearn/linear_model/_ridge.py?line=147'>148</a> n_targets = y.shape[1]
# --> <a href='file:///Users/sneddy/Library/Python/3.8/lib/python/site-packages/sklearn/linear_model/_ridge.py?line=149'>150</a> A = safe_sparse_dot(X.T, X, dense_output=True)
#     <a href='file:///Users/sneddy/Library/Python/3.8/lib/python/site-packages/sklearn/linear_model/_ridge.py?line=150'>151</a> Xy = safe_sparse_dot(X.T, y, dense_output=True)
#     <a href='file:///Users/sneddy/Library/Python/3.8/lib/python/site-packages/sklearn/linear_model/_ridge.py?line=152'>153</a> one_alpha = np.array_equal(alpha, len(alpha) * [alpha[0]])
#
# File ~/Library/Python/3.8/lib/python/site-packages/sklearn/utils/extmath.py:153, in safe_sparse_dot(a, b, dense_output)
#     <a href='file:///Users/sneddy/Library/Python/3.8/lib/python/site-packages/sklearn/utils/extmath.py?line=150'>151</a>         ret = np.dot(a, b)
#     <a href='file:///Users/sneddy/Library/Python/3.8/lib/python/site-packages/sklearn/utils/extmath.py?line=151'>152</a> else:
# --> <a href='file:///Users/sneddy/Library/Python/3.8/lib/python/site-packages/sklearn/utils/extmath.py?line=152'>153</a>     ret = a @ b
#     <a href='file:///Users/sneddy/Library/Python/3.8/lib/python/site-packages/sklearn/utils/extmath.py?line=154'>155</a> if (
#     <a href='file:///Users/sneddy/Library/Python/3.8/lib/python/site-packages/sklearn/utils/extmath.py?line=155'>156</a>     sparse.issparse(a)
#     <a href='file:///Users/sneddy/Library/Python/3.8/lib/python/site-packages/sklearn/utils/extmath.py?line=156'>157</a>     and sparse.issparse(b)
#     <a href='file:///Users/sneddy/Library/Python/3.8/lib/python/site-packages/sklearn/utils/extmath.py?line=157'>158</a>     and dense_output
#     <a href='file:///Users/sneddy/Library/Python/3.8/lib/python/site-packages/sklearn/utils/extmath.py?line=158'>159</a>     and hasattr(ret, "toarray")
#     <a href='file:///Users/sneddy/Library/Python/3.8/lib/python/site-packages/sklearn/utils/extmath.py?line=159'>160</a> ):
#     <a href='file:///Users/sneddy/Library/Python/3.8/lib/python/site-packages/sklearn/utils/extmath.py?line=160'>161</a>     return ret.toarray()
#
# KeyboardInterrupt:

# %%
best_usenames = train_features.columns[best_usecols]
with open(f'usecols/usecols_fold_{fold_id}.txt', 'w') as f:
    f.writelines('\n'.join(best_usenames))

# %%
time_folds_prod = TimeFolds(**experiment['TimeFolds'])
print(experiment['TimeFolds'])
time_folds_prod.fit(train_features.loc[:, best_usenames], target)
# Out:
# {'n_folds': 5, 'minifold_size': 60000, 'neutral_ratio': 0.025, 'test_ratio': 0.2, 'train_test_gap': 2000}

# %%
runner = CrossValRunner(time_folds_prod, **model_config)
runner.fit(verbose=True)
# Out:
# Ridge:   0%|          | 0/5 [00:00<?, ?it/s]
# |    | dataset   | metric_name   |   fold_0 |   fold_1 |   fold_2 |   fold_3 |   fold_4 |
# |---:|:----------|:--------------|---------:|---------:|---------:|---------:|---------:|
# |  0 | val       | mse           |    0.487 |    0.465 |    0.451 |    0.566 |    0.526 |
# |  1 | val       | corr          |    0.159 |    0.177 |    0.16  |    0.154 |    0.145 |
# |  2 | test      | mse           |    0.332 |    0.331 |    0.331 |    0.332 |    0.331 |
# |  3 | test      | corr          |    0.156 |    0.156 |    0.157 |    0.159 |    0.157 |
#              	Val  corr score averaged: 0.159
#             	Val   MSE score averaged: 0.499
#
#              	Test corr score averaged: 0.157
#             	Test  MSE score averaged: 0.331
#             ------------------------------------------------------------------
#             	Test  MSE predicts averaged: 0.331
#             	Test corr predicts averaged: 0.158

# %% [markdown]
# # Fold 2

# %%
time_folds = TimeFolds(**experiment['TimeFolds'])
print(experiment['TimeFolds'])
time_folds.fit(train_features, target)

model_config = model_zoo['selection_ridge']
print(model_config)
fold_id = 2
runner = CrossValRunner(time_folds, **model_config)
fold_processor = runner.preprocessor.prepare_fold(fold_id)
# Out:
# {'n_folds': 5, 'minifold_size': 60000, 'neutral_ratio': 0.025, 'test_ratio': 0.2, 'train_test_gap': 2000}
# {'model_module': 'sklearn.linear_model', 'model_cls': 'Ridge', 'model_params': {'alpha': 10}}

# %%
n_features = train_features.shape[1]
colname2idx = {name: idx for idx, name in enumerate(train_features.columns)}

dev_utils.init_seed(42 + fold_id)
best_usecols = np.random.choice(n_features, n_features // 2, replace=False)
best_mse, best_corr = score_cols(fold_processor, usecols=best_usecols)
# Out:
#  MSE score: 0.4523;  Corr score: 0.1513

# %%
not_improved_iter = 0
for current_iter in range(100000):
    if current_iter % 2 == 0:
        removing_col = np.random.choice(best_usecols)
        use_cols = [col for col in best_usecols if col != removing_col]
        prefix = f'---{removing_col}'
    else:
        adding_col = np.random.choice([idx for idx in range(n_features) if idx not in best_usecols])
        use_cols = best_usecols + [adding_col]
        prefix = f'+++{adding_col}'
    current_mse, current_corr = score_cols(fold_processor, usecols=use_cols, prefix=prefix)
    if current_mse < best_mse:
        best_usecols = use_cols
        best_mse, best_corr = current_mse, current_corr
        not_improved_iter = 0
        if current_iter % 2 == 0:
            print(f'SUCCESSFULL REMOVE OF {train_features.columns[removing_col]}. Len: {len(use_cols)}')
        else:
            print(f'SUCCESSFULL ADDING OF {train_features.columns[adding_col]}. Len: {len(use_cols)}')
            print(f'Last added cols: {[train_features.columns[col] for col in best_usecols[-5:]]}')
    else:
        not_improved_iter += 1
        print(f'Not improved: {not_improved_iter}')
    if not_improved_iter > 20:
        break

best_usenames = train_features.columns[best_usecols]
with open(f'usecols/usecols_fold_{fold_id}.txt', 'w') as f:
    f.writelines('\n'.join(best_usenames))
# Out:
# ---13 MSE score: 0.4514; ---13 Corr score: 0.1574
# Not improved: 1
# +++104 MSE score: 0.4513; +++104 Corr score: 0.1578
# SUCCESSFULL ADDING OF flatten_spread_50_ewm. Len: 119
# Last added cols: ['ask_flatten_mean_5', 'volume_imbalance_20_skew', 'flatten_spread_100_ewm', 'bid_flatten_std_5', 'flatten_spread_50_ewm']
# ---153 MSE score: 0.4513; ---153 Corr score: 0.1578
# SUCCESSFULL REMOVE OF mid_price_max_diff_5. Len: 118
# +++34 MSE score: 0.4513; +++34 Corr score: 0.1577
# Not improved: 1
# ---148 MSE score: 0.4513; ---148 Corr score: 0.1578
# SUCCESSFULL REMOVE OF mid_price_log_40. Len: 117
# +++16 MSE score: 0.4513; +++16 Corr score: 0.1579
# SUCCESSFULL ADDING OF wap1. Len: 118
# Last added cols: ['volume_imbalance_20_skew', 'flatten_spread_100_ewm', 'bid_flatten_std_5', 'flatten_spread_50_ewm', 'wap1']
# ---82 MSE score: 0.4513; ---82 Corr score: 0.1580
# SUCCESSFULL REMOVE OF bid_flatten_iqr_25. Len: 117
# +++216 MSE score: 0.4513; +++216 Corr score: 0.1580
# Not improved: 1
# ---223 MSE score: 0.4512; ---223 Corr score: 0.1584
# SUCCESSFULL REMOVE OF volume_imbalance_80_skew. Len: 116
# +++34 MSE score: 0.4512; +++34 Corr score: 0.1583
# Not improved: 1
# ---138 MSE score: 0.4512; ---138 Corr score: 0.1585
# SUCCESSFULL REMOVE OF decreased_ask_counts_10_volume. Len: 115
# +++67 MSE score: 0.4512; +++67 Corr score: 0.1587
# SUCCESSFULL ADDING OF flatten_spread_5_mean. Len: 116
# Last added cols: ['flatten_spread_100_ewm', 'bid_flatten_std_5', 'flatten_spread_50_ewm', 'wap1', 'flatten_spread_5_mean']
# ---24 MSE score: 0.4511; ---24 Corr score: 0.1589
# SUCCESSFULL REMOVE OF volume_imbalance_4. Len: 115
# +++148 MSE score: 0.4511; +++148 Corr score: 0.1589
# Not improved: 1
# ---89 MSE score: 0.4511; ---89 Corr score: 0.1590
# SUCCESSFULL REMOVE OF ask_flatten_ewm_50. Len: 114
# +++54 MSE score: 0.4511; +++54 Corr score: 0.1590
# Not improved: 1
# ---214 MSE score: 0.4515; ---214 Corr score: 0.1568
# Not improved: 2
# +++56 MSE score: 0.4511; +++56 Corr score: 0.1595
# SUCCESSFULL ADDING OF ask_flatten_std_5. Len: 115
# Last added cols: ['bid_flatten_std_5', 'flatten_spread_50_ewm', 'wap1', 'flatten_spread_5_mean', 'ask_flatten_std_5']
# ---95 MSE score: 0.4511; ---95 Corr score: 0.1594
# Not improved: 1
# +++169 MSE score: 0.4511; +++169 Corr score: 0.1594
# Not improved: 2
# ---215 MSE score: 0.4511; ---215 Corr score: 0.1594
# Not improved: 3
# +++87 MSE score: 0.4511; +++87 Corr score: 0.1594
# Not improved: 4
# ---79 MSE score: 0.4511; ---79 Corr score: 0.1595
# Not improved: 5
# +++119 MSE score: 0.4511; +++119 Corr score: 0.1594
# Not improved: 6
# ---166 MSE score: 0.4511; ---166 Corr score: 0.1595
# Not improved: 7
# +++211 MSE score: 0.4511; +++211 Corr score: 0.1591
# Not improved: 8
# ---23 MSE score: 0.4511; ---23 Corr score: 0.1594
# Not improved: 9
# +++98 MSE score: 0.4512; +++98 Corr score: 0.1587
# Not improved: 10
# ---38 MSE score: 0.4511; ---38 Corr score: 0.1593
# Not improved: 11
# +++86 MSE score: 0.4510; +++86 Corr score: 0.1595
# SUCCESSFULL ADDING OF flatten_spread_25_ewm. Len: 116
# Last added cols: ['flatten_spread_50_ewm', 'wap1', 'flatten_spread_5_mean', 'ask_flatten_std_5', 'flatten_spread_25_ewm']
# ---37 MSE score: 0.4510; ---37 Corr score: 0.1600
# SUCCESSFULL REMOVE OF wap8. Len: 115
# +++200 MSE score: 0.4510; +++200 Corr score: 0.1600
# SUCCESSFULL ADDING OF len_ratio_20_mean. Len: 116
# Last added cols: ['wap1', 'flatten_spread_5_mean', 'ask_flatten_std_5', 'flatten_spread_25_ewm', 'len_ratio_20_mean']
# ---48 MSE score: 0.4512; ---48 Corr score: 0.1587
# Not improved: 1
# +++57 MSE score: 0.4510; +++57 Corr score: 0.1597
# Not improved: 2
# ---125 MSE score: 0.4510; ---125 Corr score: 0.1600
# SUCCESSFULL REMOVE OF increased_ask_counts_{window}. Len: 115
# +++211 MSE score: 0.4510; +++211 Corr score: 0.1597
# Not improved: 1
# ---171 MSE score: 0.4510; ---171 Corr score: 0.1600
# SUCCESSFULL REMOVE OF spread_rolling_mean_40. Len: 114
# +++221 MSE score: 0.4510; +++221 Corr score: 0.1600
# SUCCESSFULL ADDING OF volume_imbalance_80_max. Len: 115
# Last added cols: ['flatten_spread_5_mean', 'ask_flatten_std_5', 'flatten_spread_25_ewm', 'len_ratio_20_mean', 'volume_imbalance_80_max']
# ---205 MSE score: 0.4509; ---205 Corr score: 0.1607
# SUCCESSFULL REMOVE OF wap1_40_mean. Len: 114
# +++41 MSE score: 0.4509; +++41 Corr score: 0.1606
# Not improved: 1
# ---177 MSE score: 0.4508; ---177 Corr score: 0.1611
# SUCCESSFULL REMOVE OF spread_rolling_std_80. Len: 113
# +++179 MSE score: 0.4508; +++179 Corr score: 0.1611
# SUCCESSFULL ADDING OF wap0_10_std. Len: 114
# Last added cols: ['ask_flatten_std_5', 'flatten_spread_25_ewm', 'len_ratio_20_mean', 'volume_imbalance_80_max', 'wap0_10_std']
# ---212 MSE score: 0.4508; ---212 Corr score: 0.1611
# Not improved: 1
# +++121 MSE score: 0.4507; +++121 Corr score: 0.1615
# SUCCESSFULL ADDING OF flatten_spread_100_mean. Len: 115
# Last added cols: ['flatten_spread_25_ewm', 'len_ratio_20_mean', 'volume_imbalance_80_max', 'wap0_10_std', 'flatten_spread_100_mean']
# ---43 MSE score: 0.4507; ---43 Corr score: 0.1615
# SUCCESSFULL REMOVE OF increased_ask_counts. Len: 114
# +++32 MSE score: 0.4508; +++32 Corr score: 0.1610
# Not improved: 1
# ---102 MSE score: 0.4507; ---102 Corr score: 0.1616
# SUCCESSFULL REMOVE OF bid_flatten_kurtosis_50. Len: 113
# +++4 MSE score: 0.4509; +++4 Corr score: 0.1600
# Not improved: 1
# ---19 MSE score: 0.4507; ---19 Corr score: 0.1616
# Not improved: 2
# +++181 MSE score: 0.4509; +++181 Corr score: 0.1605
# Not improved: 3
# ---129 MSE score: 0.4508; ---129 Corr score: 0.1612
# Not improved: 4
# +++186 MSE score: 0.4507; +++186 Corr score: 0.1615
# Not improved: 5
# ---134 MSE score: 0.4507; ---134 Corr score: 0.1618
# SUCCESSFULL REMOVE OF decreased_ask_counts_5_volume. Len: 112
# +++202 MSE score: 0.4506; +++202 Corr score: 0.1626
# SUCCESSFULL ADDING OF wap0_40_mean. Len: 113
# Last added cols: ['len_ratio_20_mean', 'volume_imbalance_80_max', 'wap0_10_std', 'flatten_spread_100_mean', 'wap0_40_mean']
# ---139 MSE score: 0.4506; ---139 Corr score: 0.1626
# Not improved: 1
# +++205 MSE score: 0.4506; +++205 Corr score: 0.1624
# Not improved: 2
# ---39 MSE score: 0.4506; ---39 Corr score: 0.1626
# Not improved: 3
# +++173 MSE score: 0.4506; +++173 Corr score: 0.1624
# Not improved: 4
# ---85 MSE score: 0.4506; ---85 Corr score: 0.1625
# Not improved: 5
# +++126 MSE score: 0.4506; +++126 Corr score: 0.1624
# Not improved: 6
# ---184 MSE score: 0.4506; ---184 Corr score: 0.1626
# SUCCESSFULL REMOVE OF volume_imbalance_10_mean. Len: 112
# +++195 MSE score: 0.4509; +++195 Corr score: 0.1602
# Not improved: 1
# ---65 MSE score: 0.4506; ---65 Corr score: 0.1626
# SUCCESSFULL REMOVE OF bid_flatten_skew_5. Len: 111
# +++153 MSE score: 0.4506; +++153 Corr score: 0.1626
# Not improved: 1
# ---230 MSE score: 0.4510; ---230 Corr score: 0.1596
# Not improved: 2
# +++211 MSE score: 0.4506; +++211 Corr score: 0.1623
# Not improved: 3
# ---86 MSE score: 0.4506; ---86 Corr score: 0.1626
# Not improved: 4
# +++110 MSE score: 0.4506; +++110 Corr score: 0.1625
# Not improved: 5
# ---67 MSE score: 0.4506; ---67 Corr score: 0.1625
# Not improved: 6
# +++216 MSE score: 0.4506; +++216 Corr score: 0.1625
# Not improved: 7
# ---160 MSE score: 0.4506; ---160 Corr score: 0.1625
# Not improved: 8
# +++1 MSE score: 0.4506; +++1 Corr score: 0.1626
# SUCCESSFULL ADDING OF bid_rate_0. Len: 112
# Last added cols: ['volume_imbalance_80_max', 'wap0_10_std', 'flatten_spread_100_mean', 'wap0_40_mean', 'bid_rate_0']
# ---1 MSE score: 0.4506; ---1 Corr score: 0.1626
# Not improved: 1
# +++50 MSE score: 0.4505; +++50 Corr score: 0.1632
# SUCCESSFULL ADDING OF decreased_bid_rank. Len: 113
# Last added cols: ['wap0_10_std', 'flatten_spread_100_mean', 'wap0_40_mean', 'bid_rate_0', 'decreased_bid_rank']
# ---115 MSE score: 0.4504; ---115 Corr score: 0.1634
# SUCCESSFULL REMOVE OF bid_flatten_len_100. Len: 112
# +++127 MSE score: 0.4504; +++127 Corr score: 0.1634
# Not improved: 1
# ---187 MSE score: 0.4504; ---187 Corr score: 0.1634
# Not improved: 2
# +++73 MSE score: 0.4504; +++73 Corr score: 0.1633
# Not improved: 3
# ---55 MSE score: 0.4504; ---55 Corr score: 0.1634
# SUCCESSFULL REMOVE OF ask_flatten_mean_5. Len: 111
# +++138 MSE score: 0.4504; +++138 Corr score: 0.1632
# Not improved: 1
# ---69 MSE score: 0.4504; ---69 Corr score: 0.1634
# SUCCESSFULL REMOVE OF wap_flatten_5. Len: 110
# +++66 MSE score: 0.4504; +++66 Corr score: 0.1635
# SUCCESSFULL ADDING OF bid_flatten_kurtosis_5. Len: 111
# Last added cols: ['flatten_spread_100_mean', 'wap0_40_mean', 'bid_rate_0', 'decreased_bid_rank', 'bid_flatten_kurtosis_5']
# ---157 MSE score: 0.4504; ---157 Corr score: 0.1635
# Not improved: 1
# +++125 MSE score: 0.4504; +++125 Corr score: 0.1635
# SUCCESSFULL ADDING OF increased_ask_counts_{window}. Len: 112
# Last added cols: ['wap0_40_mean', 'bid_rate_0', 'decreased_bid_rank', 'bid_flatten_kurtosis_5', 'increased_ask_counts_{window}']
# ---152 MSE score: 0.4505; ---152 Corr score: 0.1631
# Not improved: 1
# +++151 MSE score: 0.4504; +++151 Corr score: 0.1635
# Not improved: 2
# ---133 MSE score: 0.4504; ---133 Corr score: 0.1636
# SUCCESSFULL REMOVE OF increased_ask_counts_5_volume. Len: 111
# +++158 MSE score: 0.4504; +++158 Corr score: 0.1636
# Not improved: 1
# ---56 MSE score: 0.4504; ---56 Corr score: 0.1634
# Not improved: 2
# +++18 MSE score: 0.4504; +++18 Corr score: 0.1637
# SUCCESSFULL ADDING OF volume_imbalance_2. Len: 112
# Last added cols: ['bid_rate_0', 'decreased_bid_rank', 'bid_flatten_kurtosis_5', 'increased_ask_counts_{window}', 'volume_imbalance_2']
# ---2 MSE score: 0.4504; ---2 Corr score: 0.1637
# SUCCESSFULL REMOVE OF mid_price. Len: 111
# +++228 MSE score: 0.4504; +++228 Corr score: 0.1634
# Not improved: 1
# ---170 MSE score: 0.4504; ---170 Corr score: 0.1635
# Not improved: 2
# +++119 MSE score: 0.4504; +++119 Corr score: 0.1636
# Not improved: 3
# ---130 MSE score: 0.4505; ---130 Corr score: 0.1630
# Not improved: 4
# +++59 MSE score: 0.4504; +++59 Corr score: 0.1636
# Not improved: 5
# ---212 MSE score: 0.4504; ---212 Corr score: 0.1637
# SUCCESSFULL REMOVE OF len_ratio_40_mean. Len: 110
# +++204 MSE score: 0.4504; +++204 Corr score: 0.1638
# SUCCESSFULL ADDING OF wap0_40_max. Len: 111
# Last added cols: ['decreased_bid_rank', 'bid_flatten_kurtosis_5', 'increased_ask_counts_{window}', 'volume_imbalance_2', 'wap0_40_max']
# ---38 MSE score: 0.4504; ---38 Corr score: 0.1636
# Not improved: 1
# +++84 MSE score: 0.4504; +++84 Corr score: 0.1638
# SUCCESSFULL ADDING OF bid_flatten_kurtosis_25. Len: 112
# Last added cols: ['bid_flatten_kurtosis_5', 'increased_ask_counts_{window}', 'volume_imbalance_2', 'wap0_40_max', 'bid_flatten_kurtosis_25']
# ---165 MSE score: 0.4504; ---165 Corr score: 0.1636
# Not improved: 1
# +++158 MSE score: 0.4504; +++158 Corr score: 0.1638
# Not improved: 2
# ---230 MSE score: 0.4507; ---230 Corr score: 0.1613
# Not improved: 3
# +++116 MSE score: 0.4502; +++116 Corr score: 0.1646
# SUCCESSFULL ADDING OF bid_flatten_mean_100. Len: 113
# Last added cols: ['increased_ask_counts_{window}', 'volume_imbalance_2', 'wap0_40_max', 'bid_flatten_kurtosis_25', 'bid_flatten_mean_100']
# ---125 MSE score: 0.4502; ---125 Corr score: 0.1646
# Not improved: 1
# +++144 MSE score: 0.4502; +++144 Corr score: 0.1646
# SUCCESSFULL ADDING OF mid_price_log_20. Len: 114
# Last added cols: ['volume_imbalance_2', 'wap0_40_max', 'bid_flatten_kurtosis_25', 'bid_flatten_mean_100', 'mid_price_log_20']
# ---214 MSE score: 0.4503; ---214 Corr score: 0.1641
# Not improved: 1
# +++109 MSE score: 0.4502; +++109 Corr score: 0.1646
# SUCCESSFULL ADDING OF ask_flatten_mean_100. Len: 115
# Last added cols: ['wap0_40_max', 'bid_flatten_kurtosis_25', 'bid_flatten_mean_100', 'mid_price_log_20', 'ask_flatten_mean_100']
# ---199 MSE score: 0.4502; ---199 Corr score: 0.1646
# SUCCESSFULL REMOVE OF volume_imbalance_20_skew. Len: 114
# +++37 MSE score: 0.4504; +++37 Corr score: 0.1638
# Not improved: 1
# ---104 MSE score: 0.4502; ---104 Corr score: 0.1648
# SUCCESSFULL REMOVE OF flatten_spread_50_ewm. Len: 113
# +++74 MSE score: 0.4502; +++74 Corr score: 0.1649
# SUCCESSFULL ADDING OF ask_flatten_std_25. Len: 114
# Last added cols: ['bid_flatten_kurtosis_25', 'bid_flatten_mean_100', 'mid_price_log_20', 'ask_flatten_mean_100', 'ask_flatten_std_25']
# ---7 MSE score: 0.4503; ---7 Corr score: 0.1647
# Not improved: 1
# +++103 MSE score: 0.4502; +++103 Corr score: 0.1649
# SUCCESSFULL ADDING OF flatten_spread_50_mean. Len: 115
# Last added cols: ['bid_flatten_mean_100', 'mid_price_log_20', 'ask_flatten_mean_100', 'ask_flatten_std_25', 'flatten_spread_50_mean']
# ---114 MSE score: 0.4502; ---114 Corr score: 0.1650
# SUCCESSFULL REMOVE OF bid_flatten_ewm_100. Len: 114
# +++123 MSE score: 0.4502; +++123 Corr score: 0.1650
# SUCCESSFULL ADDING OF wap_flatten_100. Len: 115
# Last added cols: ['mid_price_log_20', 'ask_flatten_mean_100', 'ask_flatten_std_25', 'flatten_spread_50_mean', 'wap_flatten_100']
# ---135 MSE score: 0.4502; ---135 Corr score: 0.1650
# Not improved: 1
# +++150 MSE score: 0.4502; +++150 Corr score: 0.1651
# Not improved: 2
# ---214 MSE score: 0.4503; ---214 Corr score: 0.1645
# Not improved: 3
# +++37 MSE score: 0.4503; +++37 Corr score: 0.1641
# Not improved: 4
# ---160 MSE score: 0.4502; ---160 Corr score: 0.1648
# Not improved: 5
# +++27 MSE score: 0.4502; +++27 Corr score: 0.1650
# Not improved: 6
# ---11 MSE score: 0.4502; ---11 Corr score: 0.1650
# Not improved: 7
# +++41 MSE score: 0.4503; +++41 Corr score: 0.1646
# Not improved: 8
# ---79 MSE score: 0.4502; ---79 Corr score: 0.1650
# SUCCESSFULL REMOVE OF bid_flatten_len_25. Len: 114
# +++36 MSE score: 0.4503; +++36 Corr score: 0.1642
# Not improved: 1
# ---19 MSE score: 0.4502; ---19 Corr score: 0.1650
# Not improved: 2
# +++8 MSE score: 0.4508; +++8 Corr score: 0.1631
# Not improved: 3
# ---139 MSE score: 0.4502; ---139 Corr score: 0.1650
# Not improved: 4
# +++155 MSE score: 0.4502; +++155 Corr score: 0.1650
# Not improved: 5
# ---52 MSE score: 0.4502; ---52 Corr score: 0.1650
# SUCCESSFULL REMOVE OF decreased_askbid_counts. Len: 113
# +++207 MSE score: 0.4503; +++207 Corr score: 0.1644
# Not improved: 1
# ---85 MSE score: 0.4502; ---85 Corr score: 0.1650
# Not improved: 2
# +++2 MSE score: 0.4502; +++2 Corr score: 0.1650
# Not improved: 3
# ---85 MSE score: 0.4502; ---85 Corr score: 0.1650
# Not improved: 4
# +++8 MSE score: 0.4508; +++8 Corr score: 0.1631
# Not improved: 5
# ---230 MSE score: 0.4506; ---230 Corr score: 0.1626
# Not improved: 6
# +++156 MSE score: 0.4502; +++156 Corr score: 0.1650
# Not improved: 7
# ---170 MSE score: 0.4502; ---170 Corr score: 0.1648
# Not improved: 8
# +++36 MSE score: 0.4503; +++36 Corr score: 0.1642
# Not improved: 9
# ---70 MSE score: 0.4502; ---70 Corr score: 0.1650
# SUCCESSFULL REMOVE OF ewm_wap_flatten_5. Len: 112
# +++102 MSE score: 0.4502; +++102 Corr score: 0.1650
# Not improved: 1
# ---168 MSE score: 0.4502; ---168 Corr score: 0.1653
# SUCCESSFULL REMOVE OF mid_price_max_diff_40. Len: 111
# +++15 MSE score: 0.4501; +++15 Corr score: 0.1657
# SUCCESSFULL ADDING OF volume_imbalance_1. Len: 112
# Last added cols: ['ask_flatten_mean_100', 'ask_flatten_std_25', 'flatten_spread_50_mean', 'wap_flatten_100', 'volume_imbalance_1']
# ---66 MSE score: 0.4501; ---66 Corr score: 0.1657
# Not improved: 1
# +++34 MSE score: 0.4501; +++34 Corr score: 0.1658
# SUCCESSFULL ADDING OF wap7. Len: 113
# Last added cols: ['ask_flatten_std_25', 'flatten_spread_50_mean', 'wap_flatten_100', 'volume_imbalance_1', 'wap7']
# ---0 MSE score: 0.4501; ---0 Corr score: 0.1658
# SUCCESSFULL REMOVE OF ask_rate_0. Len: 112
# +++131 MSE score: 0.4501; +++131 Corr score: 0.1658
# SUCCESSFULL ADDING OF volume_imbalance_diff_3. Len: 113
# Last added cols: ['flatten_spread_50_mean', 'wap_flatten_100', 'volume_imbalance_1', 'wap7', 'volume_imbalance_diff_3']
# ---174 MSE score: 0.4502; ---174 Corr score: 0.1650
# Not improved: 1
# +++69 MSE score: 0.4501; +++69 Corr score: 0.1658
# SUCCESSFULL ADDING OF wap_flatten_5. Len: 114
# Last added cols: ['wap_flatten_100', 'volume_imbalance_1', 'wap7', 'volume_imbalance_diff_3', 'wap_flatten_5']
# ---103 MSE score: 0.4501; ---103 Corr score: 0.1658
# Not improved: 1
# +++183 MSE score: 0.4503; +++183 Corr score: 0.1649
# Not improved: 2
# ---64 MSE score: 0.4501; ---64 Corr score: 0.1658
# Not improved: 3
# +++138 MSE score: 0.4501; +++138 Corr score: 0.1656
# Not improved: 4
# ---187 MSE score: 0.4501; ---187 Corr score: 0.1659
# SUCCESSFULL REMOVE OF volume_imbalance_10_skew. Len: 113
# +++194 MSE score: 0.4500; +++194 Corr score: 0.1662
# SUCCESSFULL ADDING OF wap1_20_std. Len: 114
# Last added cols: ['volume_imbalance_1', 'wap7', 'volume_imbalance_diff_3', 'wap_flatten_5', 'wap1_20_std']
# ---175 MSE score: 0.4501; ---175 Corr score: 0.1656
# Not improved: 1
# +++190 MSE score: 0.4500; +++190 Corr score: 0.1666
# SUCCESSFULL ADDING OF wap0_20_mean. Len: 115
# Last added cols: ['wap7', 'volume_imbalance_diff_3', 'wap_flatten_5', 'wap1_20_std', 'wap0_20_mean']
# ---1 MSE score: 0.4500; ---1 Corr score: 0.1666
# SUCCESSFULL REMOVE OF bid_rate_0. Len: 114
# +++41 MSE score: 0.4500; +++41 Corr score: 0.1663
# Not improved: 1
# ---16 MSE score: 0.4500; ---16 Corr score: 0.1667
# SUCCESSFULL REMOVE OF wap1. Len: 113
# +++29 MSE score: 0.4500; +++29 Corr score: 0.1664
# Not improved: 1
# ---44 MSE score: 0.4501; ---44 Corr score: 0.1661
# Not improved: 2
# +++96 MSE score: 0.4500; +++96 Corr score: 0.1668
# SUCCESSFULL ADDING OF bid_flatten_ewm_50. Len: 114
# Last added cols: ['volume_imbalance_diff_3', 'wap_flatten_5', 'wap1_20_std', 'wap0_20_mean', 'bid_flatten_ewm_50']
# ---200 MSE score: 0.4500; ---200 Corr score: 0.1668
# Not improved: 1
# +++87 MSE score: 0.4500; +++87 Corr score: 0.1667
# Not improved: 2
# ---229 MSE score: 0.4500; ---229 Corr score: 0.1667
# Not improved: 3
# +++40 MSE score: 0.4500; +++40 Corr score: 0.1668
# SUCCESSFULL ADDING OF wap9. Len: 115
# Last added cols: ['wap_flatten_5', 'wap1_20_std', 'wap0_20_mean', 'bid_flatten_ewm_50', 'wap9']
# ---26 MSE score: 0.4500; ---26 Corr score: 0.1667
# Not improved: 1
# +++22 MSE score: 0.4500; +++22 Corr score: 0.1668
# Not improved: 2
# ---109 MSE score: 0.4500; ---109 Corr score: 0.1668
# SUCCESSFULL REMOVE OF ask_flatten_mean_100. Len: 114
# +++137 MSE score: 0.4500; +++137 Corr score: 0.1668
# Not improved: 1
# ---23 MSE score: 0.4500; ---23 Corr score: 0.1668
# Not improved: 2
# +++43 MSE score: 0.4500; +++43 Corr score: 0.1668
# Not improved: 3
# ---5 MSE score: 0.4500; ---5 Corr score: 0.1668
# Not improved: 4
# +++110 MSE score: 0.4499; +++110 Corr score: 0.1669
# SUCCESSFULL ADDING OF ask_flatten_std_100. Len: 115
# Last added cols: ['wap1_20_std', 'wap0_20_mean', 'bid_flatten_ewm_50', 'wap9', 'ask_flatten_std_100']
# ---222 MSE score: 0.4500; ---222 Corr score: 0.1667
# Not improved: 1
# +++16 MSE score: 0.4500; +++16 Corr score: 0.1669
# Not improved: 2
# ---180 MSE score: 0.4499; ---180 Corr score: 0.1669
# Not improved: 3
# +++8 MSE score: 0.4504; +++8 Corr score: 0.1653
# Not improved: 4
# ---172 MSE score: 0.4499; ---172 Corr score: 0.1670
# SUCCESSFULL REMOVE OF spread_rolling_std_40. Len: 114
# +++97 MSE score: 0.4500; +++97 Corr score: 0.1663
# Not improved: 1
# ---200 MSE score: 0.4499; ---200 Corr score: 0.1670
# Not improved: 2
# +++91 MSE score: 0.4500; +++91 Corr score: 0.1668
# Not improved: 3
# ---209 MSE score: 0.4500; ---209 Corr score: 0.1664
# Not improved: 4
# +++82 MSE score: 0.4500; +++82 Corr score: 0.1668
# Not improved: 5
# ---38 MSE score: 0.4500; ---38 Corr score: 0.1668
# Not improved: 6
# +++43 MSE score: 0.4499; +++43 Corr score: 0.1670
# Not improved: 7
# ---176 MSE score: 0.4499; ---176 Corr score: 0.1670
# SUCCESSFULL REMOVE OF spread_rolling_mean_80. Len: 113
# +++201 MSE score: 0.4499; +++201 Corr score: 0.1670
# Not improved: 1
# ---110 MSE score: 0.4499; ---110 Corr score: 0.1669
# Not improved: 2
# +++181 MSE score: 0.4499; +++181 Corr score: 0.1670
# Not improved: 3
# ---222 MSE score: 0.4500; ---222 Corr score: 0.1668
# Not improved: 4
# +++148 MSE score: 0.4499; +++148 Corr score: 0.1669
# Not improved: 5
# ---28 MSE score: 0.4499; ---28 Corr score: 0.1672
# SUCCESSFULL REMOVE OF wap5. Len: 112
# +++137 MSE score: 0.4499; +++137 Corr score: 0.1671
# Not improved: 1
# ---122 MSE score: 0.4499; ---122 Corr score: 0.1672
# SUCCESSFULL REMOVE OF flatten_spread_100_ewm. Len: 111
# +++164 MSE score: 0.4500; +++164 Corr score: 0.1668
# Not improved: 1
# ---68 MSE score: 0.4499; ---68 Corr score: 0.1672
# Not improved: 2
# +++140 MSE score: 0.4499; +++140 Corr score: 0.1672
# SUCCESSFULL ADDING OF mid_price_log_10. Len: 112
# Last added cols: ['wap0_20_mean', 'bid_flatten_ewm_50', 'wap9', 'ask_flatten_std_100', 'mid_price_log_10']
# ---112 MSE score: 0.4499; ---112 Corr score: 0.1673
# SUCCESSFULL REMOVE OF ask_flatten_skew_100. Len: 111
# +++227 MSE score: 0.4514; +++227 Corr score: 0.1579
# Not improved: 1
# ---159 MSE score: 0.4499; ---159 Corr score: 0.1674
# SUCCESSFULL REMOVE OF mid_price_min_diff_10. Len: 110
# +++158 MSE score: 0.4499; +++158 Corr score: 0.1673
# Not improved: 1
# ---18 MSE score: 0.4502; ---18 Corr score: 0.1655
# Not improved: 2
# +++83 MSE score: 0.4499; +++83 Corr score: 0.1670
# Not improved: 3
# ---116 MSE score: 0.4499; ---116 Corr score: 0.1669
# Not improved: 4
# +++177 MSE score: 0.4499; +++177 Corr score: 0.1671
# Not improved: 5
# ---5 MSE score: 0.4499; ---5 Corr score: 0.1674
# Not improved: 6
# +++72 MSE score: 0.4499; +++72 Corr score: 0.1670
# Not improved: 7
# ---111 MSE score: 0.4500; ---111 Corr score: 0.1663
# Not improved: 8
# +++28 MSE score: 0.4499; +++28 Corr score: 0.1673
# Not improved: 9
# ---9 MSE score: 0.4499; ---9 Corr score: 0.1670
# Not improved: 10
# +++164 MSE score: 0.4500; +++164 Corr score: 0.1669
# Not improved: 11
# ---69 MSE score: 0.4499; ---69 Corr score: 0.1673
# Not improved: 12
# +++156 MSE score: 0.4499; +++156 Corr score: 0.1674
# Not improved: 13
# ---147 MSE score: 0.4499; ---147 Corr score: 0.1673
# Not improved: 14
# +++28 MSE score: 0.4499; +++28 Corr score: 0.1673
# Not improved: 15
# ---107 MSE score: 0.4499; ---107 Corr score: 0.1675
# SUCCESSFULL REMOVE OF ask_flatten_ewm_100. Len: 109
# +++138 MSE score: 0.4499; +++138 Corr score: 0.1673
# Not improved: 1
# ---229 MSE score: 0.4499; ---229 Corr score: 0.1674
# Not improved: 2
# +++225 MSE score: 0.4499; +++225 Corr score: 0.1675
# Not improved: 3
# ---15 MSE score: 0.4506; ---15 Corr score: 0.1624
# Not improved: 4
# +++52 MSE score: 0.4499; +++52 Corr score: 0.1675
# Not improved: 5
# ---19 MSE score: 0.4499; ---19 Corr score: 0.1675
# SUCCESSFULL REMOVE OF wap2. Len: 108
# +++126 MSE score: 0.4499; +++126 Corr score: 0.1674
# Not improved: 1
# ---80 MSE score: 0.4498; ---80 Corr score: 0.1676
# SUCCESSFULL REMOVE OF bid_flatten_mean_25. Len: 107
# +++156 MSE score: 0.4498; +++156 Corr score: 0.1676
# Not improved: 1
# ---20 MSE score: 0.4499; ---20 Corr score: 0.1671
# Not improved: 2
# +++203 MSE score: 0.4498; +++203 Corr score: 0.1676
# Not improved: 3
# ---103 MSE score: 0.4498; ---103 Corr score: 0.1676
# SUCCESSFULL REMOVE OF flatten_spread_50_mean. Len: 106
# +++126 MSE score: 0.4499; +++126 Corr score: 0.1674
# Not improved: 1
# ---113 MSE score: 0.4498; ---113 Corr score: 0.1675
# Not improved: 2
# +++109 MSE score: 0.4499; +++109 Corr score: 0.1674
# Not improved: 3
# ---46 MSE score: 0.4500; ---46 Corr score: 0.1667
# Not improved: 4
# +++72 MSE score: 0.4499; +++72 Corr score: 0.1672
# Not improved: 5
# ---229 MSE score: 0.4498; ---229 Corr score: 0.1675
# Not improved: 6
# +++16 MSE score: 0.4499; +++16 Corr score: 0.1674
# Not improved: 7
# ---71 MSE score: 0.4498; ---71 Corr score: 0.1676
# SUCCESSFULL REMOVE OF ask_flatten_ewm_25. Len: 105
# +++122 MSE score: 0.4498; +++122 Corr score: 0.1678
# SUCCESSFULL ADDING OF flatten_spread_100_ewm. Len: 106
# Last added cols: ['bid_flatten_ewm_50', 'wap9', 'ask_flatten_std_100', 'mid_price_log_10', 'flatten_spread_100_ewm']
# ---74 MSE score: 0.4498; ---74 Corr score: 0.1678
# SUCCESSFULL REMOVE OF ask_flatten_std_25. Len: 105
# +++164 MSE score: 0.4499; +++164 Corr score: 0.1673
# Not improved: 1
# ---64 MSE score: 0.4498; ---64 Corr score: 0.1677
# Not improved: 2
# +++57 MSE score: 0.4498; +++57 Corr score: 0.1676
# Not improved: 3
# ---166 MSE score: 0.4498; ---166 Corr score: 0.1677
# Not improved: 4
# +++126 MSE score: 0.4498; +++126 Corr score: 0.1676
# Not improved: 5
# ---94 MSE score: 0.4498; ---94 Corr score: 0.1676
# Not improved: 6
# +++90 MSE score: 0.4498; +++90 Corr score: 0.1678
# SUCCESSFULL ADDING OF ask_flatten_len_50. Len: 106
# Last added cols: ['wap9', 'ask_flatten_std_100', 'mid_price_log_10', 'flatten_spread_100_ewm', 'ask_flatten_len_50']
# ---230 MSE score: 0.4511; ---230 Corr score: 0.1596
# Not improved: 1
# +++133 MSE score: 0.4498; +++133 Corr score: 0.1677
# Not improved: 2
# ---50 MSE score: 0.4499; ---50 Corr score: 0.1672
# Not improved: 3
# +++211 MSE score: 0.4499; +++211 Corr score: 0.1674
# Not improved: 4
# ---116 MSE score: 0.4498; ---116 Corr score: 0.1676
# Not improved: 5
# +++205 MSE score: 0.4498; +++205 Corr score: 0.1677
# Not improved: 6
# ---113 MSE score: 0.4498; ---113 Corr score: 0.1678
# SUCCESSFULL REMOVE OF ask_flatten_kurtosis_100. Len: 105
# +++192 MSE score: 0.4498; +++192 Corr score: 0.1678
# Not improved: 1
# ---13 MSE score: 0.4498; ---13 Corr score: 0.1677
# Not improved: 2
# +++223 MSE score: 0.4499; +++223 Corr score: 0.1672
# Not improved: 3
# ---46 MSE score: 0.4499; ---46 Corr score: 0.1670
# Not improved: 4
# +++148 MSE score: 0.4498; +++148 Corr score: 0.1677
# Not improved: 5
# ---165 MSE score: 0.4498; ---165 Corr score: 0.1676
# Not improved: 6
# +++52 MSE score: 0.4498; +++52 Corr score: 0.1678
# Not improved: 7
# ---157 MSE score: 0.4498; ---157 Corr score: 0.1678
# SUCCESSFULL REMOVE OF spread_rolling_std_5. Len: 104
# +++226 MSE score: 0.4499; +++226 Corr score: 0.1673
# Not improved: 1
# ---34 MSE score: 0.4498; ---34 Corr score: 0.1678
# SUCCESSFULL REMOVE OF wap7. Len: 103
# +++115 MSE score: 0.4498; +++115 Corr score: 0.1677
# Not improved: 1
# ---5 MSE score: 0.4498; ---5 Corr score: 0.1678
# SUCCESSFULL REMOVE OF bid_ask_spread. Len: 102
# +++112 MSE score: 0.4498; +++112 Corr score: 0.1678
# SUCCESSFULL ADDING OF ask_flatten_skew_100. Len: 103
# Last added cols: ['ask_flatten_std_100', 'mid_price_log_10', 'flatten_spread_100_ewm', 'ask_flatten_len_50', 'ask_flatten_skew_100']
# ---7 MSE score: 0.4498; ---7 Corr score: 0.1678
# SUCCESSFULL REMOVE OF bid_size_0. Len: 102
# +++78 MSE score: 0.4498; +++78 Corr score: 0.1676
# Not improved: 1
# ---202 MSE score: 0.4498; ---202 Corr score: 0.1675
# Not improved: 2
# +++195 MSE score: 0.4501; +++195 Corr score: 0.1659
# Not improved: 3
# ---17 MSE score: 0.4498; ---17 Corr score: 0.1675
# Not improved: 4
# +++197 MSE score: 0.4498; +++197 Corr score: 0.1679
# SUCCESSFULL ADDING OF volume_imbalance_20_max. Len: 103
# Last added cols: ['mid_price_log_10', 'flatten_spread_100_ewm', 'ask_flatten_len_50', 'ask_flatten_skew_100', 'volume_imbalance_20_max']
# ---95 MSE score: 0.4498; ---95 Corr score: 0.1679
# Not improved: 1
# +++53 MSE score: 0.4498; +++53 Corr score: 0.1679
# Not improved: 2
# ---69 MSE score: 0.4498; ---69 Corr score: 0.1679
# Not improved: 3
# +++205 MSE score: 0.4498; +++205 Corr score: 0.1679
# Not improved: 4
# ---106 MSE score: 0.4497; ---106 Corr score: 0.1681
# SUCCESSFULL REMOVE OF ewm_wap_flatten_50. Len: 102
# +++5 MSE score: 0.4497; +++5 Corr score: 0.1681
# Not improved: 1
# ---84 MSE score: 0.4498; ---84 Corr score: 0.1680
# Not improved: 2
# +++43 MSE score: 0.4497; +++43 Corr score: 0.1681
# Not improved: 3
# ---200 MSE score: 0.4497; ---200 Corr score: 0.1681
# Not improved: 4
# +++141 MSE score: 0.4498; +++141 Corr score: 0.1679
# Not improved: 5
# ---39 MSE score: 0.4498; ---39 Corr score: 0.1681
# Not improved: 6
# +++70 MSE score: 0.4497; +++70 Corr score: 0.1681
# SUCCESSFULL ADDING OF ewm_wap_flatten_5. Len: 103
# Last added cols: ['flatten_spread_100_ewm', 'ask_flatten_len_50', 'ask_flatten_skew_100', 'volume_imbalance_20_max', 'ewm_wap_flatten_5']
# ---86 MSE score: 0.4497; ---86 Corr score: 0.1681
# Not improved: 1
# +++220 MSE score: 0.4498; +++220 Corr score: 0.1679
# Not improved: 2
# ---49 MSE score: 0.4497; ---49 Corr score: 0.1681
# Not improved: 3
# +++167 MSE score: 0.4497; +++167 Corr score: 0.1681
# Not improved: 4
# ---68 MSE score: 0.4497; ---68 Corr score: 0.1681
# Not improved: 5
# +++25 MSE score: 0.4498; +++25 Corr score: 0.1680
# Not improved: 6
# ---123 MSE score: 0.4498; ---123 Corr score: 0.1680
# Not improved: 7
# +++37 MSE score: 0.4498; +++37 Corr score: 0.1676
# Not improved: 8
# ---90 MSE score: 0.4497; ---90 Corr score: 0.1680
# Not improved: 9
# +++72 MSE score: 0.4499; +++72 Corr score: 0.1674
# Not improved: 10
# ---219 MSE score: 0.4498; ---219 Corr score: 0.1677
# Not improved: 11
# +++1 MSE score: 0.4497; +++1 Corr score: 0.1681
# SUCCESSFULL ADDING OF bid_rate_0. Len: 104
# Last added cols: ['ask_flatten_len_50', 'ask_flatten_skew_100', 'volume_imbalance_20_max', 'ewm_wap_flatten_5', 'bid_rate_0']
# ---21 MSE score: 0.4498; ---21 Corr score: 0.1677
# Not improved: 1
# +++103 MSE score: 0.4498; +++103 Corr score: 0.1681
# Not improved: 2
# ---144 MSE score: 0.4497; ---144 Corr score: 0.1681
# Not improved: 3
# +++228 MSE score: 0.4498; +++228 Corr score: 0.1679
# Not improved: 4
# ---12 MSE score: 0.4497; ---12 Corr score: 0.1681
# Not improved: 5
# +++25 MSE score: 0.4498; +++25 Corr score: 0.1680
# Not improved: 6
# ---77 MSE score: 0.4497; ---77 Corr score: 0.1681
# Not improved: 7
# +++220 MSE score: 0.4498; +++220 Corr score: 0.1679
# Not improved: 8
# ---202 MSE score: 0.4498; ---202 Corr score: 0.1678
# Not improved: 9
# +++27 MSE score: 0.4497; +++27 Corr score: 0.1681
# Not improved: 10
# ---124 MSE score: 0.4497; ---124 Corr score: 0.1683
# SUCCESSFULL REMOVE OF ewm_wap_flatten_100. Len: 103
# +++127 MSE score: 0.4497; +++127 Corr score: 0.1682
# Not improved: 1
# ---88 MSE score: 0.4497; ---88 Corr score: 0.1684
# SUCCESSFULL REMOVE OF ewm_wap_flatten_25. Len: 102
# +++156 MSE score: 0.4497; +++156 Corr score: 0.1684
# Not improved: 1
# ---61 MSE score: 0.4497; ---61 Corr score: 0.1684
# Not improved: 2
# +++32 MSE score: 0.4498; +++32 Corr score: 0.1679
# Not improved: 3
# ---46 MSE score: 0.4498; ---46 Corr score: 0.1676
# Not improved: 4
# +++89 MSE score: 0.4497; +++89 Corr score: 0.1682
# Not improved: 5
# ---15 MSE score: 0.4508; ---15 Corr score: 0.1609
# Not improved: 6
# +++104 MSE score: 0.4497; +++104 Corr score: 0.1681
# Not improved: 7
# ---26 MSE score: 0.4497; ---26 Corr score: 0.1683
# Not improved: 8
# +++91 MSE score: 0.4498; +++91 Corr score: 0.1679
# Not improved: 9
# ---121 MSE score: 0.4497; ---121 Corr score: 0.1680
# Not improved: 10
# +++177 MSE score: 0.4497; +++177 Corr score: 0.1682
# Not improved: 11
# ---20 MSE score: 0.4497; ---20 Corr score: 0.1679
# Not improved: 12
# +++55 MSE score: 0.4497; +++55 Corr score: 0.1684
# Not improved: 13
# ---154 MSE score: 0.4497; ---154 Corr score: 0.1684
# Not improved: 14
# +++31 MSE score: 0.4497; +++31 Corr score: 0.1684
# Not improved: 15
# ---182 MSE score: 0.4497; ---182 Corr score: 0.1684
# Not improved: 16
# +++141 MSE score: 0.4497; +++141 Corr score: 0.1682
# Not improved: 17
# ---175 MSE score: 0.4498; ---175 Corr score: 0.1678
# Not improved: 18
# +++195 MSE score: 0.4500; +++195 Corr score: 0.1665
# Not improved: 19
# ---219 MSE score: 0.4498; ---219 Corr score: 0.1679
# Not improved: 20
# +++62 MSE score: 0.4497; +++62 Corr score: 0.1684
# Not improved: 21

# %%
for fold_id in (3,4):
    time_folds = TimeFolds(**experiment['TimeFolds'])
    print(experiment['TimeFolds'])
    time_folds.fit(train_features, target)

    model_config = model_zoo['selection_ridge']
    print(model_config)

    runner = CrossValRunner(time_folds, **model_config)
    fold_processor = runner.preprocessor.prepare_fold(fold_id)

    n_features = train_features.shape[1]

    dev_utils.init_seed(42 + fold_id)
    best_usecols = np.random.choice(n_features, n_features // 2, replace=False).tolist()
    best_mse, best_corr = score_cols(fold_processor, usecols=best_usecols)


    not_improved_iter = 0
    for current_iter in range(100000):
        if current_iter % 2 == 0:
            removing_col = np.random.choice(best_usecols)
            use_cols = [col for col in best_usecols if col != removing_col]
            prefix = f'---{removing_col}'
        else:
            adding_col = np.random.choice([idx for idx in range(n_features) if idx not in best_usecols])
            use_cols = best_usecols + [adding_col]
            prefix = f'+++{adding_col}'
        current_mse, current_corr = score_cols(fold_processor, usecols=use_cols, prefix=prefix)
        if current_mse < best_mse:
            best_usecols = use_cols
            best_mse, best_corr = current_mse, current_corr
            not_improved_iter = 0
            if current_iter % 2 == 0:
                print(f'SUCCESSFULL REMOVE OF {train_features.columns[removing_col]}. Len: {len(use_cols)}')
            else:
                print(f'SUCCESSFULL ADDING OF {train_features.columns[adding_col]}. Len: {len(use_cols)}')
                print(f'Last added cols: {[train_features.columns[col] for col in best_usecols[-5:]]}')
        else:
            not_improved_iter += 1
            print(f'Not improved: {not_improved_iter}')
        if not_improved_iter > 20:
            break

    best_usenames = train_features.columns[best_usecols]
    with open(f'usecols/usecols_fold_{fold_id}.txt', 'w') as f:
        f.writelines('\n'.join(best_usenames))
# Out:
# {'n_folds': 5, 'minifold_size': 60000, 'neutral_ratio': 0.025, 'test_ratio': 0.2, 'train_test_gap': 2000}
# {'model_module': 'sklearn.linear_model', 'model_cls': 'Ridge', 'model_params': {'alpha': 10}}
#  MSE score: 0.5678;  Corr score: 0.1465
# ---47 MSE score: 0.5678; ---47 Corr score: 0.1462
# Not improved: 1
# +++203 MSE score: 0.5678; +++203 Corr score: 0.1464
# Not improved: 2
# ---104 MSE score: 0.5678; ---104 Corr score: 0.1464
# Not improved: 3
# +++46 MSE score: 0.5677; +++46 Corr score: 0.1468
# SUCCESSFULL ADDING OF decreased_ask_rank. Len: 116
# Last added cols: ['increased_ask_counts', 'volume_imbalance_6', 'bid_flatten_len_50', 'decreased_ask_counts_5_volume', 'decreased_ask_rank']
# ---33 MSE score: 0.5677; ---33 Corr score: 0.1469
# SUCCESSFULL REMOVE OF volume_imbalance_7. Len: 115
# +++170 MSE score: 0.5677; +++170 Corr score: 0.1468
# Not improved: 1
# ---210 MSE score: 0.5677; ---210 Corr score: 0.1469
# SUCCESSFULL REMOVE OF volume_imbalance_40_std. Len: 114
# +++60 MSE score: 0.5677; +++60 Corr score: 0.1469
# Not improved: 1
# ---173 MSE score: 0.5679; ---173 Corr score: 0.1455
# Not improved: 2
# +++20 MSE score: 0.5678; +++20 Corr score: 0.1466
# Not improved: 3
# ---212 MSE score: 0.5677; ---212 Corr score: 0.1467
# Not improved: 4
# +++88 MSE score: 0.5677; +++88 Corr score: 0.1470
# SUCCESSFULL ADDING OF ewm_wap_flatten_25. Len: 115
# Last added cols: ['volume_imbalance_6', 'bid_flatten_len_50', 'decreased_ask_counts_5_volume', 'decreased_ask_rank', 'ewm_wap_flatten_25']
# ---208 MSE score: 0.5677; ---208 Corr score: 0.1471
# SUCCESSFULL REMOVE OF volume_imbalance_40_mean. Len: 114
# +++95 MSE score: 0.5676; +++95 Corr score: 0.1471
# SUCCESSFULL ADDING OF ask_flatten_kurtosis_50. Len: 115
# Last added cols: ['bid_flatten_len_50', 'decreased_ask_counts_5_volume', 'decreased_ask_rank', 'ewm_wap_flatten_25', 'ask_flatten_kurtosis_50']
# ---223 MSE score: 0.5677; ---223 Corr score: 0.1470
# Not improved: 1
# +++164 MSE score: 0.5676; +++164 Corr score: 0.1474
# SUCCESSFULL ADDING OF mid_price_min_diff_20. Len: 116
# Last added cols: ['decreased_ask_counts_5_volume', 'decreased_ask_rank', 'ewm_wap_flatten_25', 'ask_flatten_kurtosis_50', 'mid_price_min_diff_20']
# ---84 MSE score: 0.5675; ---84 Corr score: 0.1479
# SUCCESSFULL REMOVE OF bid_flatten_kurtosis_25. Len: 115
# +++107 MSE score: 0.5676; +++107 Corr score: 0.1476
# Not improved: 1
# ---202 MSE score: 0.5676; ---202 Corr score: 0.1471
# Not improved: 2
# +++33 MSE score: 0.5675; +++33 Corr score: 0.1478
# Not improved: 3
# ---150 MSE score: 0.5675; ---150 Corr score: 0.1480
# SUCCESSFULL REMOVE OF decreased_ask_counts_80_volume. Len: 114
# +++229 MSE score: 0.5675; +++229 Corr score: 0.1479
# Not improved: 1
# ---192 MSE score: 0.5675; ---192 Corr score: 0.1478
# Not improved: 2
# +++197 MSE score: 0.5675; +++197 Corr score: 0.1480
# Not improved: 3
# ---113 MSE score: 0.5675; ---113 Corr score: 0.1480
# Not improved: 4
# +++220 MSE score: 0.5675; +++220 Corr score: 0.1480
# Not improved: 5
# ---147 MSE score: 0.5675; ---147 Corr score: 0.1480
# Not improved: 6
# +++159 MSE score: 0.5675; +++159 Corr score: 0.1480
# Not improved: 7
# ---157 MSE score: 0.5675; ---157 Corr score: 0.1480
# SUCCESSFULL REMOVE OF spread_rolling_std_5. Len: 113
# +++181 MSE score: 0.5675; +++181 Corr score: 0.1480
# Not improved: 1
# ---138 MSE score: 0.5675; ---138 Corr score: 0.1479
# Not improved: 2
# +++206 MSE score: 0.5675; +++206 Corr score: 0.1481
# SUCCESSFULL ADDING OF wap1_40_std. Len: 114
# Last added cols: ['decreased_ask_rank', 'ewm_wap_flatten_25', 'ask_flatten_kurtosis_50', 'mid_price_min_diff_20', 'wap1_40_std']
# ---45 MSE score: 0.5675; ---45 Corr score: 0.1481
# Not improved: 1
# +++152 MSE score: 0.5673; +++152 Corr score: 0.1486
# SUCCESSFULL ADDING OF mid_price_log_80. Len: 115
# Last added cols: ['ewm_wap_flatten_25', 'ask_flatten_kurtosis_50', 'mid_price_min_diff_20', 'wap1_40_std', 'mid_price_log_80']
# ---73 MSE score: 0.5674; ---73 Corr score: 0.1481
# Not improved: 1
# +++224 MSE score: 0.5673; +++224 Corr score: 0.1488
# SUCCESSFULL ADDING OF len_ratio_80_mean. Len: 116
# Last added cols: ['ask_flatten_kurtosis_50', 'mid_price_min_diff_20', 'wap1_40_std', 'mid_price_log_80', 'len_ratio_80_mean']
# ---35 MSE score: 0.5674; ---35 Corr score: 0.1485
# Not improved: 1
# +++93 MSE score: 0.5672; +++93 Corr score: 0.1497
# SUCCESSFULL ADDING OF ask_flatten_iqr_50. Len: 117
# Last added cols: ['mid_price_min_diff_20', 'wap1_40_std', 'mid_price_log_80', 'len_ratio_80_mean', 'ask_flatten_iqr_50']
# ---74 MSE score: 0.5671; ---74 Corr score: 0.1498
# SUCCESSFULL REMOVE OF ask_flatten_std_25. Len: 116
# +++142 MSE score: 0.5671; +++142 Corr score: 0.1498
# SUCCESSFULL ADDING OF decreased_ask_counts_20_volume. Len: 117
# Last added cols: ['wap1_40_std', 'mid_price_log_80', 'len_ratio_80_mean', 'ask_flatten_iqr_50', 'decreased_ask_counts_20_volume']
# ---129 MSE score: 0.5672; ---129 Corr score: 0.1492
# Not improved: 1
# +++11 MSE score: 0.5670; +++11 Corr score: 0.1504
# SUCCESSFULL ADDING OF cum_volume_imbalance_0. Len: 118
# Last added cols: ['mid_price_log_80', 'len_ratio_80_mean', 'ask_flatten_iqr_50', 'decreased_ask_counts_20_volume', 'cum_volume_imbalance_0']
# ---11 MSE score: 0.5671; ---11 Corr score: 0.1498
# Not improved: 1
# +++2 MSE score: 0.5670; +++2 Corr score: 0.1503
# Not improved: 2
# ---218 MSE score: 0.5670; ---218 Corr score: 0.1502
# Not improved: 3
# +++170 MSE score: 0.5670; +++170 Corr score: 0.1503
# Not improved: 4
# ---152 MSE score: 0.5671; ---152 Corr score: 0.1498
# Not improved: 5
# +++18 MSE score: 0.5669; +++18 Corr score: 0.1506
# SUCCESSFULL ADDING OF volume_imbalance_2. Len: 119
# Last added cols: ['len_ratio_80_mean', 'ask_flatten_iqr_50', 'decreased_ask_counts_20_volume', 'cum_volume_imbalance_0', 'volume_imbalance_2']
# ---41 MSE score: 0.5667; ---41 Corr score: 0.1517
# SUCCESSFULL REMOVE OF ask_rate_moda_spread. Len: 118
# +++21 MSE score: 0.5666; +++21 Corr score: 0.1521
# SUCCESSFULL ADDING OF volume_imbalance_3. Len: 119
# Last added cols: ['ask_flatten_iqr_50', 'decreased_ask_counts_20_volume', 'cum_volume_imbalance_0', 'volume_imbalance_2', 'volume_imbalance_3']
# ---13 MSE score: 0.5667; ---13 Corr score: 0.1518
# Not improved: 1
# +++118 MSE score: 0.5664; +++118 Corr score: 0.1531
# SUCCESSFULL ADDING OF bid_flatten_iqr_100. Len: 120
# Last added cols: ['decreased_ask_counts_20_volume', 'cum_volume_imbalance_0', 'volume_imbalance_2', 'volume_imbalance_3', 'bid_flatten_iqr_100']
# ---188 MSE score: 0.5664; ---188 Corr score: 0.1531
# Not improved: 1
# +++226 MSE score: 0.5663; +++226 Corr score: 0.1536
# SUCCESSFULL ADDING OF wap0_ewm_80. Len: 121
# Last added cols: ['cum_volume_imbalance_0', 'volume_imbalance_2', 'volume_imbalance_3', 'bid_flatten_iqr_100', 'wap0_ewm_80']
# ---161 MSE score: 0.5663; ---161 Corr score: 0.1536
# Not improved: 1
# +++92 MSE score: 0.5665; +++92 Corr score: 0.1528
# Not improved: 2
# ---44 MSE score: 0.5668; ---44 Corr score: 0.1510
# Not improved: 3
# +++187 MSE score: 0.5663; +++187 Corr score: 0.1536
# SUCCESSFULL ADDING OF volume_imbalance_10_skew. Len: 122
# Last added cols: ['volume_imbalance_2', 'volume_imbalance_3', 'bid_flatten_iqr_100', 'wap0_ewm_80', 'volume_imbalance_10_skew']
# ---218 MSE score: 0.5664; ---218 Corr score: 0.1535
# Not improved: 1
# +++178 MSE score: 0.5663; +++178 Corr score: 0.1537
# SUCCESSFULL ADDING OF wap0_10_mean. Len: 123
# Last added cols: ['volume_imbalance_3', 'bid_flatten_iqr_100', 'wap0_ewm_80', 'volume_imbalance_10_skew', 'wap0_10_mean']
# ---3 MSE score: 0.5662; ---3 Corr score: 0.1542
# SUCCESSFULL REMOVE OF mid_price_log. Len: 122
# +++181 MSE score: 0.5662; +++181 Corr score: 0.1542
# Not improved: 1
# ---191 MSE score: 0.5662; ---191 Corr score: 0.1543
# SUCCESSFULL REMOVE OF wap0_20_std. Len: 121
# +++41 MSE score: 0.5664; +++41 Corr score: 0.1533
# Not improved: 1
# ---228 MSE score: 0.5662; ---228 Corr score: 0.1543
# Not improved: 2
# +++37 MSE score: 0.5662; +++37 Corr score: 0.1543
# SUCCESSFULL ADDING OF wap8. Len: 122
# Last added cols: ['bid_flatten_iqr_100', 'wap0_ewm_80', 'volume_imbalance_10_skew', 'wap0_10_mean', 'wap8']
# ---102 MSE score: 0.5662; ---102 Corr score: 0.1543
# SUCCESSFULL REMOVE OF bid_flatten_kurtosis_50. Len: 121
# +++55 MSE score: 0.5662; +++55 Corr score: 0.1545
# SUCCESSFULL ADDING OF ask_flatten_mean_5. Len: 122
# Last added cols: ['wap0_ewm_80', 'volume_imbalance_10_skew', 'wap0_10_mean', 'wap8', 'ask_flatten_mean_5']
# ---21 MSE score: 0.5662; ---21 Corr score: 0.1541
# Not improved: 1
# +++132 MSE score: 0.5662; +++132 Corr score: 0.1545
# SUCCESSFULL ADDING OF mid_price_log_3. Len: 123
# Last added cols: ['volume_imbalance_10_skew', 'wap0_10_mean', 'wap8', 'ask_flatten_mean_5', 'mid_price_log_3']
# ---133 MSE score: 0.5662; ---133 Corr score: 0.1545
# Not improved: 1
# +++180 MSE score: 0.5662; +++180 Corr score: 0.1545
# SUCCESSFULL ADDING OF wap0_10_max. Len: 124
# Last added cols: ['wap0_10_mean', 'wap8', 'ask_flatten_mean_5', 'mid_price_log_3', 'wap0_10_max']
# ---118 MSE score: 0.5664; ---118 Corr score: 0.1535
# Not improved: 1
# +++17 MSE score: 0.5663; +++17 Corr score: 0.1541
# Not improved: 2
# ---152 MSE score: 0.5662; ---152 Corr score: 0.1541
# Not improved: 3
# +++1 MSE score: 0.5662; +++1 Corr score: 0.1543
# Not improved: 4
# ---82 MSE score: 0.5662; ---82 Corr score: 0.1544
# Not improved: 5
# +++87 MSE score: 0.5662; +++87 Corr score: 0.1544
# Not improved: 6
# ---64 MSE score: 0.5661; ---64 Corr score: 0.1549
# SUCCESSFULL REMOVE OF bid_flatten_iqr_5. Len: 123
# +++190 MSE score: 0.5661; +++190 Corr score: 0.1548
# Not improved: 1
# ---219 MSE score: 0.5661; ---219 Corr score: 0.1549
# SUCCESSFULL REMOVE OF wap1_80_max. Len: 122
# +++85 MSE score: 0.5662; +++85 Corr score: 0.1543
# Not improved: 1
# ---218 MSE score: 0.5661; ---218 Corr score: 0.1548
# Not improved: 2
# +++12 MSE score: 0.5661; +++12 Corr score: 0.1549
# SUCCESSFULL ADDING OF volume_imbalance_0. Len: 123
# Last added cols: ['wap8', 'ask_flatten_mean_5', 'mid_price_log_3', 'wap0_10_max', 'volume_imbalance_0']
# ---118 MSE score: 0.5663; ---118 Corr score: 0.1539
# Not improved: 1
# +++185 MSE score: 0.5661; +++185 Corr score: 0.1549
# SUCCESSFULL ADDING OF volume_imbalance_10_max. Len: 124
# Last added cols: ['ask_flatten_mean_5', 'mid_price_log_3', 'wap0_10_max', 'volume_imbalance_0', 'volume_imbalance_10_max']
# ---215 MSE score: 0.5661; ---215 Corr score: 0.1549
# Not improved: 1
# +++75 MSE score: 0.5660; +++75 Corr score: 0.1550
# SUCCESSFULL ADDING OF ask_flatten_iqr_25. Len: 125
# Last added cols: ['mid_price_log_3', 'wap0_10_max', 'volume_imbalance_0', 'volume_imbalance_10_max', 'ask_flatten_iqr_25']
# ---100 MSE score: 0.5659; ---100 Corr score: 0.1555
# SUCCESSFULL REMOVE OF bid_flatten_iqr_50. Len: 124
# +++131 MSE score: 0.5659; +++131 Corr score: 0.1555
# Not improved: 1
# ---73 MSE score: 0.5659; ---73 Corr score: 0.1559
# SUCCESSFULL REMOVE OF ask_flatten_mean_25. Len: 123
# +++41 MSE score: 0.5661; +++41 Corr score: 0.1549
# Not improved: 1
# ---151 MSE score: 0.5659; ---151 Corr score: 0.1559
# SUCCESSFULL REMOVE OF volume_imbalance_diff_80. Len: 122
# +++86 MSE score: 0.5662; +++86 Corr score: 0.1544
# Not improved: 1
# ---133 MSE score: 0.5659; ---133 Corr score: 0.1559
# Not improved: 2
# +++86 MSE score: 0.5662; +++86 Corr score: 0.1544
# Not improved: 3
# ---132 MSE score: 0.5659; ---132 Corr score: 0.1559
# SUCCESSFULL REMOVE OF mid_price_log_3. Len: 121
# +++68 MSE score: 0.5658; +++68 Corr score: 0.1560
# SUCCESSFULL ADDING OF flatten_spread_5_ewm. Len: 122
# Last added cols: ['wap0_10_max', 'volume_imbalance_0', 'volume_imbalance_10_max', 'ask_flatten_iqr_25', 'flatten_spread_5_ewm']
# ---35 MSE score: 0.5659; ---35 Corr score: 0.1557
# Not improved: 1
# +++59 MSE score: 0.5657; +++59 Corr score: 0.1567
# SUCCESSFULL ADDING OF ask_flatten_kurtosis_5. Len: 123
# Last added cols: ['volume_imbalance_0', 'volume_imbalance_10_max', 'ask_flatten_iqr_25', 'flatten_spread_5_ewm', 'ask_flatten_kurtosis_5']
# ---215 MSE score: 0.5657; ---215 Corr score: 0.1566
# Not improved: 1
# +++60 MSE score: 0.5657; +++60 Corr score: 0.1567
# SUCCESSFULL ADDING OF bid_flatten_ewm_5. Len: 124
# Last added cols: ['volume_imbalance_10_max', 'ask_flatten_iqr_25', 'flatten_spread_5_ewm', 'ask_flatten_kurtosis_5', 'bid_flatten_ewm_5']
# ---82 MSE score: 0.5657; ---82 Corr score: 0.1564
# Not improved: 1
# +++208 MSE score: 0.5657; +++208 Corr score: 0.1568
# SUCCESSFULL ADDING OF volume_imbalance_40_mean. Len: 125
# Last added cols: ['ask_flatten_iqr_25', 'flatten_spread_5_ewm', 'ask_flatten_kurtosis_5', 'bid_flatten_ewm_5', 'volume_imbalance_40_mean']
# ---43 MSE score: 0.5657; ---43 Corr score: 0.1566
# Not improved: 1
# +++78 MSE score: 0.5657; +++78 Corr score: 0.1569
# SUCCESSFULL ADDING OF bid_flatten_ewm_25. Len: 126
# Last added cols: ['flatten_spread_5_ewm', 'ask_flatten_kurtosis_5', 'bid_flatten_ewm_5', 'volume_imbalance_40_mean', 'bid_flatten_ewm_25']
# ---75 MSE score: 0.5657; ---75 Corr score: 0.1569
# Not improved: 1
# +++105 MSE score: 0.5657; +++105 Corr score: 0.1567
# Not improved: 2
# ---61 MSE score: 0.5657; ---61 Corr score: 0.1569
# SUCCESSFULL REMOVE OF bid_flatten_len_5. Len: 125
# +++177 MSE score: 0.5656; +++177 Corr score: 0.1573
# SUCCESSFULL ADDING OF spread_rolling_std_80. Len: 126
# Last added cols: ['ask_flatten_kurtosis_5', 'bid_flatten_ewm_5', 'volume_imbalance_40_mean', 'bid_flatten_ewm_25', 'spread_rolling_std_80']
# ---183 MSE score: 0.5657; ---183 Corr score: 0.1566
# Not improved: 1
# +++24 MSE score: 0.5656; +++24 Corr score: 0.1573
# SUCCESSFULL ADDING OF volume_imbalance_4. Len: 127
# Last added cols: ['bid_flatten_ewm_5', 'volume_imbalance_40_mean', 'bid_flatten_ewm_25', 'spread_rolling_std_80', 'volume_imbalance_4']
# ---224 MSE score: 0.5656; ---224 Corr score: 0.1571
# Not improved: 1
# +++167 MSE score: 0.5656; +++167 Corr score: 0.1573
# Not improved: 2
# ---69 MSE score: 0.5656; ---69 Corr score: 0.1573
# Not improved: 3
# +++98 MSE score: 0.5656; +++98 Corr score: 0.1572
# Not improved: 4
# ---82 MSE score: 0.5656; ---82 Corr score: 0.1570
# Not improved: 5
# +++136 MSE score: 0.5656; +++136 Corr score: 0.1573
# SUCCESSFULL ADDING OF mid_price_log_5. Len: 128
# Last added cols: ['volume_imbalance_40_mean', 'bid_flatten_ewm_25', 'spread_rolling_std_80', 'volume_imbalance_4', 'mid_price_log_5']
# ---39 MSE score: 0.5656; ---39 Corr score: 0.1573
# SUCCESSFULL REMOVE OF volume_imbalance_9. Len: 127
# +++32 MSE score: 0.5656; +++32 Corr score: 0.1573
# Not improved: 1
# ---101 MSE score: 0.5656; ---101 Corr score: 0.1570
# Not improved: 2
# +++64 MSE score: 0.5657; +++64 Corr score: 0.1569
# Not improved: 3
# ---79 MSE score: 0.5656; ---79 Corr score: 0.1573
# SUCCESSFULL REMOVE OF bid_flatten_len_25. Len: 126
# +++145 MSE score: 0.5656; +++145 Corr score: 0.1573
# Not improved: 1
# ---122 MSE score: 0.5659; ---122 Corr score: 0.1559
# Not improved: 2
# +++132 MSE score: 0.5656; +++132 Corr score: 0.1573
# Not improved: 3
# ---171 MSE score: 0.5655; ---171 Corr score: 0.1576
# SUCCESSFULL REMOVE OF spread_rolling_mean_40. Len: 125
# +++191 MSE score: 0.5655; +++191 Corr score: 0.1576
# Not improved: 1
# ---58 MSE score: 0.5656; ---58 Corr score: 0.1572
# Not improved: 2
# +++126 MSE score: 0.5655; +++126 Corr score: 0.1577
# SUCCESSFULL ADDING OF decreased_ask_counts_{window}. Len: 126
# Last added cols: ['bid_flatten_ewm_25', 'spread_rolling_std_80', 'volume_imbalance_4', 'mid_price_log_5', 'decreased_ask_counts_{window}']
# ---205 MSE score: 0.5655; ---205 Corr score: 0.1575
# Not improved: 1
# +++3 MSE score: 0.5656; +++3 Corr score: 0.1572
# Not improved: 2
# ---96 MSE score: 0.5654; ---96 Corr score: 0.1582
# SUCCESSFULL REMOVE OF bid_flatten_ewm_50. Len: 125
# +++150 MSE score: 0.5654; +++150 Corr score: 0.1580
# Not improved: 1
# ---115 MSE score: 0.5658; ---115 Corr score: 0.1558
# Not improved: 2
# +++131 MSE score: 0.5654; +++131 Corr score: 0.1582
# Not improved: 3
# ---211 MSE score: 0.5654; ---211 Corr score: 0.1582
# Not improved: 4
# +++209 MSE score: 0.5654; +++209 Corr score: 0.1582
# Not improved: 5
# ---46 MSE score: 0.5654; ---46 Corr score: 0.1579
# Not improved: 6
# +++64 MSE score: 0.5655; +++64 Corr score: 0.1578
# Not improved: 7
# ---166 MSE score: 0.5653; ---166 Corr score: 0.1584
# SUCCESSFULL REMOVE OF spread_rolling_mean_20. Len: 124
# +++209 MSE score: 0.5653; +++209 Corr score: 0.1584
# Not improved: 1
# ---47 MSE score: 0.5654; ---47 Corr score: 0.1579
# Not improved: 2
# +++54 MSE score: 0.5653; +++54 Corr score: 0.1584
# Not improved: 3
# ---193 MSE score: 0.5653; ---193 Corr score: 0.1584
# Not improved: 4
# +++3 MSE score: 0.5655; +++3 Corr score: 0.1579
# Not improved: 5
# ---26 MSE score: 0.5653; ---26 Corr score: 0.1585
# SUCCESSFULL REMOVE OF cum_volume_imbalance_5. Len: 123
# +++98 MSE score: 0.5654; +++98 Corr score: 0.1584
# Not improved: 1
# ---217 MSE score: 0.5653; ---217 Corr score: 0.1585
# Not improved: 2
# +++197 MSE score: 0.5653; +++197 Corr score: 0.1586
# SUCCESSFULL ADDING OF volume_imbalance_20_max. Len: 124
# Last added cols: ['spread_rolling_std_80', 'volume_imbalance_4', 'mid_price_log_5', 'decreased_ask_counts_{window}', 'volume_imbalance_20_max']
# ---228 MSE score: 0.5653; ---228 Corr score: 0.1585
# Not improved: 1
# +++163 MSE score: 0.5653; +++163 Corr score: 0.1585
# Not improved: 2
# ---95 MSE score: 0.5653; ---95 Corr score: 0.1584
# Not improved: 3
# +++53 MSE score: 0.5653; +++53 Corr score: 0.1586
# Not improved: 4
# ---101 MSE score: 0.5654; ---101 Corr score: 0.1583
# Not improved: 5
# +++17 MSE score: 0.5654; +++17 Corr score: 0.1582
# Not improved: 6
# ---156 MSE score: 0.5653; ---156 Corr score: 0.1586
# Not improved: 7
# +++105 MSE score: 0.5654; +++105 Corr score: 0.1582
# Not improved: 8
# ---202 MSE score: 0.5653; ---202 Corr score: 0.1584
# Not improved: 9
# +++22 MSE score: 0.5653; +++22 Corr score: 0.1586
# SUCCESSFULL ADDING OF wap3. Len: 125
# Last added cols: ['volume_imbalance_4', 'mid_price_log_5', 'decreased_ask_counts_{window}', 'volume_imbalance_20_max', 'wap3']
# ---193 MSE score: 0.5653; ---193 Corr score: 0.1586
# Not improved: 1
# +++79 MSE score: 0.5653; +++79 Corr score: 0.1586
# Not improved: 2
# ---177 MSE score: 0.5654; ---177 Corr score: 0.1582
# Not improved: 3
# +++203 MSE score: 0.5653; +++203 Corr score: 0.1585
# Not improved: 4
# ---193 MSE score: 0.5653; ---193 Corr score: 0.1586
# Not improved: 5
# +++31 MSE score: 0.5653; +++31 Corr score: 0.1586
# SUCCESSFULL ADDING OF wap6. Len: 126
# Last added cols: ['mid_price_log_5', 'decreased_ask_counts_{window}', 'volume_imbalance_20_max', 'wap3', 'wap6']
# ---204 MSE score: 0.5653; ---204 Corr score: 0.1585
# Not improved: 1
# +++108 MSE score: 0.5655; +++108 Corr score: 0.1577
# Not improved: 2
# ---182 MSE score: 0.5653; ---182 Corr score: 0.1586
# Not improved: 3
# +++51 MSE score: 0.5653; +++51 Corr score: 0.1586
# SUCCESSFULL ADDING OF increased_askbid_counts. Len: 127
# Last added cols: ['decreased_ask_counts_{window}', 'volume_imbalance_20_max', 'wap3', 'wap6', 'increased_askbid_counts']
# ---115 MSE score: 0.5658; ---115 Corr score: 0.1562
# Not improved: 1
# +++2 MSE score: 0.5653; +++2 Corr score: 0.1584
# Not improved: 2
# ---16 MSE score: 0.5653; ---16 Corr score: 0.1586
# Not improved: 3
# +++41 MSE score: 0.5655; +++41 Corr score: 0.1576
# Not improved: 4
# ---122 MSE score: 0.5656; ---122 Corr score: 0.1570
# Not improved: 5
# +++65 MSE score: 0.5655; +++65 Corr score: 0.1577
# Not improved: 6
# ---147 MSE score: 0.5653; ---147 Corr score: 0.1586
# Not improved: 7
# +++100 MSE score: 0.5654; +++100 Corr score: 0.1579
# Not improved: 8
# ---35 MSE score: 0.5653; ---35 Corr score: 0.1585
# Not improved: 9
# +++41 MSE score: 0.5655; +++41 Corr score: 0.1576
# Not improved: 10
# ---91 MSE score: 0.5653; ---91 Corr score: 0.1588
# SUCCESSFULL REMOVE OF ask_flatten_mean_50. Len: 126
# +++48 MSE score: 0.5652; +++48 Corr score: 0.1590
# SUCCESSFULL ADDING OF increased_bid_rank. Len: 127
# Last added cols: ['volume_imbalance_20_max', 'wap3', 'wap6', 'increased_askbid_counts', 'increased_bid_rank']
# ---164 MSE score: 0.5652; ---164 Corr score: 0.1589
# Not improved: 1
# +++144 MSE score: 0.5652; +++144 Corr score: 0.1591
# SUCCESSFULL ADDING OF mid_price_log_20. Len: 128
# Last added cols: ['wap3', 'wap6', 'increased_askbid_counts', 'increased_bid_rank', 'mid_price_log_20']
# ---146 MSE score: 0.5653; ---146 Corr score: 0.1588
# Not improved: 1
# +++111 MSE score: 0.5651; +++111 Corr score: 0.1596
# SUCCESSFULL ADDING OF ask_flatten_iqr_100. Len: 129
# Last added cols: ['wap6', 'increased_askbid_counts', 'increased_bid_rank', 'mid_price_log_20', 'ask_flatten_iqr_100']
# ---152 MSE score: 0.5652; ---152 Corr score: 0.1591
# Not improved: 1
# +++150 MSE score: 0.5652; +++150 Corr score: 0.1593
# Not improved: 2
# ---217 MSE score: 0.5651; ---217 Corr score: 0.1596
# Not improved: 3
# +++158 MSE score: 0.5651; +++158 Corr score: 0.1596
# Not improved: 4
# ---224 MSE score: 0.5651; ---224 Corr score: 0.1594
# Not improved: 5
# +++167 MSE score: 0.5651; +++167 Corr score: 0.1596
# SUCCESSFULL ADDING OF spread_rolling_std_20. Len: 130
# Last added cols: ['increased_askbid_counts', 'increased_bid_rank', 'mid_price_log_20', 'ask_flatten_iqr_100', 'spread_rolling_std_20']
# ---13 MSE score: 0.5651; ---13 Corr score: 0.1595
# Not improved: 1
# +++64 MSE score: 0.5652; +++64 Corr score: 0.1592
# Not improved: 2
# ---226 MSE score: 0.5652; ---226 Corr score: 0.1592
# Not improved: 3
# +++214 MSE score: 0.5651; +++214 Corr score: 0.1595
# Not improved: 4
# ---50 MSE score: 0.5654; ---50 Corr score: 0.1583
# Not improved: 5
# +++154 MSE score: 0.5651; +++154 Corr score: 0.1596
# SUCCESSFULL ADDING OF mid_price_min_diff_5. Len: 131
# Last added cols: ['increased_bid_rank', 'mid_price_log_20', 'ask_flatten_iqr_100', 'spread_rolling_std_20', 'mid_price_min_diff_5']
# ---88 MSE score: 0.5651; ---88 Corr score: 0.1597
# SUCCESSFULL REMOVE OF ewm_wap_flatten_25. Len: 130
# +++54 MSE score: 0.5651; +++54 Corr score: 0.1597
# Not improved: 1
# ---4 MSE score: 0.5652; ---4 Corr score: 0.1591
# Not improved: 2
# +++41 MSE score: 0.5653; +++41 Corr score: 0.1589
# Not improved: 3
# ---13 MSE score: 0.5651; ---13 Corr score: 0.1596
# Not improved: 4
# +++157 MSE score: 0.5651; +++157 Corr score: 0.1597
# SUCCESSFULL ADDING OF spread_rolling_std_5. Len: 131
# Last added cols: ['mid_price_log_20', 'ask_flatten_iqr_100', 'spread_rolling_std_20', 'mid_price_min_diff_5', 'spread_rolling_std_5']
# ---97 MSE score: 0.5653; ---97 Corr score: 0.1588
# Not improved: 1
# +++14 MSE score: 0.5649; +++14 Corr score: 0.1607
# SUCCESSFULL ADDING OF cum_volume_imbalance_1. Len: 132
# Last added cols: ['ask_flatten_iqr_100', 'spread_rolling_std_20', 'mid_price_min_diff_5', 'spread_rolling_std_5', 'cum_volume_imbalance_1']
# ---90 MSE score: 0.5693; ---90 Corr score: 0.1390
# Not improved: 1
# +++171 MSE score: 0.5650; +++171 Corr score: 0.1602
# Not improved: 2
# ---141 MSE score: 0.5649; ---141 Corr score: 0.1607
# Not improved: 3
# +++19 MSE score: 0.5649; +++19 Corr score: 0.1607
# Not improved: 4
# ---205 MSE score: 0.5649; ---205 Corr score: 0.1606
# Not improved: 5
# +++120 MSE score: 0.5649; +++120 Corr score: 0.1607
# SUCCESSFULL ADDING OF bid_flatten_kurtosis_100. Len: 133
# Last added cols: ['spread_rolling_std_20', 'mid_price_min_diff_5', 'spread_rolling_std_5', 'cum_volume_imbalance_1', 'bid_flatten_kurtosis_100']
# ---164 MSE score: 0.5649; ---164 Corr score: 0.1604
# Not improved: 1
# +++107 MSE score: 0.5649; +++107 Corr score: 0.1604
# Not improved: 2
# ---82 MSE score: 0.5649; ---82 Corr score: 0.1604
# Not improved: 3
# +++79 MSE score: 0.5649; +++79 Corr score: 0.1607
# Not improved: 4
# ---156 MSE score: 0.5649; ---156 Corr score: 0.1607
# Not improved: 5
# +++108 MSE score: 0.5650; +++108 Corr score: 0.1601
# Not improved: 6
# ---31 MSE score: 0.5649; ---31 Corr score: 0.1607
# Not improved: 7
# +++150 MSE score: 0.5649; +++150 Corr score: 0.1604
# Not improved: 8
# ---185 MSE score: 0.5649; ---185 Corr score: 0.1607
# Not improved: 9
# +++27 MSE score: 0.5648; +++27 Corr score: 0.1609
# SUCCESSFULL ADDING OF volume_imbalance_5. Len: 134
# Last added cols: ['mid_price_min_diff_5', 'spread_rolling_std_5', 'cum_volume_imbalance_1', 'bid_flatten_kurtosis_100', 'volume_imbalance_5']
# ---97 MSE score: 0.5650; ---97 Corr score: 0.1600
# Not improved: 1
# +++49 MSE score: 0.5648; +++49 Corr score: 0.1610
# SUCCESSFULL ADDING OF decreased_bid_counts. Len: 135
# Last added cols: ['spread_rolling_std_5', 'cum_volume_imbalance_1', 'bid_flatten_kurtosis_100', 'volume_imbalance_5', 'decreased_bid_counts']
# ---155 MSE score: 0.5648; ---155 Corr score: 0.1611
# SUCCESSFULL REMOVE OF mid_price_std_5. Len: 134
# +++151 MSE score: 0.5648; +++151 Corr score: 0.1611
# Not improved: 1
# ---51 MSE score: 0.5648; ---51 Corr score: 0.1611
# Not improved: 2
# +++110 MSE score: 0.5652; +++110 Corr score: 0.1591
# Not improved: 3
# ---10 MSE score: 0.5647; ---10 Corr score: 0.1613
# SUCCESSFULL REMOVE OF len_ratio. Len: 133
# +++151 MSE score: 0.5647; +++151 Corr score: 0.1613
# Not improved: 1
# ---152 MSE score: 0.5649; ---152 Corr score: 0.1608
# Not improved: 2
# +++162 MSE score: 0.5647; +++162 Corr score: 0.1613
# Not improved: 3
# ---135 MSE score: 0.5647; ---135 Corr score: 0.1613
# Not improved: 4
# +++190 MSE score: 0.5648; +++190 Corr score: 0.1612
# Not improved: 5
# ---43 MSE score: 0.5647; ---43 Corr score: 0.1613
# Not improved: 6
# +++127 MSE score: 0.5647; +++127 Corr score: 0.1613
# Not improved: 7
# ---197 MSE score: 0.5647; ---197 Corr score: 0.1613
# Not improved: 8
# +++87 MSE score: 0.5648; +++87 Corr score: 0.1610
# Not improved: 9
# ---135 MSE score: 0.5647; ---135 Corr score: 0.1613
# Not improved: 10
# +++39 MSE score: 0.5647; +++39 Corr score: 0.1614
# SUCCESSFULL ADDING OF volume_imbalance_9. Len: 134
# Last added cols: ['cum_volume_imbalance_1', 'bid_flatten_kurtosis_100', 'volume_imbalance_5', 'decreased_bid_counts', 'volume_imbalance_9']
# ---37 MSE score: 0.5647; ---37 Corr score: 0.1614
# Not improved: 1
# +++103 MSE score: 0.5648; +++103 Corr score: 0.1612
# Not improved: 2
# ---0 MSE score: 0.5647; ---0 Corr score: 0.1617
# SUCCESSFULL REMOVE OF ask_rate_0. Len: 133
# +++110 MSE score: 0.5651; +++110 Corr score: 0.1597
# Not improved: 1
# ---157 MSE score: 0.5647; ---157 Corr score: 0.1617
# SUCCESSFULL REMOVE OF spread_rolling_std_5. Len: 132
# +++159 MSE score: 0.5646; +++159 Corr score: 0.1617
# SUCCESSFULL ADDING OF mid_price_min_diff_10. Len: 133
# Last added cols: ['bid_flatten_kurtosis_100', 'volume_imbalance_5', 'decreased_bid_counts', 'volume_imbalance_9', 'mid_price_min_diff_10']
# ---133 MSE score: 0.5646; ---133 Corr score: 0.1618
# SUCCESSFULL REMOVE OF increased_ask_counts_5_volume. Len: 132
# +++130 MSE score: 0.5645; +++130 Corr score: 0.1623
# SUCCESSFULL ADDING OF decreased_bid_counts_{window}. Len: 133
# Last added cols: ['volume_imbalance_5', 'decreased_bid_counts', 'volume_imbalance_9', 'mid_price_min_diff_10', 'decreased_bid_counts_{window}']
# ---104 MSE score: 0.5644; ---104 Corr score: 0.1629
# SUCCESSFULL REMOVE OF flatten_spread_50_ewm. Len: 132
# +++160 MSE score: 0.5644; +++160 Corr score: 0.1629
# Not improved: 1
# ---156 MSE score: 0.5644; ---156 Corr score: 0.1629
# SUCCESSFULL REMOVE OF spread_rolling_mean_5. Len: 131
# +++61 MSE score: 0.5644; +++61 Corr score: 0.1629
# Not improved: 1
# ---72 MSE score: 0.5647; ---72 Corr score: 0.1613
# Not improved: 2
# +++36 MSE score: 0.5645; +++36 Corr score: 0.1627
# Not improved: 3
# ---31 MSE score: 0.5644; ---31 Corr score: 0.1629
# SUCCESSFULL REMOVE OF wap6. Len: 130
# +++158 MSE score: 0.5644; +++158 Corr score: 0.1628
# Not improved: 1
# ---83 MSE score: 0.5643; ---83 Corr score: 0.1636
# SUCCESSFULL REMOVE OF bid_flatten_skew_25. Len: 129
# +++5 MSE score: 0.5644; +++5 Corr score: 0.1629
# Not improved: 1
# ---21 MSE score: 0.5644; ---21 Corr score: 0.1631
# Not improved: 2
# +++98 MSE score: 0.5643; +++98 Corr score: 0.1636
# Not improved: 3
# ---126 MSE score: 0.5643; ---126 Corr score: 0.1636
# Not improved: 4
# +++191 MSE score: 0.5643; +++191 Corr score: 0.1636
# Not improved: 5
# ---78 MSE score: 0.5643; ---78 Corr score: 0.1634
# Not improved: 6
# +++102 MSE score: 0.5643; +++102 Corr score: 0.1637
# SUCCESSFULL ADDING OF bid_flatten_kurtosis_50. Len: 130
# Last added cols: ['decreased_bid_counts', 'volume_imbalance_9', 'mid_price_min_diff_10', 'decreased_bid_counts_{window}', 'bid_flatten_kurtosis_50']
# ---120 MSE score: 0.5643; ---120 Corr score: 0.1637
# SUCCESSFULL REMOVE OF bid_flatten_kurtosis_100. Len: 129
# +++23 MSE score: 0.5643; +++23 Corr score: 0.1635
# Not improved: 1
# ---208 MSE score: 0.5643; ---208 Corr score: 0.1636
# Not improved: 2
# +++52 MSE score: 0.5643; +++52 Corr score: 0.1637
# SUCCESSFULL ADDING OF decreased_askbid_counts. Len: 130
# Last added cols: ['volume_imbalance_9', 'mid_price_min_diff_10', 'decreased_bid_counts_{window}', 'bid_flatten_kurtosis_50', 'decreased_askbid_counts']
# ---218 MSE score: 0.5643; ---218 Corr score: 0.1636
# Not improved: 1
# +++17 MSE score: 0.5641; +++17 Corr score: 0.1648
# SUCCESSFULL ADDING OF cum_volume_imbalance_2. Len: 131
# Last added cols: ['mid_price_min_diff_10', 'decreased_bid_counts_{window}', 'bid_flatten_kurtosis_50', 'decreased_askbid_counts', 'cum_volume_imbalance_2']
# ---147 MSE score: 0.5641; ---147 Corr score: 0.1647
# Not improved: 1
# +++74 MSE score: 0.5645; +++74 Corr score: 0.1629
# Not improved: 2
# ---72 MSE score: 0.5644; ---72 Corr score: 0.1631
# Not improved: 3
# +++81 MSE score: 0.5638; +++81 Corr score: 0.1658
# SUCCESSFULL ADDING OF bid_flatten_std_25. Len: 132
# Last added cols: ['decreased_bid_counts_{window}', 'bid_flatten_kurtosis_50', 'decreased_askbid_counts', 'cum_volume_imbalance_2', 'bid_flatten_std_25']
# ---43 MSE score: 0.5638; ---43 Corr score: 0.1658
# Not improved: 1
# +++96 MSE score: 0.5639; +++96 Corr score: 0.1655
# Not improved: 2
# ---198 MSE score: 0.5639; ---198 Corr score: 0.1657
# Not improved: 3
# +++83 MSE score: 0.5640; +++83 Corr score: 0.1650
# Not improved: 4
# ---34 MSE score: 0.5639; ---34 Corr score: 0.1658
# Not improved: 5
# +++124 MSE score: 0.5638; +++124 Corr score: 0.1658
# SUCCESSFULL ADDING OF ewm_wap_flatten_100. Len: 133
# Last added cols: ['bid_flatten_kurtosis_50', 'decreased_askbid_counts', 'cum_volume_imbalance_2', 'bid_flatten_std_25', 'ewm_wap_flatten_100']
# ---93 MSE score: 0.5643; ---93 Corr score: 0.1636
# Not improved: 1
# +++5 MSE score: 0.5640; +++5 Corr score: 0.1650
# Not improved: 2
# ---195 MSE score: 0.5639; ---195 Corr score: 0.1658
# Not improved: 3
# +++63 MSE score: 0.5638; +++63 Corr score: 0.1664
# SUCCESSFULL ADDING OF bid_flatten_std_5. Len: 134
# Last added cols: ['decreased_askbid_counts', 'cum_volume_imbalance_2', 'bid_flatten_std_25', 'ewm_wap_flatten_100', 'bid_flatten_std_5']
# ---89 MSE score: 0.5630; ---89 Corr score: 0.1701
# SUCCESSFULL REMOVE OF ask_flatten_ewm_50. Len: 133
# +++7 MSE score: 0.5631; +++7 Corr score: 0.1696
# Not improved: 1
# ---82 MSE score: 0.5631; ---82 Corr score: 0.1694
# Not improved: 2
# +++53 MSE score: 0.5630; +++53 Corr score: 0.1701
# SUCCESSFULL ADDING OF ask_flatten_ewm_5. Len: 134
# Last added cols: ['cum_volume_imbalance_2', 'bid_flatten_std_25', 'ewm_wap_flatten_100', 'bid_flatten_std_5', 'ask_flatten_ewm_5']
# ---24 MSE score: 0.5630; ---24 Corr score: 0.1702
# SUCCESSFULL REMOVE OF volume_imbalance_4. Len: 133
# +++3 MSE score: 0.5630; +++3 Corr score: 0.1699
# Not improved: 1
# ---16 MSE score: 0.5630; ---16 Corr score: 0.1701
# Not improved: 2
# +++70 MSE score: 0.5630; +++70 Corr score: 0.1702
# SUCCESSFULL ADDING OF ewm_wap_flatten_5. Len: 134
# Last added cols: ['bid_flatten_std_25', 'ewm_wap_flatten_100', 'bid_flatten_std_5', 'ask_flatten_ewm_5', 'ewm_wap_flatten_5']
# ---58 MSE score: 0.5632; ---58 Corr score: 0.1689
# Not improved: 1
# +++8 MSE score: 0.5629; +++8 Corr score: 0.1705
# SUCCESSFULL ADDING OF ask_len. Len: 135
# Last added cols: ['ewm_wap_flatten_100', 'bid_flatten_std_5', 'ask_flatten_ewm_5', 'ewm_wap_flatten_5', 'ask_len']
# ---128 MSE score: 0.5629; ---128 Corr score: 0.1705
# Not improved: 1
# +++166 MSE score: 0.5630; +++166 Corr score: 0.1704
# Not improved: 2
# ---94 MSE score: 0.5630; ---94 Corr score: 0.1703
# Not improved: 3
# +++54 MSE score: 0.5629; +++54 Corr score: 0.1705
# SUCCESSFULL ADDING OF ask_flatten_len_5. Len: 136
# Last added cols: ['bid_flatten_std_5', 'ask_flatten_ewm_5', 'ewm_wap_flatten_5', 'ask_len', 'ask_flatten_len_5']
# ---212 MSE score: 0.5629; ---212 Corr score: 0.1706
# SUCCESSFULL REMOVE OF len_ratio_40_mean. Len: 135
# +++133 MSE score: 0.5629; +++133 Corr score: 0.1706
# Not improved: 1
# ---46 MSE score: 0.5630; ---46 Corr score: 0.1700
# Not improved: 2
# +++170 MSE score: 0.5629; +++170 Corr score: 0.1706
# SUCCESSFULL ADDING OF mid_price_std_40. Len: 136
# Last added cols: ['ask_flatten_ewm_5', 'ewm_wap_flatten_5', 'ask_len', 'ask_flatten_len_5', 'mid_price_std_40']
# ---93 MSE score: 0.5633; ---93 Corr score: 0.1687
# Not improved: 1
# +++196 MSE score: 0.5629; +++196 Corr score: 0.1706
# SUCCESSFULL ADDING OF volume_imbalance_20_mean. Len: 137
# Last added cols: ['ewm_wap_flatten_5', 'ask_len', 'ask_flatten_len_5', 'mid_price_std_40', 'volume_imbalance_20_mean']
# ---128 MSE score: 0.5629; ---128 Corr score: 0.1706
# Not improved: 1
# +++110 MSE score: 0.5630; +++110 Corr score: 0.1702
# Not improved: 2
# ---68 MSE score: 0.5632; ---68 Corr score: 0.1691
# Not improved: 3
# +++132 MSE score: 0.5629; +++132 Corr score: 0.1706
# SUCCESSFULL ADDING OF mid_price_log_3. Len: 138
# Last added cols: ['ask_len', 'ask_flatten_len_5', 'mid_price_std_40', 'volume_imbalance_20_mean', 'mid_price_log_3']
# ---216 MSE score: 0.5628; ---216 Corr score: 0.1710
# SUCCESSFULL REMOVE OF wap0_80_max. Len: 137
# +++220 MSE score: 0.5628; +++220 Corr score: 0.1710
# Not improved: 1
# ---21 MSE score: 0.5628; ---21 Corr score: 0.1709
# Not improved: 2
# +++86 MSE score: 0.5639; +++86 Corr score: 0.1659
# Not improved: 3
# ---35 MSE score: 0.5629; ---35 Corr score: 0.1708
# Not improved: 4
# +++33 MSE score: 0.5628; +++33 Corr score: 0.1709
# Not improved: 5
# ---53 MSE score: 0.5628; ---53 Corr score: 0.1710
# Not improved: 6
# +++57 MSE score: 0.5630; +++57 Corr score: 0.1699
# Not improved: 7
# ---143 MSE score: 0.5628; ---143 Corr score: 0.1710
# Not improved: 8
# +++73 MSE score: 0.5636; +++73 Corr score: 0.1672
# Not improved: 9
# ---215 MSE score: 0.5630; ---215 Corr score: 0.1703
# Not improved: 10
# +++79 MSE score: 0.5628; +++79 Corr score: 0.1710
# Not improved: 11
# ---138 MSE score: 0.5628; ---138 Corr score: 0.1710
# Not improved: 12
# +++10 MSE score: 0.5629; +++10 Corr score: 0.1708
# Not improved: 13
# ---35 MSE score: 0.5629; ---35 Corr score: 0.1708
# Not improved: 14
# +++227 MSE score: 0.5629; +++227 Corr score: 0.1704
# Not improved: 15
# ---205 MSE score: 0.5628; ---205 Corr score: 0.1709
# Not improved: 16
# +++168 MSE score: 0.5628; +++168 Corr score: 0.1711
# SUCCESSFULL ADDING OF mid_price_max_diff_40. Len: 138
# Last added cols: ['ask_flatten_len_5', 'mid_price_std_40', 'volume_imbalance_20_mean', 'mid_price_log_3', 'mid_price_max_diff_40']
# ---193 MSE score: 0.5628; ---193 Corr score: 0.1711
# SUCCESSFULL REMOVE OF wap1_20_mean. Len: 137
# +++145 MSE score: 0.5628; +++145 Corr score: 0.1711
# Not improved: 1
# ---8 MSE score: 0.5629; ---8 Corr score: 0.1707
# Not improved: 2
# +++73 MSE score: 0.5636; +++73 Corr score: 0.1672
# Not improved: 3
# ---218 MSE score: 0.5628; ---218 Corr score: 0.1710
# Not improved: 4
# +++133 MSE score: 0.5628; +++133 Corr score: 0.1711
# Not improved: 5
# ---215 MSE score: 0.5629; ---215 Corr score: 0.1705
# Not improved: 6
# +++87 MSE score: 0.5632; +++87 Corr score: 0.1693
# Not improved: 7
# ---126 MSE score: 0.5628; ---126 Corr score: 0.1710
# Not improved: 8
# +++190 MSE score: 0.5628; +++190 Corr score: 0.1710
# Not improved: 9
# ---70 MSE score: 0.5628; ---70 Corr score: 0.1711
# Not improved: 10
# +++57 MSE score: 0.5630; +++57 Corr score: 0.1700
# Not improved: 11
# ---116 MSE score: 0.5628; ---116 Corr score: 0.1712
# SUCCESSFULL REMOVE OF bid_flatten_mean_100. Len: 136
# +++84 MSE score: 0.5630; +++84 Corr score: 0.1701
# Not improved: 1
# ---134 MSE score: 0.5628; ---134 Corr score: 0.1712
# SUCCESSFULL REMOVE OF decreased_ask_counts_5_volume. Len: 135
# +++109 MSE score: 0.5638; +++109 Corr score: 0.1661
# Not improved: 1
# ---164 MSE score: 0.5628; ---164 Corr score: 0.1710
# Not improved: 2
# +++158 MSE score: 0.5628; +++158 Corr score: 0.1711
# Not improved: 3
# ---117 MSE score: 0.5628; ---117 Corr score: 0.1712
# Not improved: 4
# +++114 MSE score: 0.5631; +++114 Corr score: 0.1697
# Not improved: 5
# ---40 MSE score: 0.5628; ---40 Corr score: 0.1712
# SUCCESSFULL REMOVE OF wap9. Len: 134
# +++89 MSE score: 0.5635; +++89 Corr score: 0.1675
# Not improved: 1
# ---125 MSE score: 0.5627; ---125 Corr score: 0.1714
# SUCCESSFULL REMOVE OF increased_ask_counts_{window}. Len: 133
# +++191 MSE score: 0.5627; +++191 Corr score: 0.1714
# SUCCESSFULL ADDING OF wap0_20_std. Len: 134
# Last added cols: ['mid_price_std_40', 'volume_imbalance_20_mean', 'mid_price_log_3', 'mid_price_max_diff_40', 'wap0_20_std']
# ---137 MSE score: 0.5627; ---137 Corr score: 0.1713
# Not improved: 1
# +++71 MSE score: 0.5634; +++71 Corr score: 0.1681
# Not improved: 2
# ---149 MSE score: 0.5627; ---149 Corr score: 0.1714
# SUCCESSFULL REMOVE OF increased_ask_counts_80_volume. Len: 133
# +++219 MSE score: 0.5628; +++219 Corr score: 0.1712
# Not improved: 1
# ---102 MSE score: 0.5627; ---102 Corr score: 0.1714
# Not improved: 2
# +++134 MSE score: 0.5627; +++134 Corr score: 0.1714
# Not improved: 3
# ---67 MSE score: 0.5629; ---67 Corr score: 0.1705
# Not improved: 4
# +++216 MSE score: 0.5628; +++216 Corr score: 0.1710
# Not improved: 5
# ---55 MSE score: 0.5627; ---55 Corr score: 0.1714
# Not improved: 6
# +++221 MSE score: 0.5627; +++221 Corr score: 0.1714
# Not improved: 7
# ---136 MSE score: 0.5627; ---136 Corr score: 0.1714
# Not improved: 8
# +++73 MSE score: 0.5636; +++73 Corr score: 0.1674
# Not improved: 9
# ---228 MSE score: 0.5627; ---228 Corr score: 0.1714
# SUCCESSFULL REMOVE OF mid_price_ewm_80. Len: 132
# +++103 MSE score: 0.5635; +++103 Corr score: 0.1675
# Not improved: 1
# ---224 MSE score: 0.5627; ---224 Corr score: 0.1713
# Not improved: 2
# +++228 MSE score: 0.5627; +++228 Corr score: 0.1714
# Not improved: 3
# ---47 MSE score: 0.5627; ---47 Corr score: 0.1714
# SUCCESSFULL REMOVE OF increased_bid_counts. Len: 131
# +++74 MSE score: 0.5637; +++74 Corr score: 0.1670
# Not improved: 1
# ---93 MSE score: 0.5631; ---93 Corr score: 0.1695
# Not improved: 2
# +++116 MSE score: 0.5627; +++116 Corr score: 0.1714
# Not improved: 3
# ---16 MSE score: 0.5627; ---16 Corr score: 0.1714
# Not improved: 4
# +++26 MSE score: 0.5627; +++26 Corr score: 0.1715
# SUCCESSFULL ADDING OF cum_volume_imbalance_5. Len: 132
# Last added cols: ['volume_imbalance_20_mean', 'mid_price_log_3', 'mid_price_max_diff_40', 'wap0_20_std', 'cum_volume_imbalance_5']
# ---170 MSE score: 0.5627; ---170 Corr score: 0.1715
# Not improved: 1
# +++106 MSE score: 0.5634; +++106 Corr score: 0.1684
# Not improved: 2
# ---186 MSE score: 0.5627; ---186 Corr score: 0.1715
# Not improved: 3
# +++40 MSE score: 0.5627; +++40 Corr score: 0.1715
# Not improved: 4
# ---187 MSE score: 0.5627; ---187 Corr score: 0.1714
# Not improved: 5
# +++116 MSE score: 0.5627; +++116 Corr score: 0.1714
# Not improved: 6
# ---154 MSE score: 0.5627; ---154 Corr score: 0.1715
# SUCCESSFULL REMOVE OF mid_price_min_diff_5. Len: 131
# +++127 MSE score: 0.5627; +++127 Corr score: 0.1715
# Not improved: 1
# ---161 MSE score: 0.5627; ---161 Corr score: 0.1716
# SUCCESSFULL REMOVE OF spread_rolling_mean_10. Len: 130
# +++6 MSE score: 0.5628; +++6 Corr score: 0.1713
# Not improved: 1
# ---112 MSE score: 0.5627; ---112 Corr score: 0.1716
# Not improved: 2
# +++31 MSE score: 0.5627; +++31 Corr score: 0.1716
# Not improved: 3
# ---80 MSE score: 0.5627; ---80 Corr score: 0.1717
# SUCCESSFULL REMOVE OF bid_flatten_mean_25. Len: 129
# +++157 MSE score: 0.5627; +++157 Corr score: 0.1717
# Not improved: 1
# ---117 MSE score: 0.5627; ---117 Corr score: 0.1717
# Not improved: 2
# +++171 MSE score: 0.5628; +++171 Corr score: 0.1710
# Not improved: 3
# ---182 MSE score: 0.5627; ---182 Corr score: 0.1717
# Not improved: 4
# +++2 MSE score: 0.5627; +++2 Corr score: 0.1716
# Not improved: 5
# ---67 MSE score: 0.5629; ---67 Corr score: 0.1708
# Not improved: 6
# +++106 MSE score: 0.5634; +++106 Corr score: 0.1684
# Not improved: 7
# ---218 MSE score: 0.5627; ---218 Corr score: 0.1716
# Not improved: 8
# +++105 MSE score: 0.5632; +++105 Corr score: 0.1689
# Not improved: 9
# ---69 MSE score: 0.5627; ---69 Corr score: 0.1717
# Not improved: 10
# +++225 MSE score: 0.5627; +++225 Corr score: 0.1718
# SUCCESSFULL ADDING OF len_ratio_80_std. Len: 130
# Last added cols: ['mid_price_log_3', 'mid_price_max_diff_40', 'wap0_20_std', 'cum_volume_imbalance_5', 'len_ratio_80_std']
# ---29 MSE score: 0.5627; ---29 Corr score: 0.1717
# Not improved: 1
# +++116 MSE score: 0.5627; +++116 Corr score: 0.1717
# Not improved: 2
# ---132 MSE score: 0.5627; ---132 Corr score: 0.1718
# Not improved: 3
# +++87 MSE score: 0.5631; +++87 Corr score: 0.1697
# Not improved: 4
# ---59 MSE score: 0.5629; ---59 Corr score: 0.1706
# Not improved: 5
# +++36 MSE score: 0.5627; +++36 Corr score: 0.1716
# Not improved: 6
# ---37 MSE score: 0.5627; ---37 Corr score: 0.1718
# Not improved: 7
# +++7 MSE score: 0.5628; +++7 Corr score: 0.1713
# Not improved: 8
# ---185 MSE score: 0.5627; ---185 Corr score: 0.1718
# Not improved: 9
# +++162 MSE score: 0.5627; +++162 Corr score: 0.1718
# Not improved: 10
# ---13 MSE score: 0.5626; ---13 Corr score: 0.1718
# SUCCESSFULL REMOVE OF wap0. Len: 129
# +++199 MSE score: 0.5627; +++199 Corr score: 0.1718
# Not improved: 1
# ---48 MSE score: 0.5627; ---48 Corr score: 0.1716
# Not improved: 2
# +++190 MSE score: 0.5627; +++190 Corr score: 0.1718
# Not improved: 3
# ---186 MSE score: 0.5627; ---186 Corr score: 0.1718
# Not improved: 4
# +++36 MSE score: 0.5627; +++36 Corr score: 0.1716
# Not improved: 5
# ---184 MSE score: 0.5626; ---184 Corr score: 0.1718
# Not improved: 6
# +++123 MSE score: 0.5631; +++123 Corr score: 0.1695
# Not improved: 7
# ---230 MSE score: 0.5632; ---230 Corr score: 0.1693
# Not improved: 8
# +++85 MSE score: 0.5637; +++85 Corr score: 0.1668
# Not improved: 9
# ---167 MSE score: 0.5626; ---167 Corr score: 0.1719
# SUCCESSFULL REMOVE OF spread_rolling_std_20. Len: 128
# +++20 MSE score: 0.5626; +++20 Corr score: 0.1720
# SUCCESSFULL ADDING OF cum_volume_imbalance_3. Len: 129
# Last added cols: ['mid_price_max_diff_40', 'wap0_20_std', 'cum_volume_imbalance_5', 'len_ratio_80_std', 'cum_volume_imbalance_3']
# ---206 MSE score: 0.5626; ---206 Corr score: 0.1720
# Not improved: 1
# +++23 MSE score: 0.5626; +++23 Corr score: 0.1721
# SUCCESSFULL ADDING OF cum_volume_imbalance_4. Len: 130
# Last added cols: ['wap0_20_std', 'cum_volume_imbalance_5', 'len_ratio_80_std', 'cum_volume_imbalance_3', 'cum_volume_imbalance_4']
# ---97 MSE score: 0.5628; ---97 Corr score: 0.1711
# Not improved: 1
# +++9 MSE score: 0.5627; +++9 Corr score: 0.1716
# Not improved: 2
# ---76 MSE score: 0.5625; ---76 Corr score: 0.1727
# SUCCESSFULL REMOVE OF ask_flatten_skew_25. Len: 129
# +++120 MSE score: 0.5625; +++120 Corr score: 0.1726
# Not improved: 1
# ---146 MSE score: 0.5625; ---146 Corr score: 0.1724
# Not improved: 2
# +++221 MSE score: 0.5625; +++221 Corr score: 0.1726
# Not improved: 3
# ---20 MSE score: 0.5625; ---20 Corr score: 0.1725
# Not improved: 4
# +++76 MSE score: 0.5626; +++76 Corr score: 0.1721
# Not improved: 5
# ---102 MSE score: 0.5625; ---102 Corr score: 0.1726
# Not improved: 6
# +++229 MSE score: 0.5625; +++229 Corr score: 0.1725
# Not improved: 7
# ---188 MSE score: 0.5626; ---188 Corr score: 0.1723
# Not improved: 8
# +++227 MSE score: 0.5626; +++227 Corr score: 0.1719
# Not improved: 9
# ---164 MSE score: 0.5625; ---164 Corr score: 0.1725
# Not improved: 10
# +++6 MSE score: 0.5625; +++6 Corr score: 0.1724
# Not improved: 11
# ---16 MSE score: 0.5625; ---16 Corr score: 0.1726
# Not improved: 12
# +++110 MSE score: 0.5625; +++110 Corr score: 0.1725
# Not improved: 13
# ---128 MSE score: 0.5625; ---128 Corr score: 0.1727
# SUCCESSFULL REMOVE OF decreased_ask_counts_3_volume. Len: 128
# +++171 MSE score: 0.5626; +++171 Corr score: 0.1720
# Not improved: 1
# ---75 MSE score: 0.5624; ---75 Corr score: 0.1731
# SUCCESSFULL REMOVE OF ask_flatten_iqr_25. Len: 127
# +++209 MSE score: 0.5624; +++209 Corr score: 0.1731
# Not improved: 1
# ---195 MSE score: 0.5624; ---195 Corr score: 0.1731
# Not improved: 2
# +++228 MSE score: 0.5624; +++228 Corr score: 0.1731
# Not improved: 3
# ---225 MSE score: 0.5624; ---225 Corr score: 0.1731
# Not improved: 4
# +++77 MSE score: 0.5624; +++77 Corr score: 0.1732
# SUCCESSFULL ADDING OF ask_flatten_kurtosis_25. Len: 128
# Last added cols: ['cum_volume_imbalance_5', 'len_ratio_80_std', 'cum_volume_imbalance_3', 'cum_volume_imbalance_4', 'ask_flatten_kurtosis_25']
# ---8 MSE score: 0.5625; ---8 Corr score: 0.1726
# Not improved: 1
# +++47 MSE score: 0.5624; +++47 Corr score: 0.1732
# Not improved: 2
# ---112 MSE score: 0.5624; ---112 Corr score: 0.1733
# SUCCESSFULL REMOVE OF ask_flatten_skew_100. Len: 127
# +++166 MSE score: 0.5624; +++166 Corr score: 0.1730
# Not improved: 1
# ---59 MSE score: 0.5626; ---59 Corr score: 0.1722
# Not improved: 2
# +++103 MSE score: 0.5634; +++103 Corr score: 0.1679
# Not improved: 3
# ---174 MSE score: 0.5624; ---174 Corr score: 0.1732
# Not improved: 4
# +++108 MSE score: 0.5635; +++108 Corr score: 0.1677
# Not improved: 5
# ---124 MSE score: 0.5623; ---124 Corr score: 0.1734
# SUCCESSFULL REMOVE OF ewm_wap_flatten_100. Len: 126
# +++104 MSE score: 0.5634; +++104 Corr score: 0.1681
# Not improved: 1
# ---21 MSE score: 0.5624; ---21 Corr score: 0.1730
# Not improved: 2
# +++171 MSE score: 0.5625; +++171 Corr score: 0.1727
# Not improved: 3
# ---139 MSE score: 0.5623; ---139 Corr score: 0.1734
# Not improved: 4
# +++87 MSE score: 0.5629; +++87 Corr score: 0.1705
# Not improved: 5
# ---59 MSE score: 0.5625; ---59 Corr score: 0.1723
# Not improved: 6
# +++2 MSE score: 0.5623; +++2 Corr score: 0.1733
# Not improved: 7
# ---225 MSE score: 0.5623; ---225 Corr score: 0.1733
# Not improved: 8
# +++179 MSE score: 0.5624; +++179 Corr score: 0.1733
# Not improved: 9
# ---186 MSE score: 0.5623; ---186 Corr score: 0.1733
# Not improved: 10
# +++153 MSE score: 0.5623; +++153 Corr score: 0.1734
# Not improved: 11
# ---4 MSE score: 0.5626; ---4 Corr score: 0.1723
# Not improved: 12
# +++87 MSE score: 0.5629; +++87 Corr score: 0.1705
# Not improved: 13
# ---224 MSE score: 0.5624; ---224 Corr score: 0.1733
# Not improved: 14
# +++64 MSE score: 0.5623; +++64 Corr score: 0.1734
# Not improved: 15
# ---50 MSE score: 0.5625; ---50 Corr score: 0.1724
# Not improved: 16
# +++105 MSE score: 0.5631; +++105 Corr score: 0.1695
# Not improved: 17
# ---21 MSE score: 0.5624; ---21 Corr score: 0.1730
# Not improved: 18
# +++100 MSE score: 0.5624; +++100 Corr score: 0.1732
# Not improved: 19
# ---175 MSE score: 0.5623; ---175 Corr score: 0.1735
# SUCCESSFULL REMOVE OF mid_price_std_80. Len: 125
# +++163 MSE score: 0.5623; +++163 Corr score: 0.1734
# Not improved: 1
# ---60 MSE score: 0.5623; ---60 Corr score: 0.1735
# SUCCESSFULL REMOVE OF bid_flatten_ewm_5. Len: 124
# +++160 MSE score: 0.5623; +++160 Corr score: 0.1734
# Not improved: 1
# ---122 MSE score: 0.5639; ---122 Corr score: 0.1655
# Not improved: 2
# +++228 MSE score: 0.5623; +++228 Corr score: 0.1735
# Not improved: 3
# ---201 MSE score: 0.5623; ---201 Corr score: 0.1734
# Not improved: 4
# +++73 MSE score: 0.5635; +++73 Corr score: 0.1677
# Not improved: 5
# ---102 MSE score: 0.5623; ---102 Corr score: 0.1734
# Not improved: 6
# +++154 MSE score: 0.5623; +++154 Corr score: 0.1735
# Not improved: 7
# ---22 MSE score: 0.5623; ---22 Corr score: 0.1735
# SUCCESSFULL REMOVE OF wap3. Len: 123
# +++161 MSE score: 0.5623; +++161 Corr score: 0.1734
# Not improved: 1
# ---184 MSE score: 0.5623; ---184 Corr score: 0.1735
# Not improved: 2
# +++228 MSE score: 0.5623; +++228 Corr score: 0.1735
# Not improved: 3
# ---27 MSE score: 0.5623; ---27 Corr score: 0.1735
# SUCCESSFULL REMOVE OF volume_imbalance_5. Len: 122
# +++148 MSE score: 0.5623; +++148 Corr score: 0.1734
# Not improved: 1
# ---138 MSE score: 0.5623; ---138 Corr score: 0.1735
# Not improved: 2
# +++40 MSE score: 0.5623; +++40 Corr score: 0.1735
# SUCCESSFULL ADDING OF wap9. Len: 123
# Last added cols: ['len_ratio_80_std', 'cum_volume_imbalance_3', 'cum_volume_imbalance_4', 'ask_flatten_kurtosis_25', 'wap9']
# ---178 MSE score: 0.5623; ---178 Corr score: 0.1735
# Not improved: 1
# +++161 MSE score: 0.5623; +++161 Corr score: 0.1734
# Not improved: 2
# ---226 MSE score: 0.5625; ---226 Corr score: 0.1726
# Not improved: 3
# +++41 MSE score: 0.5626; +++41 Corr score: 0.1721
# Not improved: 4
# ---18 MSE score: 0.5628; ---18 Corr score: 0.1711
# Not improved: 5
# +++75 MSE score: 0.5624; +++75 Corr score: 0.1729
# Not improved: 6
# ---66 MSE score: 0.5623; ---66 Corr score: 0.1734
# Not improved: 7
# +++71 MSE score: 0.5633; +++71 Corr score: 0.1689
# Not improved: 8
# ---143 MSE score: 0.5623; ---143 Corr score: 0.1735
# Not improved: 9
# +++123 MSE score: 0.5628; +++123 Corr score: 0.1712
# Not improved: 10
# ---126 MSE score: 0.5623; ---126 Corr score: 0.1733
# Not improved: 11
# +++98 MSE score: 0.5624; +++98 Corr score: 0.1732
# Not improved: 12
# ---136 MSE score: 0.5623; ---136 Corr score: 0.1735
# Not improved: 13
# +++200 MSE score: 0.5623; +++200 Corr score: 0.1735
# Not improved: 14
# ---201 MSE score: 0.5623; ---201 Corr score: 0.1734
# Not improved: 15
# +++2 MSE score: 0.5623; +++2 Corr score: 0.1734
# ...
# ---186 MSE score: 0.5235; ---186 Corr score: 0.1582
# Not improved: 2
# +++22 MSE score: 0.5235; +++22 Corr score: 0.1583
# Not improved: 3
# ---96 MSE score: 0.5235; ---96 Corr score: 0.1583
# Not improved: 4
# +++97 MSE score: 0.5240; +++97 Corr score: 0.1554
# Not improved: 5
# ---114 MSE score: 0.5235; ---114 Corr score: 0.1580
# Not improved: 6
# +++57 MSE score: 0.5235; +++57 Corr score: 0.1581
# Not improved: 7
# ---25 MSE score: 0.5234; ---25 Corr score: 0.1584
# SUCCESSFULL REMOVE OF wap4. Len: 127
# +++124 MSE score: 0.5234; +++124 Corr score: 0.1584
# Not improved: 1
# ---185 MSE score: 0.5234; ---185 Corr score: 0.1584
# Not improved: 2
# +++170 MSE score: 0.5234; +++170 Corr score: 0.1583
# Not improved: 3
# ---150 MSE score: 0.5236; ---150 Corr score: 0.1574
# Not improved: 4
# +++32 MSE score: 0.5234; +++32 Corr score: 0.1584
# Not improved: 5
# ---15 MSE score: 0.5239; ---15 Corr score: 0.1560
# Not improved: 6
# +++67 MSE score: 0.5235; +++67 Corr score: 0.1581
# Not improved: 7
# ---173 MSE score: 0.5235; ---173 Corr score: 0.1581
# Not improved: 8
# +++22 MSE score: 0.5234; +++22 Corr score: 0.1584
# Not improved: 9
# ---141 MSE score: 0.5234; ---141 Corr score: 0.1584
# Not improved: 10
# +++100 MSE score: 0.5234; +++100 Corr score: 0.1584
# Not improved: 11
# ---84 MSE score: 0.5234; ---84 Corr score: 0.1583
# Not improved: 12
# +++109 MSE score: 0.5235; +++109 Corr score: 0.1583
# Not improved: 13
# ---33 MSE score: 0.5234; ---33 Corr score: 0.1586
# SUCCESSFULL REMOVE OF volume_imbalance_7. Len: 126
# +++72 MSE score: 0.5234; +++72 Corr score: 0.1585
# Not improved: 1
# ---220 MSE score: 0.5234; ---220 Corr score: 0.1585
# Not improved: 2
# +++118 MSE score: 0.5235; +++118 Corr score: 0.1583
# Not improved: 3
# ---220 MSE score: 0.5234; ---220 Corr score: 0.1585
# Not improved: 4
# +++50 MSE score: 0.5233; +++50 Corr score: 0.1591
# SUCCESSFULL ADDING OF decreased_bid_rank. Len: 127
# Last added cols: ['mid_price_min_diff_10', 'mid_price_log_10', 'bid_flatten_mean_100', 'bid_flatten_ewm_50', 'decreased_bid_rank']
# ---198 MSE score: 0.5234; ---198 Corr score: 0.1590
# Not improved: 1
# +++23 MSE score: 0.5235; +++23 Corr score: 0.1584
# Not improved: 2
# ---178 MSE score: 0.5234; ---178 Corr score: 0.1590
# Not improved: 3
# +++100 MSE score: 0.5233; +++100 Corr score: 0.1591
# Not improved: 4
# ---119 MSE score: 0.5233; ---119 Corr score: 0.1591
# SUCCESSFULL REMOVE OF bid_flatten_skew_100. Len: 126
# +++209 MSE score: 0.5233; +++209 Corr score: 0.1592
# SUCCESSFULL ADDING OF volume_imbalance_40_max. Len: 127
# Last added cols: ['mid_price_log_10', 'bid_flatten_mean_100', 'bid_flatten_ewm_50', 'decreased_bid_rank', 'volume_imbalance_40_max']
# ---106 MSE score: 0.5234; ---106 Corr score: 0.1587
# Not improved: 1
# +++219 MSE score: 0.5234; +++219 Corr score: 0.1586
# Not improved: 2
# ---113 MSE score: 0.5233; ---113 Corr score: 0.1591
# Not improved: 3
# +++170 MSE score: 0.5233; +++170 Corr score: 0.1591
# Not improved: 4
# ---189 MSE score: 0.5233; ---189 Corr score: 0.1592
# SUCCESSFULL REMOVE OF len_ratio_10_std. Len: 126
# +++20 MSE score: 0.5235; +++20 Corr score: 0.1583
# Not improved: 1
# ---4 MSE score: 0.5234; ---4 Corr score: 0.1590
# Not improved: 2
# +++215 MSE score: 0.5234; +++215 Corr score: 0.1588
# Not improved: 3
# ---200 MSE score: 0.5233; ---200 Corr score: 0.1591
# Not improved: 4
# +++225 MSE score: 0.5233; +++225 Corr score: 0.1592
# Not improved: 5
# ---116 MSE score: 0.5234; ---116 Corr score: 0.1588
# Not improved: 6
# +++118 MSE score: 0.5234; +++118 Corr score: 0.1590
# Not improved: 7
# ---58 MSE score: 0.5233; ---58 Corr score: 0.1592
# Not improved: 8
# +++189 MSE score: 0.5233; +++189 Corr score: 0.1592
# Not improved: 9
# ---173 MSE score: 0.5234; ---173 Corr score: 0.1589
# Not improved: 10
# +++36 MSE score: 0.5233; +++36 Corr score: 0.1592
# SUCCESSFULL ADDING OF volume_imbalance_8. Len: 127
# Last added cols: ['bid_flatten_mean_100', 'bid_flatten_ewm_50', 'decreased_bid_rank', 'volume_imbalance_40_max', 'volume_imbalance_8']
# ---17 MSE score: 0.5232; ---17 Corr score: 0.1596
# SUCCESSFULL REMOVE OF cum_volume_imbalance_2. Len: 126
# +++174 MSE score: 0.5233; +++174 Corr score: 0.1594
# Not improved: 1
# ---64 MSE score: 0.5232; ---64 Corr score: 0.1595
# Not improved: 2
# +++32 MSE score: 0.5233; +++32 Corr score: 0.1594
# Not improved: 3
# ---177 MSE score: 0.5233; ---177 Corr score: 0.1592
# Not improved: 4
# +++119 MSE score: 0.5232; +++119 Corr score: 0.1596
# SUCCESSFULL ADDING OF bid_flatten_skew_100. Len: 127
# Last added cols: ['bid_flatten_ewm_50', 'decreased_bid_rank', 'volume_imbalance_40_max', 'volume_imbalance_8', 'bid_flatten_skew_100']
# ---89 MSE score: 0.5232; ---89 Corr score: 0.1596
# SUCCESSFULL REMOVE OF ask_flatten_ewm_50. Len: 126
# +++117 MSE score: 0.5234; +++117 Corr score: 0.1587
# Not improved: 1
# ---139 MSE score: 0.5232; ---139 Corr score: 0.1596
# SUCCESSFULL REMOVE OF volume_imbalance_diff_10. Len: 125
# +++162 MSE score: 0.5232; +++162 Corr score: 0.1596
# Not improved: 1
# ---134 MSE score: 0.5232; ---134 Corr score: 0.1596
# Not improved: 2
# +++100 MSE score: 0.5232; +++100 Corr score: 0.1596
# Not improved: 3
# ---82 MSE score: 0.5233; ---82 Corr score: 0.1593
# Not improved: 4
# +++108 MSE score: 0.5232; +++108 Corr score: 0.1599
# SUCCESSFULL ADDING OF ask_flatten_len_100. Len: 126
# Last added cols: ['decreased_bid_rank', 'volume_imbalance_40_max', 'volume_imbalance_8', 'bid_flatten_skew_100', 'ask_flatten_len_100']
# ---205 MSE score: 0.5232; ---205 Corr score: 0.1597
# Not improved: 1
# +++162 MSE score: 0.5232; +++162 Corr score: 0.1599
# Not improved: 2
# ---179 MSE score: 0.5232; ---179 Corr score: 0.1599
# Not improved: 3
# +++174 MSE score: 0.5232; +++174 Corr score: 0.1597
# Not improved: 4
# ---70 MSE score: 0.5232; ---70 Corr score: 0.1599
# Not improved: 5
# +++144 MSE score: 0.5232; +++144 Corr score: 0.1597
# Not improved: 6
# ---171 MSE score: 0.5232; ---171 Corr score: 0.1599
# Not improved: 7
# +++27 MSE score: 0.5232; +++27 Corr score: 0.1596
# Not improved: 8
# ---43 MSE score: 0.5232; ---43 Corr score: 0.1597
# Not improved: 9
# +++217 MSE score: 0.5232; +++217 Corr score: 0.1598
# Not improved: 10
# ---84 MSE score: 0.5232; ---84 Corr score: 0.1598
# Not improved: 11
# +++47 MSE score: 0.5232; +++47 Corr score: 0.1599
# SUCCESSFULL ADDING OF increased_bid_counts. Len: 127
# Last added cols: ['volume_imbalance_40_max', 'volume_imbalance_8', 'bid_flatten_skew_100', 'ask_flatten_len_100', 'increased_bid_counts']
# ---110 MSE score: 0.5234; ---110 Corr score: 0.1591
# Not improved: 1
# +++206 MSE score: 0.5232; +++206 Corr score: 0.1599
# SUCCESSFULL ADDING OF wap1_40_std. Len: 128
# Last added cols: ['volume_imbalance_8', 'bid_flatten_skew_100', 'ask_flatten_len_100', 'increased_bid_counts', 'wap1_40_std']
# ---65 MSE score: 0.5232; ---65 Corr score: 0.1598
# Not improved: 1
# +++67 MSE score: 0.5232; +++67 Corr score: 0.1596
# Not improved: 2
# ---39 MSE score: 0.5232; ---39 Corr score: 0.1597
# Not improved: 3
# +++23 MSE score: 0.5234; +++23 Corr score: 0.1586
# Not improved: 4
# ---137 MSE score: 0.5232; ---137 Corr score: 0.1599
# Not improved: 5
# +++127 MSE score: 0.5232; +++127 Corr score: 0.1599
# Not improved: 6
# ---5 MSE score: 0.5232; ---5 Corr score: 0.1597
# Not improved: 7
# +++124 MSE score: 0.5232; +++124 Corr score: 0.1596
# Not improved: 8
# ---60 MSE score: 0.5232; ---60 Corr score: 0.1599
# Not improved: 9
# +++225 MSE score: 0.5232; +++225 Corr score: 0.1599
# Not improved: 10
# ---0 MSE score: 0.5232; ---0 Corr score: 0.1599
# Not improved: 11
# +++41 MSE score: 0.5232; +++41 Corr score: 0.1596
# Not improved: 12
# ---192 MSE score: 0.5232; ---192 Corr score: 0.1599
# Not improved: 13
# +++127 MSE score: 0.5232; +++127 Corr score: 0.1599
# Not improved: 14
# ---45 MSE score: 0.5232; ---45 Corr score: 0.1599
# Not improved: 15
# +++219 MSE score: 0.5233; +++219 Corr score: 0.1591
# Not improved: 16
# ---202 MSE score: 0.5232; ---202 Corr score: 0.1598
# Not improved: 17
# +++31 MSE score: 0.5232; +++31 Corr score: 0.1597
# Not improved: 18
# ---18 MSE score: 0.5231; ---18 Corr score: 0.1601
# SUCCESSFULL REMOVE OF volume_imbalance_2. Len: 127
# +++182 MSE score: 0.5231; +++182 Corr score: 0.1601
# SUCCESSFULL ADDING OF wap1_10_std. Len: 128
# Last added cols: ['bid_flatten_skew_100', 'ask_flatten_len_100', 'increased_bid_counts', 'wap1_40_std', 'wap1_10_std']
# ---93 MSE score: 0.5231; ---93 Corr score: 0.1601
# SUCCESSFULL REMOVE OF ask_flatten_iqr_50. Len: 127
# +++32 MSE score: 0.5232; +++32 Corr score: 0.1600
# Not improved: 1
# ---179 MSE score: 0.5231; ---179 Corr score: 0.1601
# Not improved: 2
# +++189 MSE score: 0.5231; +++189 Corr score: 0.1601
# SUCCESSFULL ADDING OF len_ratio_10_std. Len: 128
# Last added cols: ['ask_flatten_len_100', 'increased_bid_counts', 'wap1_40_std', 'wap1_10_std', 'len_ratio_10_std']
# ---110 MSE score: 0.5233; ---110 Corr score: 0.1592
# Not improved: 1
# +++147 MSE score: 0.5231; +++147 Corr score: 0.1601
# Not improved: 2
# ---114 MSE score: 0.5231; ---114 Corr score: 0.1602
# SUCCESSFULL REMOVE OF bid_flatten_ewm_100. Len: 127
# +++112 MSE score: 0.5232; +++112 Corr score: 0.1601
# Not improved: 1
# ---149 MSE score: 0.5233; ---149 Corr score: 0.1595
# Not improved: 2
# +++53 MSE score: 0.5231; +++53 Corr score: 0.1602
# SUCCESSFULL ADDING OF ask_flatten_ewm_5. Len: 128
# Last added cols: ['increased_bid_counts', 'wap1_40_std', 'wap1_10_std', 'len_ratio_10_std', 'ask_flatten_ewm_5']
# ---48 MSE score: 0.5233; ---48 Corr score: 0.1591
# Not improved: 1
# +++69 MSE score: 0.5231; +++69 Corr score: 0.1602
# SUCCESSFULL ADDING OF wap_flatten_5. Len: 129
# Last added cols: ['wap1_40_std', 'wap1_10_std', 'len_ratio_10_std', 'ask_flatten_ewm_5', 'wap_flatten_5']
# ---180 MSE score: 0.5231; ---180 Corr score: 0.1602
# Not improved: 1
# +++102 MSE score: 0.5232; +++102 Corr score: 0.1599
# Not improved: 2
# ---179 MSE score: 0.5231; ---179 Corr score: 0.1602
# Not improved: 3
# +++29 MSE score: 0.5231; +++29 Corr score: 0.1602
# SUCCESSFULL ADDING OF cum_volume_imbalance_6. Len: 130
# Last added cols: ['wap1_10_std', 'len_ratio_10_std', 'ask_flatten_ewm_5', 'wap_flatten_5', 'cum_volume_imbalance_6']
# ---65 MSE score: 0.5231; ---65 Corr score: 0.1602
# Not improved: 1
# +++132 MSE score: 0.5231; +++132 Corr score: 0.1602
# SUCCESSFULL ADDING OF mid_price_log_3. Len: 131
# Last added cols: ['len_ratio_10_std', 'ask_flatten_ewm_5', 'wap_flatten_5', 'cum_volume_imbalance_6', 'mid_price_log_3']
# ---198 MSE score: 0.5231; ---198 Corr score: 0.1602
# Not improved: 1
# +++117 MSE score: 0.5233; +++117 Corr score: 0.1592
# Not improved: 2
# ---121 MSE score: 0.5234; ---121 Corr score: 0.1584
# Not improved: 3
# +++101 MSE score: 0.5231; +++101 Corr score: 0.1603
# SUCCESSFULL ADDING OF bid_flatten_skew_50. Len: 132
# Last added cols: ['ask_flatten_ewm_5', 'wap_flatten_5', 'cum_volume_imbalance_6', 'mid_price_log_3', 'bid_flatten_skew_50']
# ---213 MSE score: 0.5231; ---213 Corr score: 0.1603
# SUCCESSFULL REMOVE OF len_ratio_40_std. Len: 131
# +++41 MSE score: 0.5232; +++41 Corr score: 0.1600
# Not improved: 1
# ---166 MSE score: 0.5231; ---166 Corr score: 0.1601
# Not improved: 2
# +++102 MSE score: 0.5232; +++102 Corr score: 0.1600
# Not improved: 3
# ---50 MSE score: 0.5232; ---50 Corr score: 0.1598
# Not improved: 4
# +++169 MSE score: 0.5232; +++169 Corr score: 0.1600
# Not improved: 5
# ---163 MSE score: 0.5231; ---163 Corr score: 0.1602
# Not improved: 6
# +++90 MSE score: 0.5232; +++90 Corr score: 0.1597
# Not improved: 7
# ---198 MSE score: 0.5231; ---198 Corr score: 0.1602
# Not improved: 8
# +++21 MSE score: 0.5231; +++21 Corr score: 0.1604
# SUCCESSFULL ADDING OF volume_imbalance_3. Len: 132
# Last added cols: ['wap_flatten_5', 'cum_volume_imbalance_6', 'mid_price_log_3', 'bid_flatten_skew_50', 'volume_imbalance_3']
# ---4 MSE score: 0.5231; ---4 Corr score: 0.1601
# Not improved: 1
# +++103 MSE score: 0.5232; +++103 Corr score: 0.1597
# Not improved: 2
# ---142 MSE score: 0.5231; ---142 Corr score: 0.1603
# Not improved: 3
# +++226 MSE score: 0.5232; +++226 Corr score: 0.1596
# Not improved: 4
# ---13 MSE score: 0.5231; ---13 Corr score: 0.1604
# SUCCESSFULL REMOVE OF wap0. Len: 131
# +++160 MSE score: 0.5231; +++160 Corr score: 0.1604
# SUCCESSFULL ADDING OF mid_price_std_10. Len: 132
# Last added cols: ['cum_volume_imbalance_6', 'mid_price_log_3', 'bid_flatten_skew_50', 'volume_imbalance_3', 'mid_price_std_10']
# ---173 MSE score: 0.5231; ---173 Corr score: 0.1602
# Not improved: 1
# +++217 MSE score: 0.5231; +++217 Corr score: 0.1603
# Not improved: 2
# ---137 MSE score: 0.5231; ---137 Corr score: 0.1604
# Not improved: 3
# +++172 MSE score: 0.5231; +++172 Corr score: 0.1604
# Not improved: 4
# ---135 MSE score: 0.5231; ---135 Corr score: 0.1604
# Not improved: 5
# +++59 MSE score: 0.5231; +++59 Corr score: 0.1604
# Not improved: 6
# ---119 MSE score: 0.5231; ---119 Corr score: 0.1604
# Not improved: 7
# +++126 MSE score: 0.5231; +++126 Corr score: 0.1604
# SUCCESSFULL ADDING OF decreased_ask_counts_{window}. Len: 133
# Last added cols: ['mid_price_log_3', 'bid_flatten_skew_50', 'volume_imbalance_3', 'mid_price_std_10', 'decreased_ask_counts_{window}']
# ---202 MSE score: 0.5231; ---202 Corr score: 0.1604
# Not improved: 1
# +++203 MSE score: 0.5231; +++203 Corr score: 0.1602
# Not improved: 2
# ---1 MSE score: 0.5231; ---1 Corr score: 0.1604
# Not improved: 3
# +++162 MSE score: 0.5231; +++162 Corr score: 0.1604
# Not improved: 4
# ---35 MSE score: 0.5231; ---35 Corr score: 0.1602
# Not improved: 5
# +++90 MSE score: 0.5232; +++90 Corr score: 0.1598
# Not improved: 6
# ---145 MSE score: 0.5231; ---145 Corr score: 0.1604
# Not improved: 7
# +++17 MSE score: 0.5234; +++17 Corr score: 0.1587
# Not improved: 8
# ---70 MSE score: 0.5231; ---70 Corr score: 0.1604
# Not improved: 9
# +++219 MSE score: 0.5233; +++219 Corr score: 0.1594
# Not improved: 10
# ---159 MSE score: 0.5231; ---159 Corr score: 0.1602
# Not improved: 11
# +++217 MSE score: 0.5231; +++217 Corr score: 0.1603
# Not improved: 12
# ---198 MSE score: 0.5231; ---198 Corr score: 0.1603
# Not improved: 13
# +++32 MSE score: 0.5231; +++32 Corr score: 0.1603
# Not improved: 14
# ---185 MSE score: 0.5231; ---185 Corr score: 0.1604
# Not improved: 15
# +++181 MSE score: 0.5231; +++181 Corr score: 0.1606
# SUCCESSFULL ADDING OF wap1_10_mean. Len: 134
# Last added cols: ['bid_flatten_skew_50', 'volume_imbalance_3', 'mid_price_std_10', 'decreased_ask_counts_{window}', 'wap1_10_mean']
# ---38 MSE score: 0.5232; ---38 Corr score: 0.1599
# Not improved: 1
# +++183 MSE score: 0.5231; +++183 Corr score: 0.1604
# Not improved: 2
# ---10 MSE score: 0.5231; ---10 Corr score: 0.1605
# Not improved: 3
# +++225 MSE score: 0.5231; +++225 Corr score: 0.1605
# Not improved: 4
# ---205 MSE score: 0.5232; ---205 Corr score: 0.1600
# Not improved: 5
# +++225 MSE score: 0.5231; +++225 Corr score: 0.1605
# Not improved: 6
# ---87 MSE score: 0.5231; ---87 Corr score: 0.1605
# Not improved: 7
# +++118 MSE score: 0.5231; +++118 Corr score: 0.1605
# Not improved: 8
# ---104 MSE score: 0.5230; ---104 Corr score: 0.1608
# SUCCESSFULL REMOVE OF flatten_spread_50_ewm. Len: 133
# +++117 MSE score: 0.5231; +++117 Corr score: 0.1604
# Not improved: 1
# ---192 MSE score: 0.5230; ---192 Corr score: 0.1608
# Not improved: 2
# +++67 MSE score: 0.5231; +++67 Corr score: 0.1605
# Not improved: 3
# ---73 MSE score: 0.5231; ---73 Corr score: 0.1607
# Not improved: 4
# +++16 MSE score: 0.5230; +++16 Corr score: 0.1608
# Not improved: 5
# ---95 MSE score: 0.5231; ---95 Corr score: 0.1606
# Not improved: 6
# +++144 MSE score: 0.5231; +++144 Corr score: 0.1607
# Not improved: 7
# ---182 MSE score: 0.5231; ---182 Corr score: 0.1606
# Not improved: 8
# +++161 MSE score: 0.5230; +++161 Corr score: 0.1608
# Not improved: 9
# ---205 MSE score: 0.5231; ---205 Corr score: 0.1602
# Not improved: 10
# +++162 MSE score: 0.5230; +++162 Corr score: 0.1608
# Not improved: 11
# ---119 MSE score: 0.5230; ---119 Corr score: 0.1607
# Not improved: 12
# +++20 MSE score: 0.5235; +++20 Corr score: 0.1580
# Not improved: 13
# ---134 MSE score: 0.5230; ---134 Corr score: 0.1608
# Not improved: 14
# +++213 MSE score: 0.5230; +++213 Corr score: 0.1608
# Not improved: 15
# ---65 MSE score: 0.5231; ---65 Corr score: 0.1607
# Not improved: 16
# +++59 MSE score: 0.5231; +++59 Corr score: 0.1607
# Not improved: 17
# ---11 MSE score: 0.5232; ---11 Corr score: 0.1601
# Not improved: 18
# +++161 MSE score: 0.5230; +++161 Corr score: 0.1608
# Not improved: 19
# ---200 MSE score: 0.5230; ---200 Corr score: 0.1608
# Not improved: 20
# +++27 MSE score: 0.5231; +++27 Corr score: 0.1604
# Not improved: 21
